# %% [markdown]
# <a href="https://colab.research.google.com/github/SuwareeThammakoonsate/data_viz_2022/blob/main/Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# %%
path = '/content/drive/My Drive/DataViz22_data'
data_cases = pd.read_csv(os.path.join(path, 'confirmed-cases.csv'))
data_cases1 = pd.read_csv(os.path.join(path, 'confirmed-cases-since-120864.csv'))
data_cases2 = pd.read_csv(os.path.join(path, 'confirmed-cases-since-271064.csv'))
data_cases3 = pd.read_csv(os.path.join(path, 'confirmed-cases-since-280265.csv'))
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# # ข้อมูลจำนวนผู้เชื้อช่วงที่ 1

# %%
data_cases
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1            2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2            3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4            5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี         NaN
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770     12/8/2021     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771     12/8/2021     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# 0              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                     นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                    นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                      ...                               ...
# 839766             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839767             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839768             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839769             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839770             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0          กรุงเทพมหานคร               NaN
# 1          กรุงเทพมหานคร               NaN
# 2                 นครปฐม             เมือง
# 3          กรุงเทพมหานคร               NaN
# 4          กรุงเทพมหานคร               NaN
# ...                  ...               ...
# 839766         กาญจนบุรี               NaN
# 839767         กาญจนบุรี               NaN
# 839768         กาญจนบุรี               NaN
# 839769         กาญจนบุรี               NaN
# 839770         กาญจนบุรี               NaN
#
# [839771 rows x 11 columns]

# %% [markdown]
# # ข้อมูลจำนวนผู้เชื้อช่วงที่ 2

# %%
data_cases1
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0         816990     12/8/2021     11/8/2021   ชาย   7.0   ปี    Thailand
# 1         816991     12/8/2021     11/8/2021   ชาย   1.0   ปี    Thailand
# 2         816992     12/8/2021     11/8/2021   ชาย  35.0   ปี    Thailand
# 3         816993     12/8/2021     11/8/2021  หญิง  33.0   ปี    Thailand
# 4         816994     12/8/2021     11/8/2021  หญิง  14.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1042163  1859153    25/10/2021    24/10/2021   ชาย  45.0   ปี         NaN
# 1042164  1859154    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042165  1859155    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042166  1859156    25/10/2021    24/10/2021   ชาย  24.0   ปี         NaN
# 1042167  1859157    25/10/2021    24/10/2021   ชาย  25.0   ปี         NaN
#
#         province_of_isolation                                         risk  \
# 0                    เชียงราย                                        อื่นๆ
# 1                    เชียงราย                                        อื่นๆ
# 2                    เชียงราย                                        อื่นๆ
# 3                    เชียงราย                                        อื่นๆ
# 4                    เชียงราย  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                       ...                                          ...
# 1042163         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042164         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042165         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042166         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042167             เชียงใหม่                             ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset
# 0                     NaN               NaN
# 1                     NaN               NaN
# 2                     NaN               NaN
# 3                     NaN               NaN
# 4                     NaN               NaN
# ...                   ...               ...
# 1042163               NaN               NaN
# 1042164               NaN               NaN
# 1042165               NaN               NaN
# 1042166               NaN               NaN
# 1042167               NaN               NaN
#
# [1042168 rows x 11 columns]

# %% [markdown]
# # ข้อมูลจำนวนผู้เชื้อช่วงที่ 3

# %%
data_cases2
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0        1859158    26/10/2021    25/10/2021   ชาย  20.0   ปี    Thailand
# 1        1859159    26/10/2021    25/10/2021  หญิง  42.0   ปี    Thailand
# 2        1859160    26/10/2021    25/10/2021  หญิง  33.0   ปี    Thailand
# 3        1859161    26/10/2021    25/10/2021  หญิง  52.0   ปี    Thailand
# 4        1859162    26/10/2021    25/10/2021  หญิง  84.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1010454  2869612     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010455  2869613     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010456  2869614     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010457  2869615     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010458  2869616     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
#
#         province_of_isolation                                           risk  \
# 0                       ลำปาง                                          อื่นๆ
# 1                       ลำปาง                                          อื่นๆ
# 2                       ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 3                       ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 4                       ลำปาง    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                       ...                                            ...
# 1010454         กรุงเทพมหานคร                               ทัณฑสถาน/เรือนจำ
# 1010455         กรุงเทพมหานคร                               ทัณฑสถาน/เรือนจำ
# 1010456               ปัตตานี                               ทัณฑสถาน/เรือนจำ
# 1010457               ปัตตานี                               ทัณฑสถาน/เรือนจำ
# 1010458               ปัตตานี                               ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset  Unnamed: 11
# 0                   ลำปาง        เมืองลำปาง          NaN
# 1                   ลำปาง        เมืองลำปาง          NaN
# 2                   ลำปาง          ห้างฉัตร          NaN
# 3                   ลำปาง          ห้างฉัตร          NaN
# 4                   ลำปาง        เมืองลำปาง          NaN
# ...                   ...               ...          ...
# 1010454               NaN               NaN          NaN
# 1010455               NaN               NaN          NaN
# 1010456               NaN               NaN          NaN
# 1010457               NaN               NaN          NaN
# 1010458               NaN               NaN          NaN
#
# [1010459 rows x 12 columns]

# %% [markdown]
# # ข้อมูลจำนวนผู้เชื้อช่วงที่ 4

# %%
data_cases3
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0       2869617     28/2/2022     27/2/2022   ชาย  41.0   ปี    Thailand
# 1       2869618     28/2/2022     27/2/2022  หญิง  45.0   ปี    Thailand
# 2       2869619     28/2/2022     27/2/2022  หญิง  40.0   ปี    Thailand
# 3       2869620     28/2/2022     27/2/2022   ชาย  44.0   ปี    Thailand
# 4       2869621     28/2/2022     27/2/2022   ชาย  11.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 357076  3226693     15/3/2022     14/3/2022   ชาย   NaN  NaN         NaN
# 357077  3226694     15/3/2022     14/3/2022   ชาย   NaN  NaN         NaN
# 357078  3226695     15/3/2022     14/3/2022   ชาย   NaN  NaN         NaN
# 357079  3226696     15/3/2022     14/3/2022   ชาย   NaN  NaN         NaN
# 357080  3226697     15/3/2022     14/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                                         risk  \
# 0                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 3                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 4                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                      ...                                          ...
# 357076            ปราจีนบุรี                             ทัณฑสถาน/เรือนจำ
# 357077            ปราจีนบุรี                             ทัณฑสถาน/เรือนจำ
# 357078            นครราชสีมา                             ทัณฑสถาน/เรือนจำ
# 357079            นครราชสีมา                             ทัณฑสถาน/เรือนจำ
# 357080               ขอนแก่น                             ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0                  พะเยา        เมืองพะเยา
# 1                  พะเยา        เมืองพะเยา
# 2                  พะเยา        เมืองพะเยา
# 3                  พะเยา        เมืองพะเยา
# 4                  พะเยา        เมืองพะเยา
# ...                  ...               ...
# 357076               NaN               NaN
# 357077               NaN               NaN
# 357078               NaN               NaN
# 357079               NaN               NaN
# 357080               NaN               NaN
#
# [357081 rows x 11 columns]

# %% [markdown]
# # เตรียมข้อมูล

# %% [markdown]
# ## ข้อมูลจำนวนผู้เชื้อช่วงที่ 1

# %%
data_cases.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# จากการตรวจสอบพบว่า มี column ที่มีค่า missing คือ
#
# *   Notified date
# *   sex
# *   age
# *   Unit
# *   nationality
# *   province_of_isolation
# *   risk
# *   province_of_onset
# *   district_of_onset

# %%
casedrop = pd.read_csv(os.path.join(path, 'confirmed-cases.csv'))
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ### dropna

# %%
casedrop_clean = casedrop.dropna() 
casedrop_clean
# Out:
#            No. announce_date Notified date   sex   age Unit     nationality  \
# 47          48      6/3/2020      4/3/2020   ชาย  43.0   ปี  United Kingdom
# 124        125      6/3/2021      5/3/2021  หญิง  55.0   ปี        Thailand
# 161        162     17/3/2020     21/3/2020   ชาย  14.0   ปี        Thailand
# 181        182     18/3/2020     15/3/2020   ชาย  33.0   ปี        Thailand
# 186        187     18/3/2020     16/3/2020   ชาย  36.0   ปี        Thailand
# ...        ...           ...           ...   ...   ...  ...             ...
# 839391  839392     12/8/2021     11/8/2021  หญิง  83.0   ปี        Thailand
# 839392  839393     12/8/2021     11/8/2021   ชาย  66.0   ปี        Thailand
# 839393  839394     12/8/2021     11/8/2021  หญิง  43.0   ปี        Thailand
# 839394  839395     12/8/2021     11/8/2021  หญิง  74.0   ปี        Thailand
# 839395  839396     12/8/2021     11/8/2021   ชาย  29.0   ปี        Thailand
#
#        province_of_isolation  \
# 47             กรุงเทพมหานคร
# 124                 ปทุมธานี
# 161             สุราษฎร์ธานี
# 181                  ขอนแก่น
# 186                 ร้อยเอ็ด
# ...                      ...
# 839391         กรุงเทพมหานคร
# 839392         กรุงเทพมหานคร
# 839393         กรุงเทพมหานคร
# 839394         กรุงเทพมหานคร
# 839395         กรุงเทพมหานคร
#
#                                                      risk province_of_onset  \
# 47                       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 124                                   Cluster ตลาดพรพัฒน์          ปทุมธานี
# 161           สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้      สุราษฎร์ธานี
# 181                                               สนามมวย           ขอนแก่น
# 186                                               สนามมวย          ร้อยเอ็ด
# ...                                                   ...               ...
# 839391      ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว     กรุงเทพมหานคร
# 839392        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้     กรุงเทพมหานคร
# 839393      ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว     กรุงเทพมหานคร
# 839394      ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว     กรุงเทพมหานคร
# 839395  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...     กรุงเทพมหานคร
#
#        district_of_onset
# 47               คลองตัน
# 124              ธัญบุรี
# 161                เมือง
# 181                เมือง
# 186            เชียงขวัญ
# ...                  ...
# 839391             วัฒนา
# 839392       บางขุนเทียน
# 839393            ประเวศ
# 839394            ธนบุรี
# 839395            ประเวศ
#
# [599988 rows x 11 columns]

# %%
casedrop_clean.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# dtype: bool

# %%
casedrop_clean.shape #ขนาดของตาราง dropna
# Out:
# (599988, 11)

# %%
removes = data_cases.shape[0] - casedrop_clean.shape[0]
print(f'size before drop = {data_cases.shape[0]}')
print(f'size after drop = {casedrop_clean.shape[0]}')
print(f'% from drop = {(removes/data_cases.shape[0])*100}')
 #มีข้อมูลที่หายไป 28% ซึ่งไม่สามารถยอมรับได้
# Out:
# size before drop = 839771
# size after drop = 599988
# % from drop = 28.553379433202625

# %% [markdown]
# ### แทน missing ด้วยค่าที่เหมาะสม (fillna())

# %%
case = data_cases.fillna(value={'Notified date':'ไม่มีข้อมูล','sex':'ไม่มีข้อมูล','Unit':'ปี','nationality':'ไม่มีข้อมูล','province_of_isolation':'ไม่มีข้อมูล','risk':'ไม่มีข้อมูล','province_of_onset':'ไม่มีข้อมูล','district_of_onset':'ไม่มีข้อมูล'}) #แทนด้วยคำว่า ไม่มีข้อมูล ได้เนื่องจากในตารางมีค่าว่าง และในคอลัมป์ไม่มีค่าเป็นตัวเลขจึงใช้ค่า string ในการแทนที่ได้

# %%
case
# Out:
#            No. announce_date Notified date   sex   age Unit  nationality  \
# 0            1     12/1/2020   ไม่มีข้อมูล  หญิง  61.0   ปี        China
# 1            2     17/1/2020   ไม่มีข้อมูล  หญิง  74.0   ปี        China
# 2            3     22/1/2020   ไม่มีข้อมูล  หญิง  73.0   ปี     Thailand
# 3            4     22/1/2020   ไม่มีข้อมูล   ชาย  68.0   ปี        China
# 4            5     24/1/2020   ไม่มีข้อมูล  หญิง  66.0   ปี        China
# ...        ...           ...           ...   ...   ...  ...          ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี  ไม่มีข้อมูล
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี     Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี     Thailand
# 839769  839770     12/8/2021     11/8/2021   ชาย  83.0   ปี     Thailand
# 839770  839771     12/8/2021     11/8/2021   ชาย  47.0   ปี     Thailand
#
#        province_of_isolation                              risk  \
# 0              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                     นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                    นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                      ...                               ...
# 839766             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839767             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839768             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839769             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839770             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0          กรุงเทพมหานคร       ไม่มีข้อมูล
# 1          กรุงเทพมหานคร       ไม่มีข้อมูล
# 2                 นครปฐม             เมือง
# 3          กรุงเทพมหานคร       ไม่มีข้อมูล
# 4          กรุงเทพมหานคร       ไม่มีข้อมูล
# ...                  ...               ...
# 839766         กาญจนบุรี       ไม่มีข้อมูล
# 839767         กาญจนบุรี       ไม่มีข้อมูล
# 839768         กาญจนบุรี       ไม่มีข้อมูล
# 839769         กาญจนบุรี       ไม่มีข้อมูล
# 839770         กาญจนบุรี       ไม่มีข้อมูล
#
# [839771 rows x 11 columns]

# %% [markdown]
# ### แทนค่า missing ของ age ด้วย mean()

# %%
avg_age = case[['age']].mean() #เติมค่าใหม่โดยคำสั่ง .fillna
case[['age']] = case[['age']].fillna('ปี')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.

# %%
case.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# dtype: bool

# %% [markdown]
# จากการเตรียมข้อมูลจะเห็นได้ว่า ข้อมูลของจำนวนติดเชื้อช่วงที่ 1 ไม่มีค่า missing แล้ว

# %%
case.isnull().sum()
# Out:
# No.                      0
# announce_date            0
# Notified date            0
# sex                      0
# age                      0
# Unit                     0
# nationality              0
# province_of_isolation    0
# risk                     0
# province_of_onset        0
# district_of_onset        0
# dtype: int64

# %% [markdown]
# ### เลือกข้อมูลที่สนใจ

# %%
data_01 = case[['announce_date','age','risk','province_of_onset','district_of_onset']]
data_01
# Out:
#        announce_date   age                              risk  \
# 0          12/1/2020  61.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1          17/1/2020  74.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2          22/1/2020  73.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3          22/1/2020  68.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4          24/1/2020  66.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...              ...   ...                               ...
# 839766     12/8/2021  52.0                  ทัณฑสถาน/เรือนจำ
# 839767     12/8/2021  34.0                  ทัณฑสถาน/เรือนจำ
# 839768     12/8/2021  31.0                  ทัณฑสถาน/เรือนจำ
# 839769     12/8/2021  83.0                  ทัณฑสถาน/เรือนจำ
# 839770     12/8/2021  47.0                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0          กรุงเทพมหานคร       ไม่มีข้อมูล
# 1          กรุงเทพมหานคร       ไม่มีข้อมูล
# 2                 นครปฐม             เมือง
# 3          กรุงเทพมหานคร       ไม่มีข้อมูล
# 4          กรุงเทพมหานคร       ไม่มีข้อมูล
# ...                  ...               ...
# 839766         กาญจนบุรี       ไม่มีข้อมูล
# 839767         กาญจนบุรี       ไม่มีข้อมูล
# 839768         กาญจนบุรี       ไม่มีข้อมูล
# 839769         กาญจนบุรี       ไม่มีข้อมูล
# 839770         กาญจนบุรี       ไม่มีข้อมูล
#
# [839771 rows x 5 columns]

# %% [markdown]
# ## ข้อมูลจำนวนผู้เชื้อช่วงที่ 2

# %%
data_cases1.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation    False
# risk                     False
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# จากการตรวจสอบพบว่า มี column ที่มีค่า missing คือ
#
# *   sex
# *   age
# *   Unit
# *   nationality
# *   province_of_onset
# *   district_of_onset

# %%
casedrop2 = pd.read_csv(os.path.join(path, 'confirmed-cases-since-120864.csv'))

# %% [markdown]
# ### dropna

# %%
casedrop2_clean = casedrop2.dropna() 
casedrop2_clean
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 249       817239     12/8/2021     11/8/2021   ชาย  48.0   ปี    Thailand
# 250       817240     12/8/2021     11/8/2021  หญิง  19.0   ปี    Thailand
# 251       817241     12/8/2021     11/8/2021  หญิง  37.0   ปี    Thailand
# 252       817242     12/8/2021     11/8/2021   ชาย  46.0   ปี    Thailand
# 253       817243     12/8/2021     11/8/2021   ชาย  60.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1041962  1858952    25/10/2021    24/10/2021   ชาย  67.0   ปี    Thailand
# 1041963  1858953    25/10/2021    24/10/2021  หญิง  39.0   ปี    Thailand
# 1041964  1858954    25/10/2021    24/10/2021   ชาย  80.0   ปี    Thailand
# 1041965  1858955    25/10/2021    24/10/2021  หญิง  67.0   ปี    Thailand
# 1041966  1858956    25/10/2021    24/10/2021  หญิง  53.0   ปี    Thailand
#
#         province_of_isolation                                         risk  \
# 249                 เพชรบูรณ์  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 250                 เพชรบูรณ์  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 251                 เพชรบูรณ์  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 252                 เพชรบูรณ์  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 253                 เพชรบูรณ์  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                       ...                                          ...
# 1041962         กรุงเทพมหานคร  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1041963         กรุงเทพมหานคร  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1041964         กรุงเทพมหานคร                                        อื่นๆ
# 1041965         กรุงเทพมหานคร                                        อื่นๆ
# 1041966         กรุงเทพมหานคร                                        อื่นๆ
#
#         province_of_onset district_of_onset
# 249             เพชรบูรณ์    เมืองเพชรบูรณ์
# 250             เพชรบูรณ์    เมืองเพชรบูรณ์
# 251             เพชรบูรณ์    เมืองเพชรบูรณ์
# 252             เพชรบูรณ์    เมืองเพชรบูรณ์
# 253             เพชรบูรณ์    เมืองเพชรบูรณ์
# ...                   ...               ...
# 1041962     กรุงเทพมหานคร           บางพลัด
# 1041963     กรุงเทพมหานคร           บางพลัด
# 1041964     กรุงเทพมหานคร            สายไหม
# 1041965     กรุงเทพมหานคร            สายไหม
# 1041966     กรุงเทพมหานคร            สายไหม
#
# [773368 rows x 11 columns]

# %%
casedrop2_clean.shape #ขนาดของตาราง dropna
# Out:
# (773368, 11)

# %%
removes = data_cases1.shape[0] - casedrop2_clean.shape[0]
print(f'size before drop = {data_cases1.shape[0]}')
print(f'size after drop = {casedrop2_clean.shape[0]}')
print(f'% from drop = {(removes/data_cases1.shape[0])*100}')
 #มีข้อมูลที่หายไป 25% ซึ่งไม่สามารถยอมรับได้
# Out:
# size before drop = 1042168
# size after drop = 773368
# % from drop = 25.792386640157826

# %% [markdown]
# ### แทน missing ด้วยค่าที่เหมาะสม (fillna())

# %%
case1 = data_cases1.fillna(value={'sex':'ไม่มีข้อมูล','Unit':'ปี','nationality':'ไม่มีข้อมูล','province_of_onset':'ไม่มีข้อมูล','district_of_onset':'ไม่มีข้อมูล'})

# %%
case1
# Out:
#              No. announce_date Notified date   sex   age Unit  nationality  \
# 0         816990     12/8/2021     11/8/2021   ชาย   7.0   ปี     Thailand
# 1         816991     12/8/2021     11/8/2021   ชาย   1.0   ปี     Thailand
# 2         816992     12/8/2021     11/8/2021   ชาย  35.0   ปี     Thailand
# 3         816993     12/8/2021     11/8/2021  หญิง  33.0   ปี     Thailand
# 4         816994     12/8/2021     11/8/2021  หญิง  14.0   ปี     Thailand
# ...          ...           ...           ...   ...   ...  ...          ...
# 1042163  1859153    25/10/2021    24/10/2021   ชาย  45.0   ปี  ไม่มีข้อมูล
# 1042164  1859154    25/10/2021    24/10/2021   ชาย  31.0   ปี  ไม่มีข้อมูล
# 1042165  1859155    25/10/2021    24/10/2021   ชาย  31.0   ปี  ไม่มีข้อมูล
# 1042166  1859156    25/10/2021    24/10/2021   ชาย  24.0   ปี  ไม่มีข้อมูล
# 1042167  1859157    25/10/2021    24/10/2021   ชาย  25.0   ปี  ไม่มีข้อมูล
#
#         province_of_isolation                                         risk  \
# 0                    เชียงราย                                        อื่นๆ
# 1                    เชียงราย                                        อื่นๆ
# 2                    เชียงราย                                        อื่นๆ
# 3                    เชียงราย                                        อื่นๆ
# 4                    เชียงราย  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                       ...                                          ...
# 1042163         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042164         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042165         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042166         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042167             เชียงใหม่                             ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset
# 0             ไม่มีข้อมูล       ไม่มีข้อมูล
# 1             ไม่มีข้อมูล       ไม่มีข้อมูล
# 2             ไม่มีข้อมูล       ไม่มีข้อมูล
# 3             ไม่มีข้อมูล       ไม่มีข้อมูล
# 4             ไม่มีข้อมูล       ไม่มีข้อมูล
# ...                   ...               ...
# 1042163       ไม่มีข้อมูล       ไม่มีข้อมูล
# 1042164       ไม่มีข้อมูล       ไม่มีข้อมูล
# 1042165       ไม่มีข้อมูล       ไม่มีข้อมูล
# 1042166       ไม่มีข้อมูล       ไม่มีข้อมูล
# 1042167       ไม่มีข้อมูล       ไม่มีข้อมูล
#
# [1042168 rows x 11 columns]

# %% [markdown]
# ### แทนค่า missing ของ age ด้วย mean()

# %%
mean_age1 = case1[['age']].mean()

# %%
case1[['age']] = case1[['age']].fillna(mean_age1)

# %%
case1.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# dtype: bool

# %%
case1.isnull().sum()
# Out:
# No.                      0
# announce_date            0
# Notified date            0
# sex                      0
# age                      0
# Unit                     0
# nationality              0
# province_of_isolation    0
# risk                     0
# province_of_onset        0
# district_of_onset        0
# dtype: int64

# %% [markdown]
# จากการเตรียมข้อมูลจะเห็นได้ว่า ข้อมูลของจำนวนติดเชื้อช่วงที่ 2 ไม่มีค่า missing แล้ว

# %% [markdown]
# ### เลือกข้อมูลที่สนใจ

# %%
data_02 = case1[['announce_date','age','risk','province_of_onset','district_of_onset']]
data_02
# Out:
#         announce_date   age                                         risk  \
# 0           12/8/2021   7.0                                        อื่นๆ
# 1           12/8/2021   1.0                                        อื่นๆ
# 2           12/8/2021  35.0                                        อื่นๆ
# 3           12/8/2021  33.0                                        อื่นๆ
# 4           12/8/2021  14.0  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...               ...   ...                                          ...
# 1042163    25/10/2021  45.0                             ทัณฑสถาน/เรือนจำ
# 1042164    25/10/2021  31.0                             ทัณฑสถาน/เรือนจำ
# 1042165    25/10/2021  31.0                             ทัณฑสถาน/เรือนจำ
# 1042166    25/10/2021  24.0                             ทัณฑสถาน/เรือนจำ
# 1042167    25/10/2021  25.0                             ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset
# 0             ไม่มีข้อมูล       ไม่มีข้อมูล
# 1             ไม่มีข้อมูล       ไม่มีข้อมูล
# 2             ไม่มีข้อมูล       ไม่มีข้อมูล
# 3             ไม่มีข้อมูล       ไม่มีข้อมูล
# 4             ไม่มีข้อมูล       ไม่มีข้อมูล
# ...                   ...               ...
# 1042163       ไม่มีข้อมูล       ไม่มีข้อมูล
# 1042164       ไม่มีข้อมูล       ไม่มีข้อมูล
# 1042165       ไม่มีข้อมูล       ไม่มีข้อมูล
# 1042166       ไม่มีข้อมูล       ไม่มีข้อมูล
# 1042167       ไม่มีข้อมูล       ไม่มีข้อมูล
#
# [1042168 rows x 5 columns]

# %% [markdown]
# ## ข้อมูลจำนวนผู้เชื้อช่วงที่ 3

# %%
data_cases2.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# Unnamed: 11               True
# dtype: bool

# %% [markdown]
# จากการตรวจสอบพบว่า มี column ที่มีค่า missing คือ
#
# *   sex
# *   age
# *   Unit
# *   nationality
# *   province_of_isolation
# *   risk
# *   province_of_onset
# *   district_of_onset
# *   Unnamed:11

# %%
casedrop3 = pd.read_csv(os.path.join(path, 'confirmed-cases-since-271064.csv'))
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ### dropna

# %%
casedrop3_clean = casedrop3.dropna() 
casedrop3_clean
# Out:
# Empty DataFrame
# Columns: [No., announce_date, Notified date, sex, age, Unit, nationality, province_of_isolation, risk, province_of_onset, district_of_onset, Unnamed: 11]
# Index: []

# %%
casedrop3_clean.shape #ขนาดของตาราง dropna
# Out:
# (0, 12)

# %%
removes = data_cases2.shape[0] - casedrop3_clean.shape[0]
print(f'size before drop = {data_cases2.shape[0]}')
print(f'size after drop = {casedrop3_clean.shape[0]}')
print(f'% from drop = {(removes/data_cases2.shape[0])*100}')
 #มีข้อมูลที่หายไป 29% ซึ่งไม่สามารถยอมรับได้
# Out:
# size before drop = 1010459
# size after drop = 0
# % from drop = 100.0

# %% [markdown]
# ### แทน missing ด้วยค่าที่เหมาะสม (fillna())

# %%
case2 = data_cases2.fillna(value={'sex':'ไม่มีข้อมูล','Unit':'ปี','nationality':'ไม่มีข้อมูล','province_of_isolation':'ไม่มีข้อมูล','risk':'ไม่มีข้อมูล','province_of_onset':'ไม่มีข้อมูล','district_of_onset':'ไม่มีข้อมูล'})
case2
# Out:
#              No. announce_date Notified date   sex   age Unit  nationality  \
# 0        1859158    26/10/2021    25/10/2021   ชาย  20.0   ปี     Thailand
# 1        1859159    26/10/2021    25/10/2021  หญิง  42.0   ปี     Thailand
# 2        1859160    26/10/2021    25/10/2021  หญิง  33.0   ปี     Thailand
# 3        1859161    26/10/2021    25/10/2021  หญิง  52.0   ปี     Thailand
# 4        1859162    26/10/2021    25/10/2021  หญิง  84.0   ปี     Thailand
# ...          ...           ...           ...   ...   ...  ...          ...
# 1010454  2869612     27/2/2022     26/2/2022   ชาย   NaN   ปี  ไม่มีข้อมูล
# 1010455  2869613     27/2/2022     26/2/2022   ชาย   NaN   ปี  ไม่มีข้อมูล
# 1010456  2869614     27/2/2022     26/2/2022   ชาย   NaN   ปี  ไม่มีข้อมูล
# 1010457  2869615     27/2/2022     26/2/2022   ชาย   NaN   ปี  ไม่มีข้อมูล
# 1010458  2869616     27/2/2022     26/2/2022   ชาย   NaN   ปี  ไม่มีข้อมูล
#
#         province_of_isolation                                           risk  \
# 0                       ลำปาง                                          อื่นๆ
# 1                       ลำปาง                                          อื่นๆ
# 2                       ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 3                       ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 4                       ลำปาง    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                       ...                                            ...
# 1010454         กรุงเทพมหานคร                               ทัณฑสถาน/เรือนจำ
# 1010455         กรุงเทพมหานคร                               ทัณฑสถาน/เรือนจำ
# 1010456               ปัตตานี                               ทัณฑสถาน/เรือนจำ
# 1010457               ปัตตานี                               ทัณฑสถาน/เรือนจำ
# 1010458               ปัตตานี                               ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset  Unnamed: 11
# 0                   ลำปาง        เมืองลำปาง          NaN
# 1                   ลำปาง        เมืองลำปาง          NaN
# 2                   ลำปาง          ห้างฉัตร          NaN
# 3                   ลำปาง          ห้างฉัตร          NaN
# 4                   ลำปาง        เมืองลำปาง          NaN
# ...                   ...               ...          ...
# 1010454       ไม่มีข้อมูล       ไม่มีข้อมูล          NaN
# 1010455       ไม่มีข้อมูล       ไม่มีข้อมูล          NaN
# 1010456       ไม่มีข้อมูล       ไม่มีข้อมูล          NaN
# 1010457       ไม่มีข้อมูล       ไม่มีข้อมูล          NaN
# 1010458       ไม่มีข้อมูล       ไม่มีข้อมูล          NaN
#
# [1010459 rows x 12 columns]

# %% [markdown]
# ### แทนค่า missing ของ age ด้วย mean()

# %%
avg_age3 = case2[['age']].mean() #เติมค่าใหม่โดยคำสั่ง .fillna
case2[['age']] = case2[['age']].fillna('ปี')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.

# %%
case2.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# Unnamed: 11               True
# dtype: bool

# %%
case2.isnull().sum()
# Out:
# No.                            0
# announce_date                  0
# Notified date                  0
# sex                            0
# age                            0
# Unit                           0
# nationality                    0
# province_of_isolation          0
# risk                           0
# province_of_onset              0
# district_of_onset              0
# Unnamed: 11              1010459
# dtype: int64

# %% [markdown]
# ตัด column Unnamed: 11 ออกเนื่องจากไม่ทราบว่าเป็นข้อมูลเกี่ยวกับอะไรและเป็น column ที่ไม่มีความเกี่ยวข้องกัน

# %%
case2.drop(['Unnamed: 11'], axis=1, inplace=True)
case2
# Out:
#              No. announce_date Notified date   sex   age Unit  nationality  \
# 0        1859158    26/10/2021    25/10/2021   ชาย  20.0   ปี     Thailand
# 1        1859159    26/10/2021    25/10/2021  หญิง  42.0   ปี     Thailand
# 2        1859160    26/10/2021    25/10/2021  หญิง  33.0   ปี     Thailand
# 3        1859161    26/10/2021    25/10/2021  หญิง  52.0   ปี     Thailand
# 4        1859162    26/10/2021    25/10/2021  หญิง  84.0   ปี     Thailand
# ...          ...           ...           ...   ...   ...  ...          ...
# 1010454  2869612     27/2/2022     26/2/2022   ชาย    ปี   ปี  ไม่มีข้อมูล
# 1010455  2869613     27/2/2022     26/2/2022   ชาย    ปี   ปี  ไม่มีข้อมูล
# 1010456  2869614     27/2/2022     26/2/2022   ชาย    ปี   ปี  ไม่มีข้อมูล
# 1010457  2869615     27/2/2022     26/2/2022   ชาย    ปี   ปี  ไม่มีข้อมูล
# 1010458  2869616     27/2/2022     26/2/2022   ชาย    ปี   ปี  ไม่มีข้อมูล
#
#         province_of_isolation                                           risk  \
# 0                       ลำปาง                                          อื่นๆ
# 1                       ลำปาง                                          อื่นๆ
# 2                       ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 3                       ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 4                       ลำปาง    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                       ...                                            ...
# 1010454         กรุงเทพมหานคร                               ทัณฑสถาน/เรือนจำ
# 1010455         กรุงเทพมหานคร                               ทัณฑสถาน/เรือนจำ
# 1010456               ปัตตานี                               ทัณฑสถาน/เรือนจำ
# 1010457               ปัตตานี                               ทัณฑสถาน/เรือนจำ
# 1010458               ปัตตานี                               ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset
# 0                   ลำปาง        เมืองลำปาง
# 1                   ลำปาง        เมืองลำปาง
# 2                   ลำปาง          ห้างฉัตร
# 3                   ลำปาง          ห้างฉัตร
# 4                   ลำปาง        เมืองลำปาง
# ...                   ...               ...
# 1010454       ไม่มีข้อมูล       ไม่มีข้อมูล
# 1010455       ไม่มีข้อมูล       ไม่มีข้อมูล
# 1010456       ไม่มีข้อมูล       ไม่มีข้อมูล
# 1010457       ไม่มีข้อมูล       ไม่มีข้อมูล
# 1010458       ไม่มีข้อมูล       ไม่มีข้อมูล
#
# [1010459 rows x 11 columns]

# %%
case2.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# dtype: bool

# %% [markdown]
# จากการเตรียมข้อมูลจะเห็นได้ว่า ข้อมูลของจำนวนติดเชื้อช่วงที่ 3 ไม่มีค่า missing แล้ว

# %%
casedrop3.drop(['Unnamed: 11'], axis=1, inplace=True)
casedrop3
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0        1859158    26/10/2021    25/10/2021   ชาย  20.0   ปี    Thailand
# 1        1859159    26/10/2021    25/10/2021  หญิง  42.0   ปี    Thailand
# 2        1859160    26/10/2021    25/10/2021  หญิง  33.0   ปี    Thailand
# 3        1859161    26/10/2021    25/10/2021  หญิง  52.0   ปี    Thailand
# 4        1859162    26/10/2021    25/10/2021  หญิง  84.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1010454  2869612     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010455  2869613     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010456  2869614     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010457  2869615     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010458  2869616     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
#
#         province_of_isolation                                           risk  \
# 0                       ลำปาง                                          อื่นๆ
# 1                       ลำปาง                                          อื่นๆ
# 2                       ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 3                       ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 4                       ลำปาง    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                       ...                                            ...
# 1010454         กรุงเทพมหานคร                               ทัณฑสถาน/เรือนจำ
# 1010455         กรุงเทพมหานคร                               ทัณฑสถาน/เรือนจำ
# 1010456               ปัตตานี                               ทัณฑสถาน/เรือนจำ
# 1010457               ปัตตานี                               ทัณฑสถาน/เรือนจำ
# 1010458               ปัตตานี                               ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset
# 0                   ลำปาง        เมืองลำปาง
# 1                   ลำปาง        เมืองลำปาง
# 2                   ลำปาง          ห้างฉัตร
# 3                   ลำปาง          ห้างฉัตร
# 4                   ลำปาง        เมืองลำปาง
# ...                   ...               ...
# 1010454               NaN               NaN
# 1010455               NaN               NaN
# 1010456               NaN               NaN
# 1010457               NaN               NaN
# 1010458               NaN               NaN
#
# [1010459 rows x 11 columns]

# %% [markdown]
# ### เลือกข้อมูลที่สนใจ

# %%
data_03 = case2[['announce_date','age','risk','province_of_onset','district_of_onset']]
data_03
# Out:
#         announce_date   age                                           risk  \
# 0          26/10/2021  20.0                                          อื่นๆ
# 1          26/10/2021  42.0                                          อื่นๆ
# 2          26/10/2021  33.0  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 3          26/10/2021  52.0  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 4          26/10/2021  84.0    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...               ...   ...                                            ...
# 1010454     27/2/2022    ปี                               ทัณฑสถาน/เรือนจำ
# 1010455     27/2/2022    ปี                               ทัณฑสถาน/เรือนจำ
# 1010456     27/2/2022    ปี                               ทัณฑสถาน/เรือนจำ
# 1010457     27/2/2022    ปี                               ทัณฑสถาน/เรือนจำ
# 1010458     27/2/2022    ปี                               ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset
# 0                   ลำปาง        เมืองลำปาง
# 1                   ลำปาง        เมืองลำปาง
# 2                   ลำปาง          ห้างฉัตร
# 3                   ลำปาง          ห้างฉัตร
# 4                   ลำปาง        เมืองลำปาง
# ...                   ...               ...
# 1010454       ไม่มีข้อมูล       ไม่มีข้อมูล
# 1010455       ไม่มีข้อมูล       ไม่มีข้อมูล
# 1010456       ไม่มีข้อมูล       ไม่มีข้อมูล
# 1010457       ไม่มีข้อมูล       ไม่มีข้อมูล
# 1010458       ไม่มีข้อมูล       ไม่มีข้อมูล
#
# [1010459 rows x 5 columns]

# %% [markdown]
# ## ข้อมูลจำนวนผู้เชื้อช่วงที่ 4

# %%
data_cases3.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation    False
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# จากการตรวจสอบพบว่า มี column ที่มีค่า missing คือ
#
# *   sex
# *   age
# *   Unit
# *   nationality
# *   risk
# *   province_of_onset
# *   district_of_onset

# %%
casedrop4 = pd.read_csv(os.path.join(path, 'confirmed-cases-since-280265.csv'))

# %% [markdown]
# ### dropna

# %%
casedrop4_clean = casedrop4.dropna() 
casedrop4_clean
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0       2869617     28/2/2022     27/2/2022   ชาย  41.0   ปี    Thailand
# 1       2869618     28/2/2022     27/2/2022  หญิง  45.0   ปี    Thailand
# 2       2869619     28/2/2022     27/2/2022  หญิง  40.0   ปี    Thailand
# 3       2869620     28/2/2022     27/2/2022   ชาย  44.0   ปี    Thailand
# 4       2869621     28/2/2022     27/2/2022   ชาย  11.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 357022  3226639     15/3/2022     14/3/2022  หญิง  66.0   ปี    Thailand
# 357023  3226640     15/3/2022     14/3/2022  หญิง  49.0   ปี    Thailand
# 357024  3226641     15/3/2022     14/3/2022  หญิง  19.0   ปี    Thailand
# 357025  3226642     15/3/2022     14/3/2022   ชาย  66.0   ปี    Thailand
# 357026  3226643     15/3/2022     14/3/2022   ชาย  46.0   ปี    Thailand
#
#        province_of_isolation                                         risk  \
# 0                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 3                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 4                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                      ...                                          ...
# 357022         กรุงเทพมหานคร                                        อื่นๆ
# 357023         กรุงเทพมหานคร                                        อื่นๆ
# 357024         กรุงเทพมหานคร                                        อื่นๆ
# 357025         กรุงเทพมหานคร                                        อื่นๆ
# 357026         กรุงเทพมหานคร                                        อื่นๆ
#
#        province_of_onset district_of_onset
# 0                  พะเยา        เมืองพะเยา
# 1                  พะเยา        เมืองพะเยา
# 2                  พะเยา        เมืองพะเยา
# 3                  พะเยา        เมืองพะเยา
# 4                  พะเยา        เมืองพะเยา
# ...                  ...               ...
# 357022     กรุงเทพมหานคร          ห้วยขวาง
# 357023     กรุงเทพมหานคร          ห้วยขวาง
# 357024     กรุงเทพมหานคร           ราชเทวี
# 357025     กรุงเทพมหานคร          ลาดพร้าว
# 357026     กรุงเทพมหานคร          ห้วยขวาง
#
# [272319 rows x 11 columns]

# %%
casedrop4_clean.shape #ขนาดของตาราง dropna
# Out:
# (272319, 11)

# %%
removes = data_cases3.shape[0] - casedrop4_clean.shape[0]
print(f'size before drop = {data_cases3.shape[0]}')
print(f'size after drop = {casedrop4_clean.shape[0]}')
print(f'% from drop = {(removes/data_cases3.shape[0])*100}')
 #มีข้อมูลที่หายไป 23% ซึ่งไม่สามารถยอมรับได้
# Out:
# size before drop = 357081
# size after drop = 272319
# % from drop = 23.737471330034364

# %% [markdown]
# ### แทน missing ด้วยค่าที่เหมาะสม (fillna())

# %%
case3 = data_cases3.fillna(value={'sex':'ไม่มีข้อมูล','Unit':'ปี','nationality':'ไม่มีข้อมูล','risk':'ไม่มีข้อมูล','province_of_onset':'ไม่มีข้อมูล','district_of_onset':'ไม่มีข้อมูล'})
case3
# Out:
#             No. announce_date Notified date   sex   age Unit  nationality  \
# 0       2869617     28/2/2022     27/2/2022   ชาย  41.0   ปี     Thailand
# 1       2869618     28/2/2022     27/2/2022  หญิง  45.0   ปี     Thailand
# 2       2869619     28/2/2022     27/2/2022  หญิง  40.0   ปี     Thailand
# 3       2869620     28/2/2022     27/2/2022   ชาย  44.0   ปี     Thailand
# 4       2869621     28/2/2022     27/2/2022   ชาย  11.0   ปี     Thailand
# ...         ...           ...           ...   ...   ...  ...          ...
# 357076  3226693     15/3/2022     14/3/2022   ชาย   NaN   ปี  ไม่มีข้อมูล
# 357077  3226694     15/3/2022     14/3/2022   ชาย   NaN   ปี  ไม่มีข้อมูล
# 357078  3226695     15/3/2022     14/3/2022   ชาย   NaN   ปี  ไม่มีข้อมูล
# 357079  3226696     15/3/2022     14/3/2022   ชาย   NaN   ปี  ไม่มีข้อมูล
# 357080  3226697     15/3/2022     14/3/2022  หญิง   NaN   ปี  ไม่มีข้อมูล
#
#        province_of_isolation                                         risk  \
# 0                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 3                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 4                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                      ...                                          ...
# 357076            ปราจีนบุรี                             ทัณฑสถาน/เรือนจำ
# 357077            ปราจีนบุรี                             ทัณฑสถาน/เรือนจำ
# 357078            นครราชสีมา                             ทัณฑสถาน/เรือนจำ
# 357079            นครราชสีมา                             ทัณฑสถาน/เรือนจำ
# 357080               ขอนแก่น                             ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0                  พะเยา        เมืองพะเยา
# 1                  พะเยา        เมืองพะเยา
# 2                  พะเยา        เมืองพะเยา
# 3                  พะเยา        เมืองพะเยา
# 4                  พะเยา        เมืองพะเยา
# ...                  ...               ...
# 357076       ไม่มีข้อมูล       ไม่มีข้อมูล
# 357077       ไม่มีข้อมูล       ไม่มีข้อมูล
# 357078       ไม่มีข้อมูล       ไม่มีข้อมูล
# 357079       ไม่มีข้อมูล       ไม่มีข้อมูล
# 357080       ไม่มีข้อมูล       ไม่มีข้อมูล
#
# [357081 rows x 11 columns]

# %% [markdown]
# ### แทนค่า missing ของ age ด้วย mean()

# %%
mean_age3 = case3[['age']].mean() 
mean_age3
# Out:
# age    36.943725
# dtype: float64

# %%
case3[['age']] = case3[['age']].fillna(mean_age3)

# %%
case3.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# dtype: bool

# %%
case3.isnull().sum()
# Out:
# No.                      0
# announce_date            0
# Notified date            0
# sex                      0
# age                      0
# Unit                     0
# nationality              0
# province_of_isolation    0
# risk                     0
# province_of_onset        0
# district_of_onset        0
# dtype: int64

# %% [markdown]
# จากการเตรียมข้อมูลจะเห็นได้ว่า ข้อมูลของจำนวนติดเชื้อช่วงที่ 3 ไม่มีค่า missing แล้ว

# %% [markdown]
# ### เลือกข้อมูลที่สนใจ

# %%
data_04 = case3[['announce_date','age','risk','province_of_onset','district_of_onset']]
data_04
# Out:
#        announce_date        age                                         risk  \
# 0          28/2/2022  41.000000  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1          28/2/2022  45.000000  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2          28/2/2022  40.000000  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 3          28/2/2022  44.000000  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 4          28/2/2022  11.000000  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...              ...        ...                                          ...
# 357076     15/3/2022  36.943725                             ทัณฑสถาน/เรือนจำ
# 357077     15/3/2022  36.943725                             ทัณฑสถาน/เรือนจำ
# 357078     15/3/2022  36.943725                             ทัณฑสถาน/เรือนจำ
# 357079     15/3/2022  36.943725                             ทัณฑสถาน/เรือนจำ
# 357080     15/3/2022  36.943725                             ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0                  พะเยา        เมืองพะเยา
# 1                  พะเยา        เมืองพะเยา
# 2                  พะเยา        เมืองพะเยา
# 3                  พะเยา        เมืองพะเยา
# 4                  พะเยา        เมืองพะเยา
# ...                  ...               ...
# 357076       ไม่มีข้อมูล       ไม่มีข้อมูล
# 357077       ไม่มีข้อมูล       ไม่มีข้อมูล
# 357078       ไม่มีข้อมูล       ไม่มีข้อมูล
# 357079       ไม่มีข้อมูล       ไม่มีข้อมูล
# 357080       ไม่มีข้อมูล       ไม่มีข้อมูล
#
# [357081 rows x 5 columns]

# %% [markdown]
# ## แก้คำผิดของข้อมูลแต่ละช่วง

# %%
data_01['province_of_onset'].replace({'USA':'ไม่มีข้อมูล','\tประจวบคีรีขันธ์':'ประจวบคีรีขันธ์','\xa0กาญจนบุรี':'กาญจนบุรี','\xa0ชลบุรี':'ชลบุรี','\xa0ตราด':'ตราด','\xa0นครปฐม':'นครปฐม',
                                         '\xa0สมุทรสงคราม':'สมุทรสงคราม','\xa0สมุทรสาคร':'สมุทรสาคร','\xa0อุทัยธานี':'อุทัยธานี','กทม':'กรุงเทพมหานคร','กทม.':'กรุงเทพมหานคร','กบินทร์บุรี':'ปราจีนบุรี','กระบี่ี่':'กระบี่','กรุงเทพ':'กรุงเทพมหานคร',
                                         'กรุงเทพมหานคร.':'กรุงเทพมหานคร','กรุงเทพมหานคร. / พระนครศรีอยุธยา':'กรุงเทพมหานคร','กรุงเทพมหานคร. / ศรีสะเกษ':'กรุงเทพมหานคร','กรุงเทพฯ':'กรุงเทพมหานคร','กะทู้':'ภูเก็ต',
                                         'กัมพูชา':'ไม่มีข้อมูล','กาญจบุรี':'กาญจนบุรี','กาญนบุรี':'กาญจนบุรี','กาฬสิน':'กาฬสินธุ์','กาฬสินธิ์':'กาฬสินธุ์','กาฬสินธุ์\xa0':'กาฬสินธุ์','กาฬสินธ์':'กาฬสินธุ์',
                                         'กำเพงเพชร':'กำแพงเพชร','กำแพง':'กำแพงเพชร','กำแพงเพชร':'กำแพงเพชร','กำแพงเพชร\xa0':'กำแพงเพชร','กําแพงเพชร':'กำแพงเพชร',
                                         'ขอนแก่น\xa0':'ขอนแก่น','ขอนแก่่น':'ขอนแก่น','ขานุวรลักษณ์บุรี':'กำแพงเพชร','คนไทยเดินทางกลับจากต่างประเทศ':'ไม่มีข้อมูล','คลองเตย':'กรุงเทพมหานคร','จ.กรุงเทพมหานคร':'กรุงเทพมหานคร',
                                         'จ.ภูเก็ต':'ภูเก็ต','จ.ราชบุรี':'ราชบุรี','จ.สุราษฎร์ธานี':'สุราษฎร์ธานี','จังหวัดสมุทรสาคร':'สมุทรสาคร','ฉะเชองเทราร':'ฉะเชิงเทรา','ชมพร':'ชุมพร',
                                         'ชลบุรี\t':'ชลบุรี','ชลบุรี\xa0':'ชลบุรี','ชลบุุรี':'ชลบุรี','ชอนแก่น':'ขอนแก่น','ชัยนาถ':'ชัยนาท','ชัยบาดาล':'ลพบุรี','ชัยภูมิ\xa0':'ชัยภูมิ','ชุุมพร':'ชุมพร','ชุุุมพร':'ชุมพร',
                                         'ดอนมดแดง':'อุบลราชธานี','ดินแดง':'กรุงเทพมหานคร','ตรััง':'ตรัง','ตราด\xa0':'ตราด','ตากใบ':'นราธิวาส','ต่างจังหวัด':'ไม่มีข้อมูล','ทุ่งเสลี่ยม':'สุโขทัย',
                                         'ท้ายบ้าน':'สมุทรปราการ','ธารโต':'ยะลา','นคนปฐม':'นครปฐม','นคปฐม':'นครปฐม','นครนปฐม':'นครปฐม','นครนาชสีมา':'นครราชสีมา','นครปฐม\xa0':'นครปฐม',
                                         'นครปบม':'นครปฐม','นครพนม\xa0':'นครพนม','นครยายก':'นครนายก','นครราขสีมา':'นครราชสีมา','นครราชธานี':'นครราชสีมา','นครราชศรีมา':'นครราชสีมา','นครราชสสีมา':'นครราชสีมา',
                                         'นครราชสีมา ลพบุรี':'นครราชสีมา','นครราชสีมา\xa0':'นครราชสีมา','นครศรธรรมราช':'นครศรีธรรมราช','นครศรี':'นครศรีธรรมราช','นครศรีธรมมราช':'นครศรีธรรมราช',
                                         'นครศรีธรมราช':'นครศรีธรรมราช','นครศรีธรรมราข':'นครศรีธรรมราช','นครศรีฯ':'นครศรีธรรมราช','นครศรีีธรรมราช':'นครศรีธรรมราช','นครศร๊ธรรมราช':'นครศรีธรรมราช',
                                         'นครศร๊ะรรมราช':'นครศรีธรรมราช','นครสรรค์':'นครสวรรค์','นครสรีธรรมราช':'นครศรีธรรมราช','นครสวรรค':'นครสวรรค์','นครสวรรค์\xa0':'นครสวรรค์','นครสีธรรมราช':'นครศรีธรรมราช',
                                         'นครฯ':'นครศรีธรรมราช','นคราชสีมา':'นครราชสีมา','นครีศรีธรรมราช':'นครศรีธรรมราช','นตรนายก':'นครนายก','นตรปฐม':'นครปฐม','นนทบุรี\xa0':'นนทบุรี',
                                         'นนทบุุรี':'นนทบุรี','นนทุบรี':'นนทบุรี','นนทุรี':'นนทบุรี','นนมบุรี':'นนทบุรี','นรศรีธรรมราช':'นครศรีธรรมราช','นราธิวาส\u200b':'นราธิวาส','นราธฺวาส':'นราธิวาส','นอกเขต':'ไม่มีข้อมูล',
                                         'นาราธิวาส':'นราธิวาส','นาวัง':'หนองบัวลำภู','น่าน/ฉะเชิงเทรา':'น่าน','บางกรวย':'นนทบุรี','บางกะปิ':'กรุงเทพมหานคร','บางนา':'กรุงเทพมหานคร','บางปะอิน':'กรุงเทพมหานคร',
                                         'บางละมุง':'ชลบุรี','บางศรีเมือง':'นนทบุรี','บางเพียง':'สมุทรปราการ','บึงโขงหลง':'บึงกาฬ','บุรีรัมภ์':'บุรีรัมย์','บุรีรัมย์\xa0':'บุรีรัมย์','บุรีรัยม์':'บุรีรัมย์','บุรีรีมย์':'บุรีรัมย์',
                                         'บ้านหลวง':'น่าน','ปจ':'ไม่มีข้อมูล','ปทึมธานี':'ปทุมธานี','ปทุทธานี':'ปทุมธานี','ปทุมฑานี':'ปทุมธานี','ปทุมทานี':'ปทุมธานี','ปทุมธาน':'ปทุมธานี','ปทุมธานี\xa0':'ปทุมธานี','ปทุมาธานี':'ปทุมธานี',
                                         'ปธุมธานี':'ปทุมธานี','ปทุมธานี.':'ปทุมธานี','ปทุมธานีี':'ปทุมธานี','ปทุุมธานี':'ปทุมธานี','ปมุมธานี':'ปทุมธานี',
                                         'ประจวนคีรีขันธ็':'ประจวบคีรีขันธ์','ประจวบ':'ประจวบคีรีขันธ์','ประจวบคิรีขันธ์':'ประจวบคีรีขันธ์','ประจวบคีรขันธ์':'ประจวบคีรีขันธ์','ประจวบคีรขัันธ์':'ประจวบคีรีขันธ์','ประจวบคีรีขัน':'ประจวบคีรีขันธ์',
                                         'ประจวบคีรีขันธื':'ประจวบคีรีขันธ์','ประจวบคีรีขันธฺ':'ประจวบคีรีขันธ์','ประจวบคีรีขันธ์\xa0':'ประจวบคีรีขันธ์','ประจวบคีรีขันธ์์':'ประจวบคีรีขันธ์','ประจวบคีรีขัันธ์':'ประจวบคีรีขันธ์','ประจวบคีีรีขันธ์':'ประจวบคีรีขันธ์',
                                         'ประจวบฯ':'ประจวบคีรีขันธ์','ประทุมธานี':'ปทุมธานี', 'ประเทศกัมพูชา':'ไม่มีข้อมูล','ปราจีบุรี':'ปราจีนบุรี','ปลวกแดง':'ระยอง','ปลายพระยา':'กระบี่', 'ปอยเปต':'ไม่มีข้อมูล','ปัตตนรี':'ปัตตานี',
                                         'ปัตตานนี':'ปัตตานี','ปัตตานีี':'ปัตตานี','ปัว':'น่าน','ปััตตานี':'ปัตตานี','ปุทมธานี':'ปทุมธานี','ป่าโมก':'อ่างทอง','พม่า':'ไม่มีข้อมูล','พรหมพิราม':'พิษณุโลก','พระนครศรียุธยา':'พระนครศรีอยุธยา',
                                         'พระนครศรีอยุทธยา':'พระนครศรีอยุธยา','พระนครศรีอยุทยา':'พระนครศรีอยุธยา','พระนครศรีอยุธยา\xa0':'พระนครศรีอยุธยา','พัทยา':'ชลบุรี','พัทลุุง':'พัทลุง','พัังงา':'พังงา',
                                         'พิษณุโลก\xa0':'พิษณุโลก','พิษณูโลก':'พิษณุโลก','ฟินแลนด์':'ไม่มีข้อมูล','ภาษีเจริญ':'กรุงเทพมหานคร','ภุเก็ต':'ภูเก็ต','ภูุเก็ต':'ภูเก็ต','ภููเก็ต':'ภูเก็ต','ภูเก็็ต':'ภูเก็ต','ภูเพียง':'น่าน',
                                         'มหาสาคาม':'มหาสารคาม','มาเลเซีย':'ไม่มีข้อมูล','มุกาดหาร':'มุกดาหาร','ยานนาวา':'กรุงเทพมหานคร','ร.จ.จ.นราธิวาส':'นราธิวาส','รอ':'ร้อยเอ็ด','ระบุ':'ไม่มีข้อมูล','ระยอง\xa0':'ระยอง',
                                         'ระอยง':'ระยอง','ราชบบุรี':'ราชบุรี','ราชบุรีี':'ราชบุรี','ราชบุรี\u200b':'ราชบุรี','ราชุรี':'ราชบุรี','ราชเทวี':'กรุงเทพมหานคร','ร้องกวาง':'แพร่','ลบุรี':'ลพบุรี','ลพบุรี.':'ลพบุรี','ลพบุรี\xa0':'ลพบุรี','ลอง':'แพร่',
                                         'ลาดกระบัง':'กรุงเทพมหานคร','ลาดพร้าว':'กรุงเทพมหานคร','ลาว':'ไม่มีข้อมูล','ลำพูน\u200b':'ลำพูน','ลำพููน':'ลำพูน','ลำลูกกา':'ปทุมธานี','วังชิ้น':'ลำปาง','วังทอง':'พิษณุโลก',
                                         'วิเศษชัยชาญ':'อ่างทอง','ศรีษะสะเกษ':'ศรีสะเกษ','ศรีษะเกษ':'ศรีสะเกษ','ศรีสระเกษ':'ศรีสะเกษ','ศีรสะเกษ':'ศรีสะเกษ','สครสวรรค์':'นครสวรรค์',
                                         'สงขลา\u200b':'สงขลา','สถานที่ทำงาน':'ไม่มีข้อมูล','สพรรณบุรี':'สุพรรณบุรี','สมถทรปราการ':'สมุทรปราการ','สมทรสงคราม':'สมุทรสงคราม','สมทรสาคร':'สมุทรสาคร','สมุครปราการ':'สมุทรปราการ',
                                         'สมุครสาคร':'สมุทรสาคร','สมุท':'ไม่มีข้อมูล','สมุทปราการ':'สมุทรปราการ','สมุทรปรากร':'สมุทรปราการ','สมุทรปรากรร':'สมุทรปราการ','สมุทรปราการ\xa0':'สมุทรปราการ','สมุทรศาคร':'สมุทรสาคร',
                                         'สมุทรสาคร\xa0':'สมุทรสาคร','สมุทรสาคา':'สมุทรสาคร','สมุทรสาคาร':'สมุทรสาคร','สมุทรสาทร':'สมุทรสาคร','สมุทรสารคร':'สมุทรสาคร','สมุทราปราการ':'สมุทรปราการ',
                                         'สมุทราสาคร':'สมุทรสาคร','สมุทสงคราม':'สมุทรสงคราม','สมุทสาคร':'สมุทรสาคร','สมุย':'สุราษฎร์ธานี','สมุุทรปราการ':'สมุทรปราการ','สมุุทรสงคราม':'สมุทรสงคราม','สมุุทรสาคร':'สมุทรสาคร',
                                         'สระก้ว':'สระแก้ว','สระบุรี\xa0':'สระบุรี','สรินทร์':'สุรินทร์','สวิสเซอร์แลนด์':'ไม่มีข้อมูล','สอง':'แพร่','สองแคว':'น่าน','สะพานสูง':'กรุงเทพมหานคร',
                                         'สะแก้ว':'สระแก้ว','สัตหีบ':'ชลบุรี','สัมผัสผู้ป่วยยืนยัน COVID20':'ไม่มีข้อมูล','สามุทรสาคร':'สมุทรสาคร','สารคาม':'มหาสารคาม','สารภี':'เชียงใหม่','สิงห์บุรี\xa0':'สิงห์บุรี',
                                         'สุทรปราการ':'สมุทรปราการ','สุพรรญบุรี':'สุพรรณบุรี','สุพรรณบุรั':'สุพรรณบุรี','สุพรรณบุรี\xa0':'สุพรรณบุรี','สุมทรปราการ':'สมุทรปราการ',
                                         'สุมทรสาคร':'สมุทรสาคร','สุมุทรปราการ':'สมุทรปราการ','สุมุทรสาคร':'สมุทรสาคร','สุระบุรี':'สระบุรี','สุราษ':'สุราษฎร์ธานี','สุราษฎณ์ธานี':'สุราษฎร์ธานี','สุราษฎธานี':'สุราษฎร์ธานี',
                                         'สุราษฎร์':'สุราษฎร์ธานี','สุราษฎร์ฯ':'สุราษฎร์ธานี','สุราษฎร์์ธานี':'สุราษฎร์ธานี','สุราษฎ์ธานี':'สุราษฎร์ธานี','สุราษฏร์ธานี':'สุราษฎร์ธานี','สุราษธานี':'สุราษฎร์ธานี',
                                         'สุราษร์ฎธานี':'สุราษฎร์ธานี','สุราษร์ธานี':'สุราษฎร์ธานี','สุราษฯ':'สุราษฎร์ธานี','สุรินทรื':'สุรินทร์','สุรินทร์ 32150':'สุรินทร์','สุรินทร์,รีสะเกษ':'สุรินทร์','สุรินทร์\xa0':'สุรินทร์','สุริมทร์':'สุรินทร์',
                                         'สุริะแก้ว':'สระแก้ว','สุวรรณภูมิ':'สมุทรปราการ','สุุพรรณบุรี':'สุพรรณบุรี','สุุราษฎร์ธานี':'สุราษฎร์ธานี','สุุราษฏร์ธานี':'สุราษฎร์ธนี','สุุราษฯ':'สุราษฎร์ธนี','สุุรินทร์':'สุรินทร์',
                                         'สุุุโขทัย':'สุโขทัย','สุโขทับ':'สุโขทัย','สุโขทัย\xa0':'สุโขทัย','สูงเม่น':'แพร่','หนวงบัวลำภู':'หนองบัวลำภู','หนองงคาย':'หนองคาย','หนองบัวภู':'หนองบัวลำภู',
                                         'หนองบัวลำพูน':'หนองบัวลำภู','หนองบัวลําภู':'หนองบัวลำภู','หนองบััวลำภู':'หนองบัวลำภู','หนองม่วงไข่':'แพร่','หนอบัวลำภู':'หนองบัวลำภู','หลายจังหวัด':'ไม่มีข้อมูล','หัวหิน':'ประจวบคีรีขันธ์',
                                         'ห้วยขวาง':'กรุงเทพมหานคร','อยุทธยา':'พระนครศรีอยุธยา','อยุธยา':'พระนครศรีอยุธยา','อยุุธยา':'พระนครศรีอยุธยา','อำนาจเจิญ':'อำนาจเจริญ','อำนาญเจริญ':'อำนาจเจริญ','อำนาเจริญ':'อำนาจเจริญ',
                                         'อิสราเอล':'ไม่มีข้อมูล','อุดธานี':'อุดรธานี','อุดร':'อุดรธานี','อุดรธาณี':'อุดรธานี','อุดรธานี\xa0':'อุดรธานี','อุดรธานีี':'อุดรธานี','อุดรราชธานี':'อุดรธานี','อุตรดิตถ์\xa0':'อุตรดิตถ์',
                                         'อุตรดิตถ์์':'อุตรดิตถ์','อุตรดิษถ์':'อุตรดิตถ์','อุตรดิิตถ์':'อุตรดิตถ์','อุตรติดถ์':'อุตรดิตถ์','อุบลราขธานี':'อุบลราชธานี','อุบลราชธานี\xa0':'อุบลราชธานี','อุุครดิตถ์':'อุตรดิตถ์',
                                         'อุุดรธาน':'อุดรธานี','อุุดรธานี':'อุดรธานี','อุุตรดิตถ์':'อุตรดิตถ์','อุุทัยธานี':'อุทัยธานี','อุุบลราชธานี':'อุบลราชธานี','อ่งทอง':'อ่างทอง','อ่างทอง\xa0':'อ่างทอง','อํานาจเจริญ':'อำนาจเจริญ',
                                         'เชิงเทรา':'ฉะเชิงเทรา','เชียรใหญ่':'นครศรีธรรมราช','เชีียงราย':'เชียงราย','เชีียงใหม่':'เชียงใหม่','เด่นชัย':'แพร่',
                                         'เพขรบุรี':'เพชรบูรณ์','เพขรบูรณื':'เพชรบูรณ์','เพขรบูรณ์':'เพชรบูรณ์','เพชรบุรณ์':'เพชรบูรณ์','เพชรบุรี':'เพชรบูรณ์','เพชรบุรึ':'เพชรบูรณ์','เพชรบุุรี':'เพชรบูรณ์','เพชรบุูรณ์':'เพชรบูรณ์','เพชรบูรณ์\xa0':'เพชรบูรณ์',
                                         'เพชรบูร์':'เพชรบูรณ์','เพชรบููรณ์':'เพชรบูรณ์','เมือง':'แพร่','เมืองตาก':'ตาก','เมืองน่าน':'น่าน','เมืองปัตตานี':'ปัตตานี','เรือ':'เลย','เลย\xa0':'เลย','เวียงจันทร์':'ไม่มีข้อมูล','เวียงสา':'น่าน','แม่ทะ':'ลำปาง',
                                         'แล้วป่วย':'ไม่มีข้อมูล','โพธิ์ทอง':'อ่างทอง','ไชโย':'อ่างทอง','ไม่มีข้อมูล':'ไม่มีข้อมูล','ไม่มีชื่อหอพัก':'ไม่มีข้อมูล','ไม่ระบุ':'ไม่มีข้อมูล','สมุทรปรากา':'สมุทรปราการ'}, inplace=True)# แก้ไขข้อมูลที่พิมพ์จังหวัดผิด ให้อยู่ในชื่อจังหวัดที่ถูกต้อง
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
data_02['province_of_onset'].replace({'USA':'ไม่มีข้อมูล','\tประจวบคีรีขันธ์':'ประจวบคีรีขันธ์','\xa0กาญจนบุรี':'กาญจนบุรี','\xa0ชลบุรี':'ชลบุรี','\xa0ตราด':'ตราด','\xa0นครปฐม':'นครปฐม',
                                         '\xa0สมุทรสงคราม':'สมุทรสงคราม','\xa0สมุทรสาคร':'สมุทรสาคร','\xa0อุทัยธานี':'อุทัยธานี','กทม':'กรุงเทพมหานคร','กทม.':'กรุงเทพมหานคร','กบินทร์บุรี':'ปราจีนบุรี','กระบี่ี่':'กระบี่','กรุงเทพ':'กรุงเทพมหานคร',
                                         'กรุงเทพมหานคร.':'กรุงเทพมหานคร','กรุงเทพมหานคร. / พระนครศรีอยุธยา':'กรุงเทพมหานคร','กรุงเทพมหานคร. / ศรีสะเกษ':'กรุงเทพมหานคร','กรุงเทพฯ':'กรุงเทพมหานคร','กะทู้':'ภูเก็ต',
                                         'กัมพูชา':'ไม่มีข้อมูล','กาญจบุรี':'กาญจนบุรี','กาญนบุรี':'กาญจนบุรี','กาฬสิน':'กาฬสินธุ์','กาฬสินธิ์':'กาฬสินธุ์','กาฬสินธุ์\xa0':'กาฬสินธุ์','กาฬสินธ์':'กาฬสินธุ์',
                                         'กำเพงเพชร':'กำแพงเพชร','กำแพง':'กำแพงเพชร','กำแพงเพชร':'กำแพงเพชร','กำแพงเพชร\xa0':'กำแพงเพชร','กําแพงเพชร':'กำแพงเพชร',
                                         'ขอนแก่น\xa0':'ขอนแก่น','ขอนแก่่น':'ขอนแก่น','ขานุวรลักษณ์บุรี':'กำแพงเพชร','คนไทยเดินทางกลับจากต่างประเทศ':'ไม่มีข้อมูล','คลองเตย':'กรุงเทพมหานคร','จ.กรุงเทพมหานคร':'กรุงเทพมหานคร',
                                         'จ.ภูเก็ต':'ภูเก็ต','จ.ราชบุรี':'ราชบุรี','จ.สุราษฎร์ธานี':'สุราษฎร์ธานี','จังหวัดสมุทรสาคร':'สมุทรสาคร','ฉะเชองเทราร':'ฉะเชิงเทรา','ชมพร':'ชุมพร',
                                         'ชลบุรี\t':'ชลบุรี','ชลบุรี\xa0':'ชลบุรี','ชลบุุรี':'ชลบุรี','ชอนแก่น':'ขอนแก่น','ชัยนาถ':'ชัยนาท','ชัยบาดาล':'ลพบุรี','ชัยภูมิ\xa0':'ชัยภูมิ','ชุุมพร':'ชุมพร','ชุุุมพร':'ชุมพร',
                                         'ดอนมดแดง':'อุบลราชธานี','ดินแดง':'กรุงเทพมหานคร','ตรััง':'ตรัง','ตราด\xa0':'ตราด','ตากใบ':'นราธิวาส','ต่างจังหวัด':'ไม่มีข้อมูล','ทุ่งเสลี่ยม':'สุโขทัย',
                                         'ท้ายบ้าน':'สมุทรปราการ','ธารโต':'ยะลา','นคนปฐม':'นครปฐม','นคปฐม':'นครปฐม','นครนปฐม':'นครปฐม','นครนาชสีมา':'นครราชสีมา','นครปฐม\xa0':'นครปฐม',
                                         'นครปบม':'นครปฐม','นครพนม\xa0':'นครพนม','นครยายก':'นครนายก','นครราขสีมา':'นครราชสีมา','นครราชธานี':'นครราชสีมา','นครราชศรีมา':'นครราชสีมา','นครราชสสีมา':'นครราชสีมา',
                                         'นครราชสีมา ลพบุรี':'นครราชสีมา','นครราชสีมา\xa0':'นครราชสีมา','นครศรธรรมราช':'นครศรีธรรมราช','นครศรี':'นครศรีธรรมราช','นครศรีธรมมราช':'นครศรีธรรมราช',
                                         'นครศรีธรมราช':'นครศรีธรรมราช','นครศรีธรรมราข':'นครศรีธรรมราช','นครศรีฯ':'นครศรีธรรมราช','นครศรีีธรรมราช':'นครศรีธรรมราช','นครศร๊ธรรมราช':'นครศรีธรรมราช',
                                         'นครศร๊ะรรมราช':'นครศรีธรรมราช','นครสรรค์':'นครสวรรค์','นครสรีธรรมราช':'นครศรีธรรมราช','นครสวรรค':'นครสวรรค์','นครสวรรค์\xa0':'นครสวรรค์','นครสีธรรมราช':'นครศรีธรรมราช',
                                         'นครฯ':'นครศรีธรรมราช','นคราชสีมา':'นครราชสีมา','นครีศรีธรรมราช':'นครศรีธรรมราช','นตรนายก':'นครนายก','นตรปฐม':'นครปฐม','นนทบุรี\xa0':'นนทบุรี',
                                         'นนทบุุรี':'นนทบุรี','นนทุบรี':'นนทบุรี','นนทุรี':'นนทบุรี','นนมบุรี':'นนทบุรี','นรศรีธรรมราช':'นครศรีธรรมราช','นราธิวาส\u200b':'นราธิวาส','นราธฺวาส':'นราธิวาส','นอกเขต':'ไม่มีข้อมูล',
                                         'นาราธิวาส':'นราธิวาส','นาวัง':'หนองบัวลำภู','น่าน/ฉะเชิงเทรา':'น่าน','บางกรวย':'นนทบุรี','บางกะปิ':'กรุงเทพมหานคร','บางนา':'กรุงเทพมหานคร','บางปะอิน':'กรุงเทพมหานคร',
                                         'บางละมุง':'ชลบุรี','บางศรีเมือง':'นนทบุรี','บางเพียง':'สมุทรปราการ','บึงโขงหลง':'บึงกาฬ','บุรีรัมภ์':'บุรีรัมย์','บุรีรัมย์\xa0':'บุรีรัมย์','บุรีรัยม์':'บุรีรัมย์','บุรีรีมย์':'บุรีรัมย์',
                                         'บ้านหลวง':'น่าน','ปจ':'ไม่มีข้อมูล','ปทึมธานี':'ปทุมธานี','ปทุทธานี':'ปทุมธานี','ปทุมฑานี':'ปทุมธานี','ปทุมทานี':'ปทุมธานี','ปทุมธาน':'ปทุมธานี','ปทุมธานี\xa0':'ปทุมธานี','ปทุมาธานี':'ปทุมธานี',
                                         'ปธุมธานี':'ปทุมธานี','ปทุมธานี.':'ปทุมธานี','ปทุมธานีี':'ปทุมธานี','ปทุุมธานี':'ปทุมธานี','ปมุมธานี':'ปทุมธานี',
                                         'ประจวนคีรีขันธ็':'ประจวบคีรีขันธ์','ประจวบ':'ประจวบคีรีขันธ์','ประจวบคิรีขันธ์':'ประจวบคีรีขันธ์','ประจวบคีรขันธ์':'ประจวบคีรีขันธ์','ประจวบคีรขัันธ์':'ประจวบคีรีขันธ์','ประจวบคีรีขัน':'ประจวบคีรีขันธ์',
                                         'ประจวบคีรีขันธื':'ประจวบคีรีขันธ์','ประจวบคีรีขันธฺ':'ประจวบคีรีขันธ์','ประจวบคีรีขันธ์\xa0':'ประจวบคีรีขันธ์','ประจวบคีรีขันธ์์':'ประจวบคีรีขันธ์','ประจวบคีรีขัันธ์':'ประจวบคีรีขันธ์','ประจวบคีีรีขันธ์':'ประจวบคีรีขันธ์',
                                         'ประจวบฯ':'ประจวบคีรีขันธ์','ประทุมธานี':'ปทุมธานี', 'ประเทศกัมพูชา':'ไม่มีข้อมูล','ปราจีบุรี':'ปราจีนบุรี','ปลวกแดง':'ระยอง','ปลายพระยา':'กระบี่', 'ปอยเปต':'ไม่มีข้อมูล','ปัตตนรี':'ปัตตานี',
                                         'ปัตตานนี':'ปัตตานี','ปัตตานีี':'ปัตตานี','ปัว':'น่าน','ปััตตานี':'ปัตตานี','ปุทมธานี':'ปทุมธานี','ป่าโมก':'อ่างทอง','พม่า':'ไม่มีข้อมูล','พรหมพิราม':'พิษณุโลก','พระนครศรียุธยา':'พระนครศรีอยุธยา',
                                         'พระนครศรีอยุทธยา':'พระนครศรีอยุธยา','พระนครศรีอยุทยา':'พระนครศรีอยุธยา','พระนครศรีอยุธยา\xa0':'พระนครศรีอยุธยา','พัทยา':'ชลบุรี','พัทลุุง':'พัทลุง','พัังงา':'พังงา',
                                         'พิษณุโลก\xa0':'พิษณุโลก','พิษณูโลก':'พิษณุโลก','ฟินแลนด์':'ไม่มีข้อมูล','ภาษีเจริญ':'กรุงเทพมหานคร','ภุเก็ต':'ภูเก็ต','ภูุเก็ต':'ภูเก็ต','ภููเก็ต':'ภูเก็ต','ภูเก็็ต':'ภูเก็ต','ภูเพียง':'น่าน',
                                         'มหาสาคาม':'มหาสารคาม','มาเลเซีย':'ไม่มีข้อมูล','มุกาดหาร':'มุกดาหาร','ยานนาวา':'กรุงเทพมหานคร','ร.จ.จ.นราธิวาส':'นราธิวาส','รอ':'ร้อยเอ็ด','ระบุ':'ไม่มีข้อมูล','ระยอง\xa0':'ระยอง',
                                         'ระอยง':'ระยอง','ราชบบุรี':'ราชบุรี','ราชบุรีี':'ราชบุรี','ราชบุรี\u200b':'ราชบุรี','ราชุรี':'ราชบุรี','ราชเทวี':'กรุงเทพมหานคร','ร้องกวาง':'แพร่','ลบุรี':'ลพบุรี','ลพบุรี.':'ลพบุรี','ลพบุรี\xa0':'ลพบุรี','ลอง':'แพร่',
                                         'ลาดกระบัง':'กรุงเทพมหานคร','ลาดพร้าว':'กรุงเทพมหานคร','ลาว':'ไม่มีข้อมูล','ลำพูน\u200b':'ลำพูน','ลำพููน':'ลำพูน','ลำลูกกา':'ปทุมธานี','วังชิ้น':'ลำปาง','วังทอง':'พิษณุโลก',
                                         'วิเศษชัยชาญ':'อ่างทอง','ศรีษะสะเกษ':'ศรีสะเกษ','ศรีษะเกษ':'ศรีสะเกษ','ศรีสระเกษ':'ศรีสะเกษ','ศีรสะเกษ':'ศรีสะเกษ','สครสวรรค์':'นครสวรรค์',
                                         'สงขลา\u200b':'สงขลา','สถานที่ทำงาน':'ไม่มีข้อมูล','สพรรณบุรี':'สุพรรณบุรี','สมถทรปราการ':'สมุทรปราการ','สมทรสงคราม':'สมุทรสงคราม','สมทรสาคร':'สมุทรสาคร','สมุครปราการ':'สมุทรปราการ',
                                         'สมุครสาคร':'สมุทรสาคร','สมุท':'ไม่มีข้อมูล','สมุทปราการ':'สมุทรปราการ','สมุทรปรากร':'สมุทรปราการ','สมุทรปรากรร':'สมุทรปราการ','สมุทรปราการ\xa0':'สมุทรปราการ','สมุทรศาคร':'สมุทรสาคร',
                                         'สมุทรสาคร\xa0':'สมุทรสาคร','สมุทรสาคา':'สมุทรสาคร','สมุทรสาคาร':'สมุทรสาคร','สมุทรสาทร':'สมุทรสาคร','สมุทรสารคร':'สมุทรสาคร','สมุทราปราการ':'สมุทรปราการ',
                                         'สมุทราสาคร':'สมุทรสาคร','สมุทสงคราม':'สมุทรสงคราม','สมุทสาคร':'สมุทรสาคร','สมุย':'สุราษฎร์ธานี','สมุุทรปราการ':'สมุทรปราการ','สมุุทรสงคราม':'สมุทรสงคราม','สมุุทรสาคร':'สมุทรสาคร',
                                         'สระก้ว':'สระแก้ว','สระบุรี\xa0':'สระบุรี','สรินทร์':'สุรินทร์','สวิสเซอร์แลนด์':'ไม่มีข้อมูล','สอง':'แพร่','สองแคว':'น่าน','สะพานสูง':'กรุงเทพมหานคร',
                                         'สะแก้ว':'สระแก้ว','สัตหีบ':'ชลบุรี','สัมผัสผู้ป่วยยืนยัน COVID20':'ไม่มีข้อมูล','สามุทรสาคร':'สมุทรสาคร','สารคาม':'มหาสารคาม','สารภี':'เชียงใหม่','สิงห์บุรี\xa0':'สิงห์บุรี',
                                         'สุทรปราการ':'สมุทรปราการ','สุพรรญบุรี':'สุพรรณบุรี','สุพรรณบุรั':'สุพรรณบุรี','สุพรรณบุรี\xa0':'สุพรรณบุรี','สุมทรปราการ':'สมุทรปราการ',
                                         'สุมทรสาคร':'สมุทรสาคร','สุมุทรปราการ':'สมุทรปราการ','สุมุทรสาคร':'สมุทรสาคร','สุระบุรี':'สระบุรี','สุราษ':'สุราษฎร์ธานี','สุราษฎณ์ธานี':'สุราษฎร์ธานี','สุราษฎธานี':'สุราษฎร์ธานี',
                                         'สุราษฎร์':'สุราษฎร์ธานี','สุราษฎร์ฯ':'สุราษฎร์ธานี','สุราษฎร์์ธานี':'สุราษฎร์ธานี','สุราษฎ์ธานี':'สุราษฎร์ธานี','สุราษฏร์ธานี':'สุราษฎร์ธานี','สุราษธานี':'สุราษฎร์ธานี',
                                         'สุราษร์ฎธานี':'สุราษฎร์ธานี','สุราษร์ธานี':'สุราษฎร์ธานี','สุราษฯ':'สุราษฎร์ธานี','สุรินทรื':'สุรินทร์','สุรินทร์ 32150':'สุรินทร์','สุรินทร์,รีสะเกษ':'สุรินทร์','สุรินทร์\xa0':'สุรินทร์','สุริมทร์':'สุรินทร์',
                                         'สุริะแก้ว':'สระแก้ว','สุวรรณภูมิ':'สมุทรปราการ','สุุพรรณบุรี':'สุพรรณบุรี','สุุราษฎร์ธานี':'สุราษฎร์ธานี','สุุราษฏร์ธานี':'สุราษฎร์ธนี','สุุราษฯ':'สุราษฎร์ธนี','สุุรินทร์':'สุรินทร์',
                                         'สุุุโขทัย':'สุโขทัย','สุโขทับ':'สุโขทัย','สุโขทัย\xa0':'สุโขทัย','สูงเม่น':'แพร่','หนวงบัวลำภู':'หนองบัวลำภู','หนองงคาย':'หนองคาย','หนองบัวภู':'หนองบัวลำภู',
                                         'หนองบัวลำพูน':'หนองบัวลำภู','หนองบัวลําภู':'หนองบัวลำภู','หนองบััวลำภู':'หนองบัวลำภู','หนองม่วงไข่':'แพร่','หนอบัวลำภู':'หนองบัวลำภู','หลายจังหวัด':'ไม่มีข้อมูล','หัวหิน':'ประจวบคีรีขันธ์',
                                         'ห้วยขวาง':'กรุงเทพมหานคร','อยุทธยา':'พระนครศรีอยุธยา','อยุธยา':'พระนครศรีอยุธยา','อยุุธยา':'พระนครศรีอยุธยา','อำนาจเจิญ':'อำนาจเจริญ','อำนาญเจริญ':'อำนาจเจริญ','อำนาเจริญ':'อำนาจเจริญ',
                                         'อิสราเอล':'ไม่มีข้อมูล','อุดธานี':'อุดรธานี','อุดร':'อุดรธานี','อุดรธาณี':'อุดรธานี','อุดรธานี\xa0':'อุดรธานี','อุดรธานีี':'อุดรธานี','อุดรราชธานี':'อุดรธานี','อุตรดิตถ์\xa0':'อุตรดิตถ์',
                                         'อุตรดิตถ์์':'อุตรดิตถ์','อุตรดิษถ์':'อุตรดิตถ์','อุตรดิิตถ์':'อุตรดิตถ์','อุตรติดถ์':'อุตรดิตถ์','อุบลราขธานี':'อุบลราชธานี','อุบลราชธานี\xa0':'อุบลราชธานี','อุุครดิตถ์':'อุตรดิตถ์',
                                         'อุุดรธาน':'อุดรธานี','อุุดรธานี':'อุดรธานี','อุุตรดิตถ์':'อุตรดิตถ์','อุุทัยธานี':'อุทัยธานี','อุุบลราชธานี':'อุบลราชธานี','อ่งทอง':'อ่างทอง','อ่างทอง\xa0':'อ่างทอง','อํานาจเจริญ':'อำนาจเจริญ',
                                         'เชิงเทรา':'ฉะเชิงเทรา','เชียรใหญ่':'นครศรีธรรมราช','เชีียงราย':'เชียงราย','เชีียงใหม่':'เชียงใหม่','เด่นชัย':'แพร่',
                                         'เพขรบุรี':'เพชรบูรณ์','เพขรบูรณื':'เพชรบูรณ์','เพขรบูรณ์':'เพชรบูรณ์','เพชรบุรณ์':'เพชรบูรณ์','เพชรบุรี':'เพชรบูรณ์','เพชรบุรึ':'เพชรบูรณ์','เพชรบุุรี':'เพชรบูรณ์','เพชรบุูรณ์':'เพชรบูรณ์','เพชรบูรณ์\xa0':'เพชรบูรณ์',
                                         'เพชรบูร์':'เพชรบูรณ์','เพชรบููรณ์':'เพชรบูรณ์','เมือง':'แพร่','เมืองตาก':'ตาก','เมืองน่าน':'น่าน','เมืองปัตตานี':'ปัตตานี','เรือ':'เลย','เลย\xa0':'เลย','เวียงจันทร์':'ไม่มีข้อมูล','เวียงสา':'น่าน','แม่ทะ':'ลำปาง',
                                         'แล้วป่วย':'ไม่มีข้อมูล','โพธิ์ทอง':'อ่างทอง','ไชโย':'อ่างทอง','ไม่มีข้อมูล':'ไม่มีข้อมูล','ไม่มีชื่อหอพัก':'ไม่มีข้อมูล','ไม่ระบุ':'ไม่มีข้อมูล','สมุทรปรากา':'สมุทรปราการ'}, inplace=True)# แก้ไขข้อมูลที่พิมพ์จังหวัดผิด ให้อยู่ในชื่อจังหวัดที่ถูกต้อง
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
data_03['province_of_onset'].replace({'USA':'ไม่มีข้อมูล','\tประจวบคีรีขันธ์':'ประจวบคีรีขันธ์','\xa0กาญจนบุรี':'กาญจนบุรี','\xa0ชลบุรี':'ชลบุรี','\xa0ตราด':'ตราด','\xa0นครปฐม':'นครปฐม',
                                         '\xa0สมุทรสงคราม':'สมุทรสงคราม','\xa0สมุทรสาคร':'สมุทรสาคร','\xa0อุทัยธานี':'อุทัยธานี','กทม':'กรุงเทพมหานคร','กทม.':'กรุงเทพมหานคร','กบินทร์บุรี':'ปราจีนบุรี','กระบี่ี่':'กระบี่','กรุงเทพ':'กรุงเทพมหานคร',
                                         'กรุงเทพมหานคร.':'กรุงเทพมหานคร','กรุงเทพมหานคร. / พระนครศรีอยุธยา':'กรุงเทพมหานคร','กรุงเทพมหานคร. / ศรีสะเกษ':'กรุงเทพมหานคร','กรุงเทพฯ':'กรุงเทพมหานคร','กะทู้':'ภูเก็ต',
                                         'กัมพูชา':'ไม่มีข้อมูล','กาญจบุรี':'กาญจนบุรี','กาญนบุรี':'กาญจนบุรี','กาฬสิน':'กาฬสินธุ์','กาฬสินธิ์':'กาฬสินธุ์','กาฬสินธุ์\xa0':'กาฬสินธุ์','กาฬสินธ์':'กาฬสินธุ์',
                                         'กำเพงเพชร':'กำแพงเพชร','กำแพง':'กำแพงเพชร','กำแพงเพชร':'กำแพงเพชร','กำแพงเพชร\xa0':'กำแพงเพชร','กําแพงเพชร':'กำแพงเพชร',
                                         'ขอนแก่น\xa0':'ขอนแก่น','ขอนแก่่น':'ขอนแก่น','ขานุวรลักษณ์บุรี':'กำแพงเพชร','คนไทยเดินทางกลับจากต่างประเทศ':'ไม่มีข้อมูล','คลองเตย':'กรุงเทพมหานคร','จ.กรุงเทพมหานคร':'กรุงเทพมหานคร',
                                         'จ.ภูเก็ต':'ภูเก็ต','จ.ราชบุรี':'ราชบุรี','จ.สุราษฎร์ธานี':'สุราษฎร์ธานี','จังหวัดสมุทรสาคร':'สมุทรสาคร','ฉะเชองเทราร':'ฉะเชิงเทรา','ชมพร':'ชุมพร',
                                         'ชลบุรี\t':'ชลบุรี','ชลบุรี\xa0':'ชลบุรี','ชลบุุรี':'ชลบุรี','ชอนแก่น':'ขอนแก่น','ชัยนาถ':'ชัยนาท','ชัยบาดาล':'ลพบุรี','ชัยภูมิ\xa0':'ชัยภูมิ','ชุุมพร':'ชุมพร','ชุุุมพร':'ชุมพร',
                                         'ดอนมดแดง':'อุบลราชธานี','ดินแดง':'กรุงเทพมหานคร','ตรััง':'ตรัง','ตราด\xa0':'ตราด','ตากใบ':'นราธิวาส','ต่างจังหวัด':'ไม่มีข้อมูล','ทุ่งเสลี่ยม':'สุโขทัย',
                                         'ท้ายบ้าน':'สมุทรปราการ','ธารโต':'ยะลา','นคนปฐม':'นครปฐม','นคปฐม':'นครปฐม','นครนปฐม':'นครปฐม','นครนาชสีมา':'นครราชสีมา','นครปฐม\xa0':'นครปฐม',
                                         'นครปบม':'นครปฐม','นครพนม\xa0':'นครพนม','นครยายก':'นครนายก','นครราขสีมา':'นครราชสีมา','นครราชธานี':'นครราชสีมา','นครราชศรีมา':'นครราชสีมา','นครราชสสีมา':'นครราชสีมา',
                                         'นครราชสีมา ลพบุรี':'นครราชสีมา','นครราชสีมา\xa0':'นครราชสีมา','นครศรธรรมราช':'นครศรีธรรมราช','นครศรี':'นครศรีธรรมราช','นครศรีธรมมราช':'นครศรีธรรมราช',
                                         'นครศรีธรมราช':'นครศรีธรรมราช','นครศรีธรรมราข':'นครศรีธรรมราช','นครศรีฯ':'นครศรีธรรมราช','นครศรีีธรรมราช':'นครศรีธรรมราช','นครศร๊ธรรมราช':'นครศรีธรรมราช',
                                         'นครศร๊ะรรมราช':'นครศรีธรรมราช','นครสรรค์':'นครสวรรค์','นครสรีธรรมราช':'นครศรีธรรมราช','นครสวรรค':'นครสวรรค์','นครสวรรค์\xa0':'นครสวรรค์','นครสีธรรมราช':'นครศรีธรรมราช',
                                         'นครฯ':'นครศรีธรรมราช','นคราชสีมา':'นครราชสีมา','นครีศรีธรรมราช':'นครศรีธรรมราช','นตรนายก':'นครนายก','นตรปฐม':'นครปฐม','นนทบุรี\xa0':'นนทบุรี',
                                         'นนทบุุรี':'นนทบุรี','นนทุบรี':'นนทบุรี','นนทุรี':'นนทบุรี','นนมบุรี':'นนทบุรี','นรศรีธรรมราช':'นครศรีธรรมราช','นราธิวาส\u200b':'นราธิวาส','นราธฺวาส':'นราธิวาส','นอกเขต':'ไม่มีข้อมูล',
                                         'นาราธิวาส':'นราธิวาส','นาวัง':'หนองบัวลำภู','น่าน/ฉะเชิงเทรา':'น่าน','บางกรวย':'นนทบุรี','บางกะปิ':'กรุงเทพมหานคร','บางนา':'กรุงเทพมหานคร','บางปะอิน':'กรุงเทพมหานคร',
                                         'บางละมุง':'ชลบุรี','บางศรีเมือง':'นนทบุรี','บางเพียง':'สมุทรปราการ','บึงโขงหลง':'บึงกาฬ','บุรีรัมภ์':'บุรีรัมย์','บุรีรัมย์\xa0':'บุรีรัมย์','บุรีรัยม์':'บุรีรัมย์','บุรีรีมย์':'บุรีรัมย์',
                                         'บ้านหลวง':'น่าน','ปจ':'ไม่มีข้อมูล','ปทึมธานี':'ปทุมธานี','ปทุทธานี':'ปทุมธานี','ปทุมฑานี':'ปทุมธานี','ปทุมทานี':'ปทุมธานี','ปทุมธาน':'ปทุมธานี','ปทุมธานี\xa0':'ปทุมธานี','ปทุมาธานี':'ปทุมธานี',
                                         'ปธุมธานี':'ปทุมธานี','ปทุมธานี.':'ปทุมธานี','ปทุมธานีี':'ปทุมธานี','ปทุุมธานี':'ปทุมธานี','ปมุมธานี':'ปทุมธานี',
                                         'ประจวนคีรีขันธ็':'ประจวบคีรีขันธ์','ประจวบ':'ประจวบคีรีขันธ์','ประจวบคิรีขันธ์':'ประจวบคีรีขันธ์','ประจวบคีรขันธ์':'ประจวบคีรีขันธ์','ประจวบคีรขัันธ์':'ประจวบคีรีขันธ์','ประจวบคีรีขัน':'ประจวบคีรีขันธ์',
                                         'ประจวบคีรีขันธื':'ประจวบคีรีขันธ์','ประจวบคีรีขันธฺ':'ประจวบคีรีขันธ์','ประจวบคีรีขันธ์\xa0':'ประจวบคีรีขันธ์','ประจวบคีรีขันธ์์':'ประจวบคีรีขันธ์','ประจวบคีรีขัันธ์':'ประจวบคีรีขันธ์','ประจวบคีีรีขันธ์':'ประจวบคีรีขันธ์',
                                         'ประจวบฯ':'ประจวบคีรีขันธ์','ประทุมธานี':'ปทุมธานี', 'ประเทศกัมพูชา':'ไม่มีข้อมูล','ปราจีบุรี':'ปราจีนบุรี','ปลวกแดง':'ระยอง','ปลายพระยา':'กระบี่', 'ปอยเปต':'ไม่มีข้อมูล','ปัตตนรี':'ปัตตานี',
                                         'ปัตตานนี':'ปัตตานี','ปัตตานีี':'ปัตตานี','ปัว':'น่าน','ปััตตานี':'ปัตตานี','ปุทมธานี':'ปทุมธานี','ป่าโมก':'อ่างทอง','พม่า':'ไม่มีข้อมูล','พรหมพิราม':'พิษณุโลก','พระนครศรียุธยา':'พระนครศรีอยุธยา',
                                         'พระนครศรีอยุทธยา':'พระนครศรีอยุธยา','พระนครศรีอยุทยา':'พระนครศรีอยุธยา','พระนครศรีอยุธยา\xa0':'พระนครศรีอยุธยา','พัทยา':'ชลบุรี','พัทลุุง':'พัทลุง','พัังงา':'พังงา',
                                         'พิษณุโลก\xa0':'พิษณุโลก','พิษณูโลก':'พิษณุโลก','ฟินแลนด์':'ไม่มีข้อมูล','ภาษีเจริญ':'กรุงเทพมหานคร','ภุเก็ต':'ภูเก็ต','ภูุเก็ต':'ภูเก็ต','ภููเก็ต':'ภูเก็ต','ภูเก็็ต':'ภูเก็ต','ภูเพียง':'น่าน',
                                         'มหาสาคาม':'มหาสารคาม','มาเลเซีย':'ไม่มีข้อมูล','มุกาดหาร':'มุกดาหาร','ยานนาวา':'กรุงเทพมหานคร','ร.จ.จ.นราธิวาส':'นราธิวาส','รอ':'ร้อยเอ็ด','ระบุ':'ไม่มีข้อมูล','ระยอง\xa0':'ระยอง',
                                         'ระอยง':'ระยอง','ราชบบุรี':'ราชบุรี','ราชบุรีี':'ราชบุรี','ราชบุรี\u200b':'ราชบุรี','ราชุรี':'ราชบุรี','ราชเทวี':'กรุงเทพมหานคร','ร้องกวาง':'แพร่','ลบุรี':'ลพบุรี','ลพบุรี.':'ลพบุรี','ลพบุรี\xa0':'ลพบุรี','ลอง':'แพร่',
                                         'ลาดกระบัง':'กรุงเทพมหานคร','ลาดพร้าว':'กรุงเทพมหานคร','ลาว':'ไม่มีข้อมูล','ลำพูน\u200b':'ลำพูน','ลำพููน':'ลำพูน','ลำลูกกา':'ปทุมธานี','วังชิ้น':'ลำปาง','วังทอง':'พิษณุโลก',
                                         'วิเศษชัยชาญ':'อ่างทอง','ศรีษะสะเกษ':'ศรีสะเกษ','ศรีษะเกษ':'ศรีสะเกษ','ศรีสระเกษ':'ศรีสะเกษ','ศีรสะเกษ':'ศรีสะเกษ','สครสวรรค์':'นครสวรรค์',
                                         'สงขลา\u200b':'สงขลา','สถานที่ทำงาน':'ไม่มีข้อมูล','สพรรณบุรี':'สุพรรณบุรี','สมถทรปราการ':'สมุทรปราการ','สมทรสงคราม':'สมุทรสงคราม','สมทรสาคร':'สมุทรสาคร','สมุครปราการ':'สมุทรปราการ',
                                         'สมุครสาคร':'สมุทรสาคร','สมุท':'ไม่มีข้อมูล','สมุทปราการ':'สมุทรปราการ','สมุทรปรากร':'สมุทรปราการ','สมุทรปรากรร':'สมุทรปราการ','สมุทรปราการ\xa0':'สมุทรปราการ','สมุทรศาคร':'สมุทรสาคร',
                                         'สมุทรสาคร\xa0':'สมุทรสาคร','สมุทรสาคา':'สมุทรสาคร','สมุทรสาคาร':'สมุทรสาคร','สมุทรสาทร':'สมุทรสาคร','สมุทรสารคร':'สมุทรสาคร','สมุทราปราการ':'สมุทรปราการ',
                                         'สมุทราสาคร':'สมุทรสาคร','สมุทสงคราม':'สมุทรสงคราม','สมุทสาคร':'สมุทรสาคร','สมุย':'สุราษฎร์ธานี','สมุุทรปราการ':'สมุทรปราการ','สมุุทรสงคราม':'สมุทรสงคราม','สมุุทรสาคร':'สมุทรสาคร',
                                         'สระก้ว':'สระแก้ว','สระบุรี\xa0':'สระบุรี','สรินทร์':'สุรินทร์','สวิสเซอร์แลนด์':'ไม่มีข้อมูล','สอง':'แพร่','สองแคว':'น่าน','สะพานสูง':'กรุงเทพมหานคร',
                                         'สะแก้ว':'สระแก้ว','สัตหีบ':'ชลบุรี','สัมผัสผู้ป่วยยืนยัน COVID20':'ไม่มีข้อมูล','สามุทรสาคร':'สมุทรสาคร','สารคาม':'มหาสารคาม','สารภี':'เชียงใหม่','สิงห์บุรี\xa0':'สิงห์บุรี',
                                         'สุทรปราการ':'สมุทรปราการ','สุพรรญบุรี':'สุพรรณบุรี','สุพรรณบุรั':'สุพรรณบุรี','สุพรรณบุรี\xa0':'สุพรรณบุรี','สุมทรปราการ':'สมุทรปราการ',
                                         'สุมทรสาคร':'สมุทรสาคร','สุมุทรปราการ':'สมุทรปราการ','สุมุทรสาคร':'สมุทรสาคร','สุระบุรี':'สระบุรี','สุราษ':'สุราษฎร์ธานี','สุราษฎณ์ธานี':'สุราษฎร์ธานี','สุราษฎธานี':'สุราษฎร์ธานี',
                                         'สุราษฎร์':'สุราษฎร์ธานี','สุราษฎร์ฯ':'สุราษฎร์ธานี','สุราษฎร์์ธานี':'สุราษฎร์ธานี','สุราษฎ์ธานี':'สุราษฎร์ธานี','สุราษฏร์ธานี':'สุราษฎร์ธานี','สุราษธานี':'สุราษฎร์ธานี',
                                         'สุราษร์ฎธานี':'สุราษฎร์ธานี','สุราษร์ธานี':'สุราษฎร์ธานี','สุราษฯ':'สุราษฎร์ธานี','สุรินทรื':'สุรินทร์','สุรินทร์ 32150':'สุรินทร์','สุรินทร์,รีสะเกษ':'สุรินทร์','สุรินทร์\xa0':'สุรินทร์','สุริมทร์':'สุรินทร์',
                                         'สุริะแก้ว':'สระแก้ว','สุวรรณภูมิ':'สมุทรปราการ','สุุพรรณบุรี':'สุพรรณบุรี','สุุราษฎร์ธานี':'สุราษฎร์ธานี','สุุราษฏร์ธานี':'สุราษฎร์ธนี','สุุราษฯ':'สุราษฎร์ธนี','สุุรินทร์':'สุรินทร์',
                                         'สุุุโขทัย':'สุโขทัย','สุโขทับ':'สุโขทัย','สุโขทัย\xa0':'สุโขทัย','สูงเม่น':'แพร่','หนวงบัวลำภู':'หนองบัวลำภู','หนองงคาย':'หนองคาย','หนองบัวภู':'หนองบัวลำภู',
                                         'หนองบัวลำพูน':'หนองบัวลำภู','หนองบัวลําภู':'หนองบัวลำภู','หนองบััวลำภู':'หนองบัวลำภู','หนองม่วงไข่':'แพร่','หนอบัวลำภู':'หนองบัวลำภู','หลายจังหวัด':'ไม่มีข้อมูล','หัวหิน':'ประจวบคีรีขันธ์',
                                         'ห้วยขวาง':'กรุงเทพมหานคร','อยุทธยา':'พระนครศรีอยุธยา','อยุธยา':'พระนครศรีอยุธยา','อยุุธยา':'พระนครศรีอยุธยา','อำนาจเจิญ':'อำนาจเจริญ','อำนาญเจริญ':'อำนาจเจริญ','อำนาเจริญ':'อำนาจเจริญ',
                                         'อิสราเอล':'ไม่มีข้อมูล','อุดธานี':'อุดรธานี','อุดร':'อุดรธานี','อุดรธาณี':'อุดรธานี','อุดรธานี\xa0':'อุดรธานี','อุดรธานีี':'อุดรธานี','อุดรราชธานี':'อุดรธานี','อุตรดิตถ์\xa0':'อุตรดิตถ์',
                                         'อุตรดิตถ์์':'อุตรดิตถ์','อุตรดิษถ์':'อุตรดิตถ์','อุตรดิิตถ์':'อุตรดิตถ์','อุตรติดถ์':'อุตรดิตถ์','อุบลราขธานี':'อุบลราชธานี','อุบลราชธานี\xa0':'อุบลราชธานี','อุุครดิตถ์':'อุตรดิตถ์',
                                         'อุุดรธาน':'อุดรธานี','อุุดรธานี':'อุดรธานี','อุุตรดิตถ์':'อุตรดิตถ์','อุุทัยธานี':'อุทัยธานี','อุุบลราชธานี':'อุบลราชธานี','อ่งทอง':'อ่างทอง','อ่างทอง\xa0':'อ่างทอง','อํานาจเจริญ':'อำนาจเจริญ',
                                         'เชิงเทรา':'ฉะเชิงเทรา','เชียรใหญ่':'นครศรีธรรมราช','เชีียงราย':'เชียงราย','เชีียงใหม่':'เชียงใหม่','เด่นชัย':'แพร่',
                                         'เพขรบุรี':'เพชรบูรณ์','เพขรบูรณื':'เพชรบูรณ์','เพขรบูรณ์':'เพชรบูรณ์','เพชรบุรณ์':'เพชรบูรณ์','เพชรบุรี':'เพชรบูรณ์','เพชรบุรึ':'เพชรบูรณ์','เพชรบุุรี':'เพชรบูรณ์','เพชรบุูรณ์':'เพชรบูรณ์','เพชรบูรณ์\xa0':'เพชรบูรณ์',
                                         'เพชรบูร์':'เพชรบูรณ์','เพชรบููรณ์':'เพชรบูรณ์','เมือง':'แพร่','เมืองตาก':'ตาก','เมืองน่าน':'น่าน','เมืองปัตตานี':'ปัตตานี','เรือ':'เลย','เลย\xa0':'เลย','เวียงจันทร์':'ไม่มีข้อมูล','เวียงสา':'น่าน','แม่ทะ':'ลำปาง',
                                         'แล้วป่วย':'ไม่มีข้อมูล','โพธิ์ทอง':'อ่างทอง','ไชโย':'อ่างทอง','ไม่มีข้อมูล':'ไม่มีข้อมูล','ไม่มีชื่อหอพัก':'ไม่มีข้อมูล','ไม่ระบุ':'ไม่มีข้อมูล','สมุทรปรากา':'สมุทรปราการ'}, inplace=True)# แก้ไขข้อมูลที่พิมพ์จังหวัดผิด ให้อยู่ในชื่อจังหวัดที่ถูกต้อง
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
data_04['province_of_onset'].replace({'USA':'ไม่มีข้อมูล','\tประจวบคีรีขันธ์':'ประจวบคีรีขันธ์','\xa0กาญจนบุรี':'กาญจนบุรี','\xa0ชลบุรี':'ชลบุรี','\xa0ตราด':'ตราด','\xa0นครปฐม':'นครปฐม',
                                         '\xa0สมุทรสงคราม':'สมุทรสงคราม','\xa0สมุทรสาคร':'สมุทรสาคร','\xa0อุทัยธานี':'อุทัยธานี','กทม':'กรุงเทพมหานคร','กทม.':'กรุงเทพมหานคร','กบินทร์บุรี':'ปราจีนบุรี','กระบี่ี่':'กระบี่','กรุงเทพ':'กรุงเทพมหานคร',
                                         'กรุงเทพมหานคร.':'กรุงเทพมหานคร','กรุงเทพมหานคร. / พระนครศรีอยุธยา':'กรุงเทพมหานคร','กรุงเทพมหานคร. / ศรีสะเกษ':'กรุงเทพมหานคร','กรุงเทพฯ':'กรุงเทพมหานคร','กะทู้':'ภูเก็ต',
                                         'กัมพูชา':'ไม่มีข้อมูล','กาญจบุรี':'กาญจนบุรี','กาญนบุรี':'กาญจนบุรี','กาฬสิน':'กาฬสินธุ์','กาฬสินธิ์':'กาฬสินธุ์','กาฬสินธุ์\xa0':'กาฬสินธุ์','กาฬสินธ์':'กาฬสินธุ์',
                                         'กำเพงเพชร':'กำแพงเพชร','กำแพง':'กำแพงเพชร','กำแพงเพชร':'กำแพงเพชร','กำแพงเพชร\xa0':'กำแพงเพชร','กําแพงเพชร':'กำแพงเพชร',
                                         'ขอนแก่น\xa0':'ขอนแก่น','ขอนแก่่น':'ขอนแก่น','ขานุวรลักษณ์บุรี':'กำแพงเพชร','คนไทยเดินทางกลับจากต่างประเทศ':'ไม่มีข้อมูล','คลองเตย':'กรุงเทพมหานคร','จ.กรุงเทพมหานคร':'กรุงเทพมหานคร',
                                         'จ.ภูเก็ต':'ภูเก็ต','จ.ราชบุรี':'ราชบุรี','จ.สุราษฎร์ธานี':'สุราษฎร์ธานี','จังหวัดสมุทรสาคร':'สมุทรสาคร','ฉะเชองเทราร':'ฉะเชิงเทรา','ชมพร':'ชุมพร',
                                         'ชลบุรี\t':'ชลบุรี','ชลบุรี\xa0':'ชลบุรี','ชลบุุรี':'ชลบุรี','ชอนแก่น':'ขอนแก่น','ชัยนาถ':'ชัยนาท','ชัยบาดาล':'ลพบุรี','ชัยภูมิ\xa0':'ชัยภูมิ','ชุุมพร':'ชุมพร','ชุุุมพร':'ชุมพร',
                                         'ดอนมดแดง':'อุบลราชธานี','ดินแดง':'กรุงเทพมหานคร','ตรััง':'ตรัง','ตราด\xa0':'ตราด','ตากใบ':'นราธิวาส','ต่างจังหวัด':'ไม่มีข้อมูล','ทุ่งเสลี่ยม':'สุโขทัย',
                                         'ท้ายบ้าน':'สมุทรปราการ','ธารโต':'ยะลา','นคนปฐม':'นครปฐม','นคปฐม':'นครปฐม','นครนปฐม':'นครปฐม','นครนาชสีมา':'นครราชสีมา','นครปฐม\xa0':'นครปฐม',
                                         'นครปบม':'นครปฐม','นครพนม\xa0':'นครพนม','นครยายก':'นครนายก','นครราขสีมา':'นครราชสีมา','นครราชธานี':'นครราชสีมา','นครราชศรีมา':'นครราชสีมา','นครราชสสีมา':'นครราชสีมา',
                                         'นครราชสีมา ลพบุรี':'นครราชสีมา','นครราชสีมา\xa0':'นครราชสีมา','นครศรธรรมราช':'นครศรีธรรมราช','นครศรี':'นครศรีธรรมราช','นครศรีธรมมราช':'นครศรีธรรมราช',
                                         'นครศรีธรมราช':'นครศรีธรรมราช','นครศรีธรรมราข':'นครศรีธรรมราช','นครศรีฯ':'นครศรีธรรมราช','นครศรีีธรรมราช':'นครศรีธรรมราช','นครศร๊ธรรมราช':'นครศรีธรรมราช',
                                         'นครศร๊ะรรมราช':'นครศรีธรรมราช','นครสรรค์':'นครสวรรค์','นครสรีธรรมราช':'นครศรีธรรมราช','นครสวรรค':'นครสวรรค์','นครสวรรค์\xa0':'นครสวรรค์','นครสีธรรมราช':'นครศรีธรรมราช',
                                         'นครฯ':'นครศรีธรรมราช','นคราชสีมา':'นครราชสีมา','นครีศรีธรรมราช':'นครศรีธรรมราช','นตรนายก':'นครนายก','นตรปฐม':'นครปฐม','นนทบุรี\xa0':'นนทบุรี',
                                         'นนทบุุรี':'นนทบุรี','นนทุบรี':'นนทบุรี','นนทุรี':'นนทบุรี','นนมบุรี':'นนทบุรี','นรศรีธรรมราช':'นครศรีธรรมราช','นราธิวาส\u200b':'นราธิวาส','นราธฺวาส':'นราธิวาส','นอกเขต':'ไม่มีข้อมูล',
                                         'นาราธิวาส':'นราธิวาส','นาวัง':'หนองบัวลำภู','น่าน/ฉะเชิงเทรา':'น่าน','บางกรวย':'นนทบุรี','บางกะปิ':'กรุงเทพมหานคร','บางนา':'กรุงเทพมหานคร','บางปะอิน':'กรุงเทพมหานคร',
                                         'บางละมุง':'ชลบุรี','บางศรีเมือง':'นนทบุรี','บางเพียง':'สมุทรปราการ','บึงโขงหลง':'บึงกาฬ','บุรีรัมภ์':'บุรีรัมย์','บุรีรัมย์\xa0':'บุรีรัมย์','บุรีรัยม์':'บุรีรัมย์','บุรีรีมย์':'บุรีรัมย์',
                                         'บ้านหลวง':'น่าน','ปจ':'ไม่มีข้อมูล','ปทึมธานี':'ปทุมธานี','ปทุทธานี':'ปทุมธานี','ปทุมฑานี':'ปทุมธานี','ปทุมทานี':'ปทุมธานี','ปทุมธาน':'ปทุมธานี','ปทุมธานี\xa0':'ปทุมธานี','ปทุมาธานี':'ปทุมธานี',
                                         'ปธุมธานี':'ปทุมธานี','ปทุมธานี.':'ปทุมธานี','ปทุมธานีี':'ปทุมธานี','ปทุุมธานี':'ปทุมธานี','ปมุมธานี':'ปทุมธานี',
                                         'ประจวนคีรีขันธ็':'ประจวบคีรีขันธ์','ประจวบ':'ประจวบคีรีขันธ์','ประจวบคิรีขันธ์':'ประจวบคีรีขันธ์','ประจวบคีรขันธ์':'ประจวบคีรีขันธ์','ประจวบคีรขัันธ์':'ประจวบคีรีขันธ์','ประจวบคีรีขัน':'ประจวบคีรีขันธ์',
                                         'ประจวบคีรีขันธื':'ประจวบคีรีขันธ์','ประจวบคีรีขันธฺ':'ประจวบคีรีขันธ์','ประจวบคีรีขันธ์\xa0':'ประจวบคีรีขันธ์','ประจวบคีรีขันธ์์':'ประจวบคีรีขันธ์','ประจวบคีรีขัันธ์':'ประจวบคีรีขันธ์','ประจวบคีีรีขันธ์':'ประจวบคีรีขันธ์',
                                         'ประจวบฯ':'ประจวบคีรีขันธ์','ประทุมธานี':'ปทุมธานี', 'ประเทศกัมพูชา':'ไม่มีข้อมูล','ปราจีบุรี':'ปราจีนบุรี','ปลวกแดง':'ระยอง','ปลายพระยา':'กระบี่', 'ปอยเปต':'ไม่มีข้อมูล','ปัตตนรี':'ปัตตานี',
                                         'ปัตตานนี':'ปัตตานี','ปัตตานีี':'ปัตตานี','ปัว':'น่าน','ปััตตานี':'ปัตตานี','ปุทมธานี':'ปทุมธานี','ป่าโมก':'อ่างทอง','พม่า':'ไม่มีข้อมูล','พรหมพิราม':'พิษณุโลก','พระนครศรียุธยา':'พระนครศรีอยุธยา',
                                         'พระนครศรีอยุทธยา':'พระนครศรีอยุธยา','พระนครศรีอยุทยา':'พระนครศรีอยุธยา','พระนครศรีอยุธยา\xa0':'พระนครศรีอยุธยา','พัทยา':'ชลบุรี','พัทลุุง':'พัทลุง','พัังงา':'พังงา',
                                         'พิษณุโลก\xa0':'พิษณุโลก','พิษณูโลก':'พิษณุโลก','ฟินแลนด์':'ไม่มีข้อมูล','ภาษีเจริญ':'กรุงเทพมหานคร','ภุเก็ต':'ภูเก็ต','ภูุเก็ต':'ภูเก็ต','ภููเก็ต':'ภูเก็ต','ภูเก็็ต':'ภูเก็ต','ภูเพียง':'น่าน',
                                         'มหาสาคาม':'มหาสารคาม','มาเลเซีย':'ไม่มีข้อมูล','มุกาดหาร':'มุกดาหาร','ยานนาวา':'กรุงเทพมหานคร','ร.จ.จ.นราธิวาส':'นราธิวาส','รอ':'ร้อยเอ็ด','ระบุ':'ไม่มีข้อมูล','ระยอง\xa0':'ระยอง',
                                         'ระอยง':'ระยอง','ราชบบุรี':'ราชบุรี','ราชบุรีี':'ราชบุรี','ราชบุรี\u200b':'ราชบุรี','ราชุรี':'ราชบุรี','ราชเทวี':'กรุงเทพมหานคร','ร้องกวาง':'แพร่','ลบุรี':'ลพบุรี','ลพบุรี.':'ลพบุรี','ลพบุรี\xa0':'ลพบุรี','ลอง':'แพร่',
                                         'ลาดกระบัง':'กรุงเทพมหานคร','ลาดพร้าว':'กรุงเทพมหานคร','ลาว':'ไม่มีข้อมูล','ลำพูน\u200b':'ลำพูน','ลำพููน':'ลำพูน','ลำลูกกา':'ปทุมธานี','วังชิ้น':'ลำปาง','วังทอง':'พิษณุโลก',
                                         'วิเศษชัยชาญ':'อ่างทอง','ศรีษะสะเกษ':'ศรีสะเกษ','ศรีษะเกษ':'ศรีสะเกษ','ศรีสระเกษ':'ศรีสะเกษ','ศีรสะเกษ':'ศรีสะเกษ','สครสวรรค์':'นครสวรรค์',
                                         'สงขลา\u200b':'สงขลา','สถานที่ทำงาน':'ไม่มีข้อมูล','สพรรณบุรี':'สุพรรณบุรี','สมถทรปราการ':'สมุทรปราการ','สมทรสงคราม':'สมุทรสงคราม','สมทรสาคร':'สมุทรสาคร','สมุครปราการ':'สมุทรปราการ',
                                         'สมุครสาคร':'สมุทรสาคร','สมุท':'ไม่มีข้อมูล','สมุทปราการ':'สมุทรปราการ','สมุทรปรากร':'สมุทรปราการ','สมุทรปรากรร':'สมุทรปราการ','สมุทรปราการ\xa0':'สมุทรปราการ','สมุทรศาคร':'สมุทรสาคร',
                                         'สมุทรสาคร\xa0':'สมุทรสาคร','สมุทรสาคา':'สมุทรสาคร','สมุทรสาคาร':'สมุทรสาคร','สมุทรสาทร':'สมุทรสาคร','สมุทรสารคร':'สมุทรสาคร','สมุทราปราการ':'สมุทรปราการ',
                                         'สมุทราสาคร':'สมุทรสาคร','สมุทสงคราม':'สมุทรสงคราม','สมุทสาคร':'สมุทรสาคร','สมุย':'สุราษฎร์ธานี','สมุุทรปราการ':'สมุทรปราการ','สมุุทรสงคราม':'สมุทรสงคราม','สมุุทรสาคร':'สมุทรสาคร',
                                         'สระก้ว':'สระแก้ว','สระบุรี\xa0':'สระบุรี','สรินทร์':'สุรินทร์','สวิสเซอร์แลนด์':'ไม่มีข้อมูล','สอง':'แพร่','สองแคว':'น่าน','สะพานสูง':'กรุงเทพมหานคร',
                                         'สะแก้ว':'สระแก้ว','สัตหีบ':'ชลบุรี','สัมผัสผู้ป่วยยืนยัน COVID20':'ไม่มีข้อมูล','สามุทรสาคร':'สมุทรสาคร','สารคาม':'มหาสารคาม','สารภี':'เชียงใหม่','สิงห์บุรี\xa0':'สิงห์บุรี',
                                         'สุทรปราการ':'สมุทรปราการ','สุพรรญบุรี':'สุพรรณบุรี','สุพรรณบุรั':'สุพรรณบุรี','สุพรรณบุรี\xa0':'สุพรรณบุรี','สุมทรปราการ':'สมุทรปราการ',
                                         'สุมทรสาคร':'สมุทรสาคร','สุมุทรปราการ':'สมุทรปราการ','สุมุทรสาคร':'สมุทรสาคร','สุระบุรี':'สระบุรี','สุราษ':'สุราษฎร์ธานี','สุราษฎณ์ธานี':'สุราษฎร์ธานี','สุราษฎธานี':'สุราษฎร์ธานี',
                                         'สุราษฎร์':'สุราษฎร์ธานี','สุราษฎร์ฯ':'สุราษฎร์ธานี','สุราษฎร์์ธานี':'สุราษฎร์ธานี','สุราษฎ์ธานี':'สุราษฎร์ธานี','สุราษฏร์ธานี':'สุราษฎร์ธานี','สุราษธานี':'สุราษฎร์ธานี',
                                         'สุราษร์ฎธานี':'สุราษฎร์ธานี','สุราษร์ธานี':'สุราษฎร์ธานี','สุราษฯ':'สุราษฎร์ธานี','สุรินทรื':'สุรินทร์','สุรินทร์ 32150':'สุรินทร์','สุรินทร์,รีสะเกษ':'สุรินทร์','สุรินทร์\xa0':'สุรินทร์','สุริมทร์':'สุรินทร์',
                                         'สุริะแก้ว':'สระแก้ว','สุวรรณภูมิ':'สมุทรปราการ','สุุพรรณบุรี':'สุพรรณบุรี','สุุราษฎร์ธานี':'สุราษฎร์ธานี','สุุราษฏร์ธานี':'สุราษฎร์ธนี','สุุราษฯ':'สุราษฎร์ธนี','สุุรินทร์':'สุรินทร์',
                                         'สุุุโขทัย':'สุโขทัย','สุโขทับ':'สุโขทัย','สุโขทัย\xa0':'สุโขทัย','สูงเม่น':'แพร่','หนวงบัวลำภู':'หนองบัวลำภู','หนองงคาย':'หนองคาย','หนองบัวภู':'หนองบัวลำภู',
                                         'หนองบัวลำพูน':'หนองบัวลำภู','หนองบัวลําภู':'หนองบัวลำภู','หนองบััวลำภู':'หนองบัวลำภู','หนองม่วงไข่':'แพร่','หนอบัวลำภู':'หนองบัวลำภู','หลายจังหวัด':'ไม่มีข้อมูล','หัวหิน':'ประจวบคีรีขันธ์',
                                         'ห้วยขวาง':'กรุงเทพมหานคร','อยุทธยา':'พระนครศรีอยุธยา','อยุธยา':'พระนครศรีอยุธยา','อยุุธยา':'พระนครศรีอยุธยา','อำนาจเจิญ':'อำนาจเจริญ','อำนาญเจริญ':'อำนาจเจริญ','อำนาเจริญ':'อำนาจเจริญ',
                                         'อิสราเอล':'ไม่มีข้อมูล','อุดธานี':'อุดรธานี','อุดร':'อุดรธานี','อุดรธาณี':'อุดรธานี','อุดรธานี\xa0':'อุดรธานี','อุดรธานีี':'อุดรธานี','อุดรราชธานี':'อุดรธานี','อุตรดิตถ์\xa0':'อุตรดิตถ์',
                                         'อุตรดิตถ์์':'อุตรดิตถ์','อุตรดิษถ์':'อุตรดิตถ์','อุตรดิิตถ์':'อุตรดิตถ์','อุตรติดถ์':'อุตรดิตถ์','อุบลราขธานี':'อุบลราชธานี','อุบลราชธานี\xa0':'อุบลราชธานี','อุุครดิตถ์':'อุตรดิตถ์',
                                         'อุุดรธาน':'อุดรธานี','อุุดรธานี':'อุดรธานี','อุุตรดิตถ์':'อุตรดิตถ์','อุุทัยธานี':'อุทัยธานี','อุุบลราชธานี':'อุบลราชธานี','อ่งทอง':'อ่างทอง','อ่างทอง\xa0':'อ่างทอง','อํานาจเจริญ':'อำนาจเจริญ',
                                         'เชิงเทรา':'ฉะเชิงเทรา','เชียรใหญ่':'นครศรีธรรมราช','เชีียงราย':'เชียงราย','เชีียงใหม่':'เชียงใหม่','เด่นชัย':'แพร่',
                                         'เพขรบุรี':'เพชรบูรณ์','เพขรบูรณื':'เพชรบูรณ์','เพขรบูรณ์':'เพชรบูรณ์','เพชรบุรณ์':'เพชรบูรณ์','เพชรบุรี':'เพชรบูรณ์','เพชรบุรึ':'เพชรบูรณ์','เพชรบุุรี':'เพชรบูรณ์','เพชรบุูรณ์':'เพชรบูรณ์','เพชรบูรณ์\xa0':'เพชรบูรณ์',
                                         'เพชรบูร์':'เพชรบูรณ์','เพชรบููรณ์':'เพชรบูรณ์','เมือง':'แพร่','เมืองตาก':'ตาก','เมืองน่าน':'น่าน','เมืองปัตตานี':'ปัตตานี','เรือ':'เลย','เลย\xa0':'เลย','เวียงจันทร์':'ไม่มีข้อมูล','เวียงสา':'น่าน','แม่ทะ':'ลำปาง',
                                         'แล้วป่วย':'ไม่มีข้อมูล','โพธิ์ทอง':'อ่างทอง','ไชโย':'อ่างทอง','ไม่มีข้อมูล':'ไม่มีข้อมูล','ไม่มีชื่อหอพัก':'ไม่มีข้อมูล','ไม่ระบุ':'ไม่มีข้อมูล','สมุทรปรากา':'สมุทรปราการ'}, inplace=True)# แก้ไขข้อมูลที่พิมพ์จังหวัดผิด ให้อยู่ในชื่อจังหวัดที่ถูกต้อง
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %% [markdown]
# ## รวมตารางข้อมูลจำนวนผู้ติดเชื้อ

# %% [markdown]
# ### รวมตารางข้อมูลจำนวนผู้ติดเชื้อช่วงที่ 1 ,ข้อมูลจำนวนผู้ติดเชื้อช่วงที่ 2, ข้อมูลจำนวนผู้ติดเชื้อช่วงที่ 3 และข้อมูลจำนวนผู้ติดเชื้อช่วงที่ 4

# %%
data1234= pd.concat([data_01, data_02, data_03, data_04],axis=0) #vertical_concat
data1234
# Out:
#        announce_date        age                              risk  \
# 0          12/1/2020       61.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1          17/1/2020       74.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2          22/1/2020       73.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3          22/1/2020       68.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4          24/1/2020       66.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...              ...        ...                               ...
# 357076     15/3/2022  36.943725                  ทัณฑสถาน/เรือนจำ
# 357077     15/3/2022  36.943725                  ทัณฑสถาน/เรือนจำ
# 357078     15/3/2022  36.943725                  ทัณฑสถาน/เรือนจำ
# 357079     15/3/2022  36.943725                  ทัณฑสถาน/เรือนจำ
# 357080     15/3/2022  36.943725                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0          กรุงเทพมหานคร       ไม่มีข้อมูล
# 1          กรุงเทพมหานคร       ไม่มีข้อมูล
# 2                 นครปฐม             เมือง
# 3          กรุงเทพมหานคร       ไม่มีข้อมูล
# 4          กรุงเทพมหานคร       ไม่มีข้อมูล
# ...                  ...               ...
# 357076       ไม่มีข้อมูล       ไม่มีข้อมูล
# 357077       ไม่มีข้อมูล       ไม่มีข้อมูล
# 357078       ไม่มีข้อมูล       ไม่มีข้อมูล
# 357079       ไม่มีข้อมูล       ไม่มีข้อมูล
# 357080       ไม่มีข้อมูล       ไม่มีข้อมูล
#
# [3249479 rows x 5 columns]

# %%
set(data1234['province_of_onset'])
# Out:
# {'กระบี่',
#  'กรุงเทพมหานคร',
#  'กาญจนบุรี',
#  'กาฬสินธุ์',
#  'กำแพงเพชร',
#  'ขอนแก่น',
#  'ขัยนาท',
#  'ขัยภูมิ',
#  'จันทบุรี',
#  'ฉะเชิงเทรา',
#  'ชลบุรี',
#  'ชัยนาท',
#  'ชัยภูมิ',
#  'ชุมพร',
#  'ตรัง',
#  'ตราด',
#  'ตาก',
#  'นครนายก',
#  'นครปฐม',
#  'นครพนม',
#  'นครราชสีมา',
#  'นครศรีธรรมราช',
#  'นครสวรรค์',
#  'นนทบุรี',
#  'นราธิวาส',
#  'น่าน',
#  'บึงกาฬ',
#  'บุรีรัมย์',
#  'ปทุมธานี',
#  'ประจวบคีรีขันธ์',
#  'ปราจีนบุรี',
#  'ปัตตานี',
#  'ปัตาตานี',
#  'พระนครศรีอยุธยา',
#  'พะเยา',
#  'พังงา',
#  'พัทลุง',
#  'พิจิตร',
#  'พิษณุโลก',
#  'ภูเก็ต',
#  'มหาสารคาม',
#  'มุกดาหาร',
#  'ยะลา',
#  'ยโสธร',
#  'ระนอง',
#  'ระยอง',
#  'ราชบุรี',
#  'ร้อยเอ็ด',
#  'ลพบุรี',
#  'ลำปาง',
#  'ลำพูน',
#  'ศรีสะเกษ',
#  'สกลนคร',
#  'สงขลา',
#  'สตูล',
#  'สมุทรปราการ',
#  'สมุทรสงคราม',
#  'สมุทรสาคร',
#  'สระบุรี',
#  'สระแก้ว',
#  'สิงห์บุรี',
#  'สุพรรณบุรี',
#  'สุราษฎร์ธนี',
#  'สุราษฎร์ธานี',
#  'สุรินทร์',
#  'สุโขทัย',
#  'หนองคาย',
#  'หนองบัวลำภู',
#  'อำนาจเจริญ',
#  'อุดรธานี',
#  'อุตรดิตถ์',
#  'อุทัยธานี',
#  'อุทัยานี',
#  'อุบลราชธานี',
#  'อ่างทอง',
#  'เชียงราย',
#  'เชียงใหม่',
#  'เพชรบูรณ์',
#  'เลย',
#  'แพร่',
#  'แม่ฮ่องสอน',
#  'ไม่มีข้อมูล'}

# %% [markdown]
# # ข้อมูลจังหวัดแต่ละภูมิภาค

# %%
import pandas as pd

# %%
data_province = {'province': ['อำนาจเจริญ', 'บึงกาฬ', 'บุรีรัมย์', 'ชัยภูมิ', 'กาฬสินธุ์', 'ขอนแก่น', 'เลย', 'มหาสารคาม', 'มุกดาหาร', 'นครพนม', 'นครราชสีมา', 'หนองบัวลำภู', 'หนองคาย', 'ร้อยเอ็ด', 'สกลนคร', 'ศรีสะเกษ', 'สุรินทร์', 'อุบลราชธานี', 'อุดรธานี', 'ยโสธร','เชียงใหม่', 'เชียงราย', 'ลำปาง', 'ลำพูน', 'แม่ฮ่องสอน', 'น่าน', 'พะเยา', 'แพร่', 'อุตรดิตถ์','ตาก','สุโขทัย', 'พิษณุโลก', 'พิจิตร', 'กำแพงเพชร', 'เพชรบูรณ์','นครสวรรค์', 'อุทัยธานี','อ่างทอง', 'ชัยนาท', 'พระนครศรีอยุธยา', 'กรุงเทพมหานคร', 'ลพบุรี', 'นครปฐม', 'นนทบุรี', 'ปทุมธานี', 'สมุทรปราการ','สมุทรสาคร', 'สมุทรสงคราม','สระบุรี', 'สิงห์บุรี', 'สุพรรณบุรี','นครนายก','ฉะเชิงเทรา', 'จันทบุรี', 'ชลบุรี', 'ปราจีนบุรี', 'ระยอง', 'สระแก้ว', 'ตราด','กาญจนบุรี', 'ราชบุรี','เพชรบุรี', 'ประจวบคีรีขันธ์','ชุมพร', 'นครศรีธรรมราช', 'นราธิวาส', 'ปัตตานี', 'พัทลุง', 'สงขลา', 'สุราษฎร์ธานี', 'ยะลา','กระบี่', 'พังงา', 'ภูเก็ต', 'ระนอง', 'สตูล', 'ตรัง'],
            '6 ภูมิภาค (ภูมิศาสตร์)': ['ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','ตะวันตก','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันตก','ตะวันตก','ตะวันตก','ตะวันตก','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้']
}

# %%
province_df = pd.DataFrame.from_dict(data_province) #คำสั่งสร้างตาราง Dataframe
province_df
# Out:
#       province 6 ภูมิภาค (ภูมิศาสตร์)
# 0   อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 1       บึงกาฬ     ตะวันออกเฉียงเหนือ
# 2    บุรีรัมย์     ตะวันออกเฉียงเหนือ
# 3      ชัยภูมิ     ตะวันออกเฉียงเหนือ
# 4    กาฬสินธุ์     ตะวันออกเฉียงเหนือ
# ..         ...                    ...
# 72       พังงา                    ใต้
# 73      ภูเก็ต                    ใต้
# 74       ระนอง                    ใต้
# 75        สตูล                    ใต้
# 76        ตรัง                    ใต้
#
# [77 rows x 2 columns]

# %% [markdown]
# ## รวมตารางข้อมูลจำนวนผู้ติดเชื้อกับข้อมูลจังหวัดแต่ละภูมิภาค

# %%
case_pro = data1234.merge(province_df,how='left',left_on='province_of_onset',right_on = 'province') 
case_pro
# Out:
#         announce_date        age                              risk  \
# 0           12/1/2020       61.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1           17/1/2020       74.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2           22/1/2020       73.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3           22/1/2020       68.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4           24/1/2020       66.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...               ...        ...                               ...
# 3249474     15/3/2022  36.943725                  ทัณฑสถาน/เรือนจำ
# 3249475     15/3/2022  36.943725                  ทัณฑสถาน/เรือนจำ
# 3249476     15/3/2022  36.943725                  ทัณฑสถาน/เรือนจำ
# 3249477     15/3/2022  36.943725                  ทัณฑสถาน/เรือนจำ
# 3249478     15/3/2022  36.943725                  ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset       province  \
# 0           กรุงเทพมหานคร       ไม่มีข้อมูล  กรุงเทพมหานคร
# 1           กรุงเทพมหานคร       ไม่มีข้อมูล  กรุงเทพมหานคร
# 2                  นครปฐม             เมือง         นครปฐม
# 3           กรุงเทพมหานคร       ไม่มีข้อมูล  กรุงเทพมหานคร
# 4           กรุงเทพมหานคร       ไม่มีข้อมูล  กรุงเทพมหานคร
# ...                   ...               ...            ...
# 3249474       ไม่มีข้อมูล       ไม่มีข้อมูล            NaN
# 3249475       ไม่มีข้อมูล       ไม่มีข้อมูล            NaN
# 3249476       ไม่มีข้อมูล       ไม่มีข้อมูล            NaN
# 3249477       ไม่มีข้อมูล       ไม่มีข้อมูล            NaN
# 3249478       ไม่มีข้อมูล       ไม่มีข้อมูล            NaN
#
#         6 ภูมิภาค (ภูมิศาสตร์)
# 0                         กลาง
# 1                         กลาง
# 2                         กลาง
# 3                         กลาง
# 4                         กลาง
# ...                        ...
# 3249474                    NaN
# 3249475                    NaN
# 3249476                    NaN
# 3249477                    NaN
# 3249478                    NaN
#
# [3249479 rows x 7 columns]

# %%
#case_pro.to_csv('case_pro.csv', encoding='utf-8') #ไม่ต้องแคป

# %%
case_pro.isnull().any()
# Out:
# announce_date             False
# age                       False
# risk                      False
# province_of_onset         False
# district_of_onset         False
# province                   True
# 6 ภูมิภาค (ภูมิศาสตร์)     True
# dtype: bool

# %% [markdown]
# แทน missing ด้วยค่าที่เหมาะสม (fillna())

# %%
case_pro01 = case_pro.fillna(value={'province':'ไม่มีข้อมูล','6 ภูมิภาค (ภูมิศาสตร์)':'ไม่มีข้อมูล'})
case_pro01
# Out:
#         announce_date        age                              risk  \
# 0           12/1/2020       61.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1           17/1/2020       74.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2           22/1/2020       73.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3           22/1/2020       68.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4           24/1/2020       66.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...               ...        ...                               ...
# 3249474     15/3/2022  36.943725                  ทัณฑสถาน/เรือนจำ
# 3249475     15/3/2022  36.943725                  ทัณฑสถาน/เรือนจำ
# 3249476     15/3/2022  36.943725                  ทัณฑสถาน/เรือนจำ
# 3249477     15/3/2022  36.943725                  ทัณฑสถาน/เรือนจำ
# 3249478     15/3/2022  36.943725                  ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset       province  \
# 0           กรุงเทพมหานคร       ไม่มีข้อมูล  กรุงเทพมหานคร
# 1           กรุงเทพมหานคร       ไม่มีข้อมูล  กรุงเทพมหานคร
# 2                  นครปฐม             เมือง         นครปฐม
# 3           กรุงเทพมหานคร       ไม่มีข้อมูล  กรุงเทพมหานคร
# 4           กรุงเทพมหานคร       ไม่มีข้อมูล  กรุงเทพมหานคร
# ...                   ...               ...            ...
# 3249474       ไม่มีข้อมูล       ไม่มีข้อมูล    ไม่มีข้อมูล
# 3249475       ไม่มีข้อมูล       ไม่มีข้อมูล    ไม่มีข้อมูล
# 3249476       ไม่มีข้อมูล       ไม่มีข้อมูล    ไม่มีข้อมูล
# 3249477       ไม่มีข้อมูล       ไม่มีข้อมูล    ไม่มีข้อมูล
# 3249478       ไม่มีข้อมูล       ไม่มีข้อมูล    ไม่มีข้อมูล
#
#         6 ภูมิภาค (ภูมิศาสตร์)
# 0                         กลาง
# 1                         กลาง
# 2                         กลาง
# 3                         กลาง
# 4                         กลาง
# ...                        ...
# 3249474            ไม่มีข้อมูล
# 3249475            ไม่มีข้อมูล
# 3249476            ไม่มีข้อมูล
# 3249477            ไม่มีข้อมูล
# 3249478            ไม่มีข้อมูล
#
# [3249479 rows x 7 columns]

# %% [markdown]
# # ไม่ต้องเอาลงสไลด์ จนถึงตารางข้อมูลจำนวนผู้ติดเชื้อช่วงที่ 4 และภูมิภาคจังหวัด

# %% [markdown]
# ### ตารางข้อมูลจำนวนผู้ติดเชื้อช่วงที่ 1 และภูมิภาคจังหวัด

# %%
data_pro1 = data_01.merge(province_df,how='left',left_on='province_of_onset',right_on = 'province') 
data_pro1
# Out:
#        announce_date   age                              risk  \
# 0          12/1/2020  61.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1          17/1/2020  74.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2          22/1/2020  73.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3          22/1/2020  68.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4          24/1/2020  66.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...              ...   ...                               ...
# 839766     12/8/2021  52.0                  ทัณฑสถาน/เรือนจำ
# 839767     12/8/2021  34.0                  ทัณฑสถาน/เรือนจำ
# 839768     12/8/2021  31.0                  ทัณฑสถาน/เรือนจำ
# 839769     12/8/2021  83.0                  ทัณฑสถาน/เรือนจำ
# 839770     12/8/2021  47.0                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset       province  \
# 0          กรุงเทพมหานคร       ไม่มีข้อมูล  กรุงเทพมหานคร
# 1          กรุงเทพมหานคร       ไม่มีข้อมูล  กรุงเทพมหานคร
# 2                 นครปฐม             เมือง         นครปฐม
# 3          กรุงเทพมหานคร       ไม่มีข้อมูล  กรุงเทพมหานคร
# 4          กรุงเทพมหานคร       ไม่มีข้อมูล  กรุงเทพมหานคร
# ...                  ...               ...            ...
# 839766         กาญจนบุรี       ไม่มีข้อมูล      กาญจนบุรี
# 839767         กาญจนบุรี       ไม่มีข้อมูล      กาญจนบุรี
# 839768         กาญจนบุรี       ไม่มีข้อมูล      กาญจนบุรี
# 839769         กาญจนบุรี       ไม่มีข้อมูล      กาญจนบุรี
# 839770         กาญจนบุรี       ไม่มีข้อมูล      กาญจนบุรี
#
#        6 ภูมิภาค (ภูมิศาสตร์)
# 0                        กลาง
# 1                        กลาง
# 2                        กลาง
# 3                        กลาง
# 4                        กลาง
# ...                       ...
# 839766                ตะวันตก
# 839767                ตะวันตก
# 839768                ตะวันตก
# 839769                ตะวันตก
# 839770                ตะวันตก
#
# [839771 rows x 7 columns]

# %%
data_pro1.isnull().any()
# Out:
# announce_date             False
# age                       False
# risk                      False
# province_of_onset         False
# district_of_onset         False
# province                   True
# 6 ภูมิภาค (ภูมิศาสตร์)     True
# dtype: bool

# %%
data_pro001 = data_pro1.fillna(value={'province':'ไม่มีข้อมูล','6 ภูมิภาค (ภูมิศาสตร์)':'ไม่มีข้อมูล'})
data_pro001
# Out:
#        announce_date   age                              risk  \
# 0          12/1/2020  61.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1          17/1/2020  74.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2          22/1/2020  73.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3          22/1/2020  68.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4          24/1/2020  66.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...              ...   ...                               ...
# 839766     12/8/2021  52.0                  ทัณฑสถาน/เรือนจำ
# 839767     12/8/2021  34.0                  ทัณฑสถาน/เรือนจำ
# 839768     12/8/2021  31.0                  ทัณฑสถาน/เรือนจำ
# 839769     12/8/2021  83.0                  ทัณฑสถาน/เรือนจำ
# 839770     12/8/2021  47.0                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset       province  \
# 0          กรุงเทพมหานคร       ไม่มีข้อมูล  กรุงเทพมหานคร
# 1          กรุงเทพมหานคร       ไม่มีข้อมูล  กรุงเทพมหานคร
# 2                 นครปฐม             เมือง         นครปฐม
# 3          กรุงเทพมหานคร       ไม่มีข้อมูล  กรุงเทพมหานคร
# 4          กรุงเทพมหานคร       ไม่มีข้อมูล  กรุงเทพมหานคร
# ...                  ...               ...            ...
# 839766         กาญจนบุรี       ไม่มีข้อมูล      กาญจนบุรี
# 839767         กาญจนบุรี       ไม่มีข้อมูล      กาญจนบุรี
# 839768         กาญจนบุรี       ไม่มีข้อมูล      กาญจนบุรี
# 839769         กาญจนบุรี       ไม่มีข้อมูล      กาญจนบุรี
# 839770         กาญจนบุรี       ไม่มีข้อมูล      กาญจนบุรี
#
#        6 ภูมิภาค (ภูมิศาสตร์)
# 0                        กลาง
# 1                        กลาง
# 2                        กลาง
# 3                        กลาง
# 4                        กลาง
# ...                       ...
# 839766                ตะวันตก
# 839767                ตะวันตก
# 839768                ตะวันตก
# 839769                ตะวันตก
# 839770                ตะวันตก
#
# [839771 rows x 7 columns]

# %% [markdown]
# ### ตารางข้อมูลจำนวนผู้ติดเชื้อช่วงที่ 2 และภูมิภาคจังหวัด

# %%
data_pro2 = data_02.merge(province_df,how='left',left_on='province_of_onset',right_on = 'province') 
data_pro2
# Out:
#         announce_date   age                                         risk  \
# 0           12/8/2021   7.0                                        อื่นๆ
# 1           12/8/2021   1.0                                        อื่นๆ
# 2           12/8/2021  35.0                                        อื่นๆ
# 3           12/8/2021  33.0                                        อื่นๆ
# 4           12/8/2021  14.0  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...               ...   ...                                          ...
# 1042163    25/10/2021  45.0                             ทัณฑสถาน/เรือนจำ
# 1042164    25/10/2021  31.0                             ทัณฑสถาน/เรือนจำ
# 1042165    25/10/2021  31.0                             ทัณฑสถาน/เรือนจำ
# 1042166    25/10/2021  24.0                             ทัณฑสถาน/เรือนจำ
# 1042167    25/10/2021  25.0                             ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset province 6 ภูมิภาค (ภูมิศาสตร์)
# 0             ไม่มีข้อมูล       ไม่มีข้อมูล      NaN                    NaN
# 1             ไม่มีข้อมูล       ไม่มีข้อมูล      NaN                    NaN
# 2             ไม่มีข้อมูล       ไม่มีข้อมูล      NaN                    NaN
# 3             ไม่มีข้อมูล       ไม่มีข้อมูล      NaN                    NaN
# 4             ไม่มีข้อมูล       ไม่มีข้อมูล      NaN                    NaN
# ...                   ...               ...      ...                    ...
# 1042163       ไม่มีข้อมูล       ไม่มีข้อมูล      NaN                    NaN
# 1042164       ไม่มีข้อมูล       ไม่มีข้อมูล      NaN                    NaN
# 1042165       ไม่มีข้อมูล       ไม่มีข้อมูล      NaN                    NaN
# 1042166       ไม่มีข้อมูล       ไม่มีข้อมูล      NaN                    NaN
# 1042167       ไม่มีข้อมูล       ไม่มีข้อมูล      NaN                    NaN
#
# [1042168 rows x 7 columns]

# %%
data_pro2.isnull().any()
# Out:
# announce_date             False
# age                       False
# risk                      False
# province_of_onset         False
# district_of_onset         False
# province                   True
# 6 ภูมิภาค (ภูมิศาสตร์)     True
# dtype: bool

# %%
data_pro002 = data_pro2.fillna(value={'province':'ไม่มีข้อมูล','6 ภูมิภาค (ภูมิศาสตร์)':'ไม่มีข้อมูล'})
data_pro002
# Out:
#         announce_date   age                                         risk  \
# 0           12/8/2021   7.0                                        อื่นๆ
# 1           12/8/2021   1.0                                        อื่นๆ
# 2           12/8/2021  35.0                                        อื่นๆ
# 3           12/8/2021  33.0                                        อื่นๆ
# 4           12/8/2021  14.0  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...               ...   ...                                          ...
# 1042163    25/10/2021  45.0                             ทัณฑสถาน/เรือนจำ
# 1042164    25/10/2021  31.0                             ทัณฑสถาน/เรือนจำ
# 1042165    25/10/2021  31.0                             ทัณฑสถาน/เรือนจำ
# 1042166    25/10/2021  24.0                             ทัณฑสถาน/เรือนจำ
# 1042167    25/10/2021  25.0                             ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset     province  \
# 0             ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล
# 1             ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล
# 2             ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล
# 3             ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล
# 4             ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล
# ...                   ...               ...          ...
# 1042163       ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล
# 1042164       ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล
# 1042165       ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล
# 1042166       ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล
# 1042167       ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล
#
#         6 ภูมิภาค (ภูมิศาสตร์)
# 0                  ไม่มีข้อมูล
# 1                  ไม่มีข้อมูล
# 2                  ไม่มีข้อมูล
# 3                  ไม่มีข้อมูล
# 4                  ไม่มีข้อมูล
# ...                        ...
# 1042163            ไม่มีข้อมูล
# 1042164            ไม่มีข้อมูล
# 1042165            ไม่มีข้อมูล
# 1042166            ไม่มีข้อมูล
# 1042167            ไม่มีข้อมูล
#
# [1042168 rows x 7 columns]

# %% [markdown]
# ### ตารางข้อมูลจำนวนผู้ติดเชื้อช่วงที่ 3 และภูมิภาคจังหวัด

# %%
data_pro3 = data_03.merge(province_df,how='left',left_on='province_of_onset',right_on = 'province') 
data_pro3
# Out:
#         announce_date   age                                           risk  \
# 0          26/10/2021  20.0                                          อื่นๆ
# 1          26/10/2021  42.0                                          อื่นๆ
# 2          26/10/2021  33.0  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 3          26/10/2021  52.0  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 4          26/10/2021  84.0    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...               ...   ...                                            ...
# 1010454     27/2/2022    ปี                               ทัณฑสถาน/เรือนจำ
# 1010455     27/2/2022    ปี                               ทัณฑสถาน/เรือนจำ
# 1010456     27/2/2022    ปี                               ทัณฑสถาน/เรือนจำ
# 1010457     27/2/2022    ปี                               ทัณฑสถาน/เรือนจำ
# 1010458     27/2/2022    ปี                               ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset province 6 ภูมิภาค (ภูมิศาสตร์)
# 0                   ลำปาง        เมืองลำปาง    ลำปาง                  เหนือ
# 1                   ลำปาง        เมืองลำปาง    ลำปาง                  เหนือ
# 2                   ลำปาง          ห้างฉัตร    ลำปาง                  เหนือ
# 3                   ลำปาง          ห้างฉัตร    ลำปาง                  เหนือ
# 4                   ลำปาง        เมืองลำปาง    ลำปาง                  เหนือ
# ...                   ...               ...      ...                    ...
# 1010454       ไม่มีข้อมูล       ไม่มีข้อมูล      NaN                    NaN
# 1010455       ไม่มีข้อมูล       ไม่มีข้อมูล      NaN                    NaN
# 1010456       ไม่มีข้อมูล       ไม่มีข้อมูล      NaN                    NaN
# 1010457       ไม่มีข้อมูล       ไม่มีข้อมูล      NaN                    NaN
# 1010458       ไม่มีข้อมูล       ไม่มีข้อมูล      NaN                    NaN
#
# [1010459 rows x 7 columns]

# %%
data_pro3.isnull().any()
# Out:
# announce_date             False
# age                       False
# risk                      False
# province_of_onset         False
# district_of_onset         False
# province                   True
# 6 ภูมิภาค (ภูมิศาสตร์)     True
# dtype: bool

# %%
data_pro003 = data_pro3.fillna(value={'province':'ไม่มีข้อมูล','6 ภูมิภาค (ภูมิศาสตร์)':'ไม่มีข้อมูล'})
data_pro003
# Out:
#         announce_date   age                                           risk  \
# 0          26/10/2021  20.0                                          อื่นๆ
# 1          26/10/2021  42.0                                          อื่นๆ
# 2          26/10/2021  33.0  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 3          26/10/2021  52.0  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 4          26/10/2021  84.0    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...               ...   ...                                            ...
# 1010454     27/2/2022    ปี                               ทัณฑสถาน/เรือนจำ
# 1010455     27/2/2022    ปี                               ทัณฑสถาน/เรือนจำ
# 1010456     27/2/2022    ปี                               ทัณฑสถาน/เรือนจำ
# 1010457     27/2/2022    ปี                               ทัณฑสถาน/เรือนจำ
# 1010458     27/2/2022    ปี                               ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset     province  \
# 0                   ลำปาง        เมืองลำปาง        ลำปาง
# 1                   ลำปาง        เมืองลำปาง        ลำปาง
# 2                   ลำปาง          ห้างฉัตร        ลำปาง
# 3                   ลำปาง          ห้างฉัตร        ลำปาง
# 4                   ลำปาง        เมืองลำปาง        ลำปาง
# ...                   ...               ...          ...
# 1010454       ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล
# 1010455       ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล
# 1010456       ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล
# 1010457       ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล
# 1010458       ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล
#
#         6 ภูมิภาค (ภูมิศาสตร์)
# 0                        เหนือ
# 1                        เหนือ
# 2                        เหนือ
# 3                        เหนือ
# 4                        เหนือ
# ...                        ...
# 1010454            ไม่มีข้อมูล
# 1010455            ไม่มีข้อมูล
# 1010456            ไม่มีข้อมูล
# 1010457            ไม่มีข้อมูล
# 1010458            ไม่มีข้อมูล
#
# [1010459 rows x 7 columns]

# %% [markdown]
# ### ตารางข้อมูลจำนวนผู้ติดเชื้อช่วงที่ 4 และภูมิภาคจังหวัด

# %%
data_pro4 = data_04.merge(province_df,how='left',left_on='province_of_onset',right_on = 'province') 
data_pro4
# Out:
#        announce_date        age                                         risk  \
# 0          28/2/2022  41.000000  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1          28/2/2022  45.000000  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2          28/2/2022  40.000000  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 3          28/2/2022  44.000000  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 4          28/2/2022  11.000000  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...              ...        ...                                          ...
# 357076     15/3/2022  36.943725                             ทัณฑสถาน/เรือนจำ
# 357077     15/3/2022  36.943725                             ทัณฑสถาน/เรือนจำ
# 357078     15/3/2022  36.943725                             ทัณฑสถาน/เรือนจำ
# 357079     15/3/2022  36.943725                             ทัณฑสถาน/เรือนจำ
# 357080     15/3/2022  36.943725                             ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset province 6 ภูมิภาค (ภูมิศาสตร์)
# 0                  พะเยา        เมืองพะเยา    พะเยา                  เหนือ
# 1                  พะเยา        เมืองพะเยา    พะเยา                  เหนือ
# 2                  พะเยา        เมืองพะเยา    พะเยา                  เหนือ
# 3                  พะเยา        เมืองพะเยา    พะเยา                  เหนือ
# 4                  พะเยา        เมืองพะเยา    พะเยา                  เหนือ
# ...                  ...               ...      ...                    ...
# 357076       ไม่มีข้อมูล       ไม่มีข้อมูล      NaN                    NaN
# 357077       ไม่มีข้อมูล       ไม่มีข้อมูล      NaN                    NaN
# 357078       ไม่มีข้อมูล       ไม่มีข้อมูล      NaN                    NaN
# 357079       ไม่มีข้อมูล       ไม่มีข้อมูล      NaN                    NaN
# 357080       ไม่มีข้อมูล       ไม่มีข้อมูล      NaN                    NaN
#
# [357081 rows x 7 columns]

# %%
data_pro4.isnull().any()
# Out:
# announce_date             False
# age                       False
# risk                      False
# province_of_onset         False
# district_of_onset         False
# province                   True
# 6 ภูมิภาค (ภูมิศาสตร์)     True
# dtype: bool

# %%
data_pro004 = data_pro4.fillna(value={'province':'ไม่มีข้อมูล','6 ภูมิภาค (ภูมิศาสตร์)':'ไม่มีข้อมูล'})
data_pro004
# Out:
#        announce_date        age                                         risk  \
# 0          28/2/2022  41.000000  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1          28/2/2022  45.000000  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2          28/2/2022  40.000000  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 3          28/2/2022  44.000000  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 4          28/2/2022  11.000000  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...              ...        ...                                          ...
# 357076     15/3/2022  36.943725                             ทัณฑสถาน/เรือนจำ
# 357077     15/3/2022  36.943725                             ทัณฑสถาน/เรือนจำ
# 357078     15/3/2022  36.943725                             ทัณฑสถาน/เรือนจำ
# 357079     15/3/2022  36.943725                             ทัณฑสถาน/เรือนจำ
# 357080     15/3/2022  36.943725                             ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset     province 6 ภูมิภาค (ภูมิศาสตร์)
# 0                  พะเยา        เมืองพะเยา        พะเยา                  เหนือ
# 1                  พะเยา        เมืองพะเยา        พะเยา                  เหนือ
# 2                  พะเยา        เมืองพะเยา        พะเยา                  เหนือ
# 3                  พะเยา        เมืองพะเยา        พะเยา                  เหนือ
# 4                  พะเยา        เมืองพะเยา        พะเยา                  เหนือ
# ...                  ...               ...          ...                    ...
# 357076       ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล            ไม่มีข้อมูล
# 357077       ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล            ไม่มีข้อมูล
# 357078       ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล            ไม่มีข้อมูล
# 357079       ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล            ไม่มีข้อมูล
# 357080       ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล            ไม่มีข้อมูล
#
# [357081 rows x 7 columns]

# %% [markdown]
# # ข้อมูลรายชื่อห้องปฏิบัติการเครือข่ายตรวจโควิด-19

# %%
lab = pd.read_csv('labscovid19_update080365.csv', encoding="TIS-620") # TIS-620 คือ Decoding ที่เราใช้อ่านจาก file.csv แล้วนำค่ากลับมา Encodingเป็น UTF-8-sig เพื่อให้ตัว microsoft excel ในเครื่องเราที่มีdefault ในการอ่านค่าเป็น utf-8 อ่านได้ 
lab
# Out:
#                                         orgth  \
# 0     ศูนย์วิทยาศาสตร์การแพทย์ที่ 1 เชียงใหม่
# 1    ศูนย์วิทยาศาสตร์การแพทย์ที่ 1/1 เชียงราย
# 2     สำนักงานป้องกันควบคุมโรคที่ 1 เชียงใหม่
# 3                           โรงพยาบาลนครพิงค์
# 4                              โรงพยาบาลลำปาง
# ..                                        ...
# 508           งานอณูชีววิทยา โรงพยาบาลราชวิถี
# 509           งานจุลชีววิทยา โรงพยาบาลราชวิถี
# 510                        โรงพยาบาลประโคนชัย
# 511     กรุงเทพพยาธิ-แลป คลินิกเทคนิคการแพทย์
# 512            เอ็นเฮลท์ คลินิกเทคนิคการแพทย์
#
#                                                  orgen  \
# 0        Regional Medical Sciences Center 1 Chiang Mai
# 1      Regional Medical Sciences Center 1/1 Chiang Rai
# 2    The Office of Disease Prevention and Control 1...
# 3                                  Nakornping Hospital
# 4                                     Lampang Hospital
# ..                                                 ...
# 508                                                NaN
# 509                                                NaN
# 510                                                NaN
# 511                                                NaN
# 512                                                NaN
#
#                       telephone  \
# 0                0-5311-2188-90
# 1                 0-5317-6224-6
# 2                   0-5314-0774
# 3                  0-5399-9200
# 4                   0-5423-7400
# ..                          ...
# 508     0-2206-2900 ต่อ 40610-2
# 509  0-2206-2900 ต่อ 3142, 3143
# 510                 0-4467-0103
# 511                 0-2619-2909
# 512  0-2019-9921,  09-8650-6735
#
#                                                address  \
# 0      191 หมู่ 8 ต.ดอนแก้ว อ.แม่ริม จ.เชียงใหม่ 50180
# 1    148 หมู่ 3 ตำบลนางแล อำเภอเมือง จังหวัดเชียงรา...
# 2    447 ถนนเชียงใหม่-ลำพูน ตำบลวัดเกต อำเภอเมือง จ...
# 3    159 ม.10 ถ.โชตนา ต.ดอนแก้ว อ.แม่ริม จ.เชียงใหม...
# 4    28/3 ห้องอณูชีวโมเลกุล กลุ่มงานเทคนิคการแพทย์ ...
# ..                                                 ...
# 508                                                NaN
# 509                                                NaN
# 510                                                NaN
# 511                                                NaN
# 512                                                NaN
#
#                                                website healtharea  agency  \
# 0    http://webapp1.dmsc.moph.go.th/cm1/web/post-gr...      เขต 1  ภาครัฐ
# 1                          http://cri.dmsc.moph.go.th/      เขต 1  ภาครัฐ
# 2                        https://ddc.moph.go.th/odpc1/      เขต 1  ภาครัฐ
# 3                    http://www.nkp-hospital.go.th/th/      เขต 1  ภาครัฐ
# 4                          http://www.lph.go.th/lpweb/      เขต 1  ภาครัฐ
# ..                                                 ...        ...     ...
# 508  http://www.rajavithi.go.th/rj/medtech/biomolec...     เขต 13  ภาครัฐ
# 509  http://www.rajavithi.go.th/rj/medtech/microbio...     เขต 13  ภาครัฐ
# 510               https://www.facebook.com/pkchospital      เขต 9  ภาครัฐ
# 511                        https://www.bpl.co.th/pweb/     เขต 13   เอกชน
# 512         https://www.nhealth-asia.com/th/product/14     เขต 13   เอกชน
#
#           province        district               area         npsts  \
# 0        เชียงใหม่          แม่ริม        ต่างจังหวัด  เปิดตรวจแล้ว
# 1         เชียงราย   เมืองเชียงราย        ต่างจังหวัด  เปิดตรวจแล้ว
# 2        เชียงใหม่  เมืองเชียงใหม่        ต่างจังหวัด  เปิดตรวจแล้ว
# 3        เชียงใหม่          แม่ริม        ต่างจังหวัด  เปิดตรวจแล้ว
# 4            ลำปาง      เมืองลำปาง        ต่างจังหวัด  เปิดตรวจแล้ว
# ..             ...             ...                ...           ...
# 508  กรุงเทพมหานคร         ราชเทวี  กรุงเทพและปริมณฑล  เปิดตรวจแล้ว
# 509  กรุงเทพมหานคร         ราชเทวี  กรุงเทพและปริมณฑล  เปิดตรวจแล้ว
# 510      บุรีรัมย์       ประโคนชัย        ต่างจังหวัด  เปิดตรวจแล้ว
# 511  กรุงเทพมหานคร           พญาไท  กรุงเทพและปริมณฑล  เปิดตรวจแล้ว
# 512  กรุงเทพมหานคร           บางแค  กรุงเทพและปริมณฑล  เปิดตรวจแล้ว
#
#      pooledsaliva    pooledswab
# 0    เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 1    เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 2             NaN  เปิดตรวจแล้ว
# 3    เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 4    เปิดตรวจแล้ว  เปิดตรวจแล้ว
# ..            ...           ...
# 508           NaN           NaN
# 509           NaN           NaN
# 510           NaN           NaN
# 511           NaN           NaN
# 512           NaN           NaN
#
# [513 rows x 13 columns]

# %% [markdown]
# จากในตารางมีข้อมูลดังนี้
#
# *   orgth = ชื่อห้องปฏิบัติการภาษาไทย
# *   orgen = ชื่อห้องปฏิบัติการภาษาอังกฤษ
# *   telephone = หมายเลขโทรศัพท์
# *   address = ที่อยู่ของห้องปฏิบัติการ
# *   website = เว็บไซต์
# *   healtharea = เขต
# *   agency = หน่วยงาน
# *   province = จังหวัด
# *   district = อำเภอ
# *   area = บริเวณพื้นที่
# *   npsts = สถานะ (NPS+TS = การตรวจด้วยตัวอย่างป้ายหลังโพรงจมูก และป้ายลำคอ)
# *   pooledsaliva = สถานะ (การตรวจด้วยตัวอย่างน้ำลาย)
# *   pooledswab = สถานะ (การตรวจด้วยตัวอย่างในโพรงจมูก)

# %%
lab.isnull().any()
# Out:
# orgth           False
# orgen            True
# telephone        True
# address          True
# website          True
# healtharea      False
# agency          False
# province        False
# district         True
# area            False
# npsts           False
# pooledsaliva     True
# pooledswab       True
# dtype: bool

# %% [markdown]
# จากการตรวจสอบพบว่า มี column ที่มีค่า missing คือ
#
# *  orgen
# *  telephone
# *  address
# *  website
# *  district
# *  pooledsaliva
# *  pooledswab

# %% [markdown]
# ## แทน missing ด้วยค่าที่เหมาะสม (fillna())

# %%
lab_clean = lab.fillna(value={'orgen':'ไม่ระบุ','telephone':'ไม่ระบุ','address':'ไม่ระบุ','website':'ไม่ระบุ','district':'ไม่ระบุ','pooledsaliva':'ไม่ระบุ','pooledswab':'ไม่ระบุ'})
lab_clean
# Out:
#                                         orgth  \
# 0     ศูนย์วิทยาศาสตร์การแพทย์ที่ 1 เชียงใหม่
# 1    ศูนย์วิทยาศาสตร์การแพทย์ที่ 1/1 เชียงราย
# 2     สำนักงานป้องกันควบคุมโรคที่ 1 เชียงใหม่
# 3                           โรงพยาบาลนครพิงค์
# 4                              โรงพยาบาลลำปาง
# ..                                        ...
# 508           งานอณูชีววิทยา โรงพยาบาลราชวิถี
# 509           งานจุลชีววิทยา โรงพยาบาลราชวิถี
# 510                        โรงพยาบาลประโคนชัย
# 511     กรุงเทพพยาธิ-แลป คลินิกเทคนิคการแพทย์
# 512            เอ็นเฮลท์ คลินิกเทคนิคการแพทย์
#
#                                                  orgen  \
# 0        Regional Medical Sciences Center 1 Chiang Mai
# 1      Regional Medical Sciences Center 1/1 Chiang Rai
# 2    The Office of Disease Prevention and Control 1...
# 3                                  Nakornping Hospital
# 4                                     Lampang Hospital
# ..                                                 ...
# 508                                            ไม่ระบุ
# 509                                            ไม่ระบุ
# 510                                            ไม่ระบุ
# 511                                            ไม่ระบุ
# 512                                            ไม่ระบุ
#
#                       telephone  \
# 0                0-5311-2188-90
# 1                 0-5317-6224-6
# 2                   0-5314-0774
# 3                  0-5399-9200
# 4                   0-5423-7400
# ..                          ...
# 508     0-2206-2900 ต่อ 40610-2
# 509  0-2206-2900 ต่อ 3142, 3143
# 510                 0-4467-0103
# 511                 0-2619-2909
# 512  0-2019-9921,  09-8650-6735
#
#                                                address  \
# 0      191 หมู่ 8 ต.ดอนแก้ว อ.แม่ริม จ.เชียงใหม่ 50180
# 1    148 หมู่ 3 ตำบลนางแล อำเภอเมือง จังหวัดเชียงรา...
# 2    447 ถนนเชียงใหม่-ลำพูน ตำบลวัดเกต อำเภอเมือง จ...
# 3    159 ม.10 ถ.โชตนา ต.ดอนแก้ว อ.แม่ริม จ.เชียงใหม...
# 4    28/3 ห้องอณูชีวโมเลกุล กลุ่มงานเทคนิคการแพทย์ ...
# ..                                                 ...
# 508                                            ไม่ระบุ
# 509                                            ไม่ระบุ
# 510                                            ไม่ระบุ
# 511                                            ไม่ระบุ
# 512                                            ไม่ระบุ
#
#                                                website healtharea  agency  \
# 0    http://webapp1.dmsc.moph.go.th/cm1/web/post-gr...      เขต 1  ภาครัฐ
# 1                          http://cri.dmsc.moph.go.th/      เขต 1  ภาครัฐ
# 2                        https://ddc.moph.go.th/odpc1/      เขต 1  ภาครัฐ
# 3                    http://www.nkp-hospital.go.th/th/      เขต 1  ภาครัฐ
# 4                          http://www.lph.go.th/lpweb/      เขต 1  ภาครัฐ
# ..                                                 ...        ...     ...
# 508  http://www.rajavithi.go.th/rj/medtech/biomolec...     เขต 13  ภาครัฐ
# 509  http://www.rajavithi.go.th/rj/medtech/microbio...     เขต 13  ภาครัฐ
# 510               https://www.facebook.com/pkchospital      เขต 9  ภาครัฐ
# 511                        https://www.bpl.co.th/pweb/     เขต 13   เอกชน
# 512         https://www.nhealth-asia.com/th/product/14     เขต 13   เอกชน
#
#           province        district               area         npsts  \
# 0        เชียงใหม่          แม่ริม        ต่างจังหวัด  เปิดตรวจแล้ว
# 1         เชียงราย   เมืองเชียงราย        ต่างจังหวัด  เปิดตรวจแล้ว
# 2        เชียงใหม่  เมืองเชียงใหม่        ต่างจังหวัด  เปิดตรวจแล้ว
# 3        เชียงใหม่          แม่ริม        ต่างจังหวัด  เปิดตรวจแล้ว
# 4            ลำปาง      เมืองลำปาง        ต่างจังหวัด  เปิดตรวจแล้ว
# ..             ...             ...                ...           ...
# 508  กรุงเทพมหานคร         ราชเทวี  กรุงเทพและปริมณฑล  เปิดตรวจแล้ว
# 509  กรุงเทพมหานคร         ราชเทวี  กรุงเทพและปริมณฑล  เปิดตรวจแล้ว
# 510      บุรีรัมย์       ประโคนชัย        ต่างจังหวัด  เปิดตรวจแล้ว
# 511  กรุงเทพมหานคร           พญาไท  กรุงเทพและปริมณฑล  เปิดตรวจแล้ว
# 512  กรุงเทพมหานคร           บางแค  กรุงเทพและปริมณฑล  เปิดตรวจแล้ว
#
#      pooledsaliva    pooledswab
# 0    เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 1    เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 2         ไม่ระบุ  เปิดตรวจแล้ว
# 3    เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 4    เปิดตรวจแล้ว  เปิดตรวจแล้ว
# ..            ...           ...
# 508       ไม่ระบุ       ไม่ระบุ
# 509       ไม่ระบุ       ไม่ระบุ
# 510       ไม่ระบุ       ไม่ระบุ
# 511       ไม่ระบุ       ไม่ระบุ
# 512       ไม่ระบุ       ไม่ระบุ
#
# [513 rows x 13 columns]

# %%
lab_clean.isnull().any()
# Out:
# orgth           False
# orgen           False
# telephone       False
# address         False
# website         False
# healtharea      False
# agency          False
# province        False
# district        False
# area            False
# npsts           False
# pooledsaliva    False
# pooledswab      False
# dtype: bool

# %% [markdown]
# จากการเตรียมข้อมูลจะเห็นได้ว่า ข้อมูลรายชื่อห้องปฏิบัติการเครือข่ายตรวจโควิด-19 ไม่มีค่า missing แล้ว

# %% [markdown]
# ## dropna

# %%
#labdrop = pd.read_csv('labscovid19_update080365.csv', encoding="TIS-620") # TIS-620 คือ Decoding ที่เราใช้อ่านจาก file.csv แล้วนำค่ากลับมา Encodingเป็น UTF-8-sig เพื่อให้ตัว microsoft excel ในเครื่องเราที่มีdefault ในการอ่านค่าเป็น utf-8 อ่านได้

# %%
#labdrop_clean = labdrop.dropna()
#labdrop_clean

# %% [markdown]
# ## เลือกมาเฉพาะข้อมูลที่สนใจ

# %%
data_lab = lab_clean[['orgth','telephone','address','district','npsts','pooledsaliva','pooledswab','province']]
data_lab
# Out:
#                                         orgth                   telephone  \
# 0     ศูนย์วิทยาศาสตร์การแพทย์ที่ 1 เชียงใหม่              0-5311-2188-90
# 1    ศูนย์วิทยาศาสตร์การแพทย์ที่ 1/1 เชียงราย               0-5317-6224-6
# 2     สำนักงานป้องกันควบคุมโรคที่ 1 เชียงใหม่                 0-5314-0774
# 3                           โรงพยาบาลนครพิงค์                0-5399-9200
# 4                              โรงพยาบาลลำปาง                 0-5423-7400
# ..                                        ...                         ...
# 508           งานอณูชีววิทยา โรงพยาบาลราชวิถี     0-2206-2900 ต่อ 40610-2
# 509           งานจุลชีววิทยา โรงพยาบาลราชวิถี  0-2206-2900 ต่อ 3142, 3143
# 510                        โรงพยาบาลประโคนชัย                 0-4467-0103
# 511     กรุงเทพพยาธิ-แลป คลินิกเทคนิคการแพทย์                 0-2619-2909
# 512            เอ็นเฮลท์ คลินิกเทคนิคการแพทย์  0-2019-9921,  09-8650-6735
#
#                                                address        district  \
# 0      191 หมู่ 8 ต.ดอนแก้ว อ.แม่ริม จ.เชียงใหม่ 50180          แม่ริม
# 1    148 หมู่ 3 ตำบลนางแล อำเภอเมือง จังหวัดเชียงรา...   เมืองเชียงราย
# 2    447 ถนนเชียงใหม่-ลำพูน ตำบลวัดเกต อำเภอเมือง จ...  เมืองเชียงใหม่
# 3    159 ม.10 ถ.โชตนา ต.ดอนแก้ว อ.แม่ริม จ.เชียงใหม...          แม่ริม
# 4    28/3 ห้องอณูชีวโมเลกุล กลุ่มงานเทคนิคการแพทย์ ...      เมืองลำปาง
# ..                                                 ...             ...
# 508                                            ไม่ระบุ         ราชเทวี
# 509                                            ไม่ระบุ         ราชเทวี
# 510                                            ไม่ระบุ       ประโคนชัย
# 511                                            ไม่ระบุ           พญาไท
# 512                                            ไม่ระบุ           บางแค
#
#             npsts  pooledsaliva    pooledswab       province
# 0    เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว      เชียงใหม่
# 1    เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว       เชียงราย
# 2    เปิดตรวจแล้ว       ไม่ระบุ  เปิดตรวจแล้ว      เชียงใหม่
# 3    เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว      เชียงใหม่
# 4    เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว          ลำปาง
# ..            ...           ...           ...            ...
# 508  เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ  กรุงเทพมหานคร
# 509  เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ  กรุงเทพมหานคร
# 510  เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ      บุรีรัมย์
# 511  เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ  กรุงเทพมหานคร
# 512  เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ  กรุงเทพมหานคร
#
# [513 rows x 8 columns]

# %% [markdown]
# ### เช็คคำผิดของข้อมูลจังหวัด

# %%
set(lab_clean['province'])
# Out:
# {'กระบี่',
#  'กรุงเทพมหานคร',
#  'กาญจนบุรี',
#  'กาฬสินธุ์',
#  'กำแพงเพชร',
#  'ขอนแก่น',
#  'จันทบุรี',
#  'ฉะเชิงเทรา',
#  'ชลบุรี',
#  'ชัยนาท',
#  'ชัยภูมิ',
#  'ชุมพร',
#  'ตรัง',
#  'ตราด',
#  'ตาก',
#  'นครนายก',
#  'นครปฐม',
#  'นครพนม',
#  'นครราชสีมา',
#  'นครศรีธรรมราช',
#  'นครสวรรค์',
#  'นนทบุรี',
#  'นราธิวาส',
#  'น่าน',
#  'บึงกาฬ',
#  'บุรีรัมย์',
#  'ปทุมธานี',
#  'ประจวบคีรีขันธ์',
#  'ปราจีนบุรี',
#  'ปัตตานี',
#  'พระนครศรีอยุธยา',
#  'พะเยา',
#  'พังงา',
#  'พัทลุง',
#  'พิจิตร',
#  'พิษณุโลก',
#  'ภูเก็ต',
#  'มหาสารคาม',
#  'มุกดาหาร',
#  'ยะลา',
#  'ยโสธร',
#  'ระนอง',
#  'ระยอง',
#  'ราชบุรี',
#  'ร้อยเอ็ด',
#  'ลพบุรี',
#  'ลำปาง',
#  'ลำพูน',
#  'ศรีสะเกษ',
#  'สกลนคร',
#  'สงขลา',
#  'สตูล',
#  'สมุทรปราการ',
#  'สมุทรสงคราม',
#  'สมุทรสาคร',
#  'สระบุรี',
#  'สระแก้ว',
#  'สิงห์บุรี',
#  'สุพรรณบุรี',
#  'สุราษฎร์ธานี',
#  'สุรินทร์',
#  'สุโขทัย',
#  'หนองคาย',
#  'หนองบัวลำภู',
#  'อำนาจเจริญ',
#  'อุดรธานี',
#  'อุตรดิตถ์',
#  'อุทัยธานี',
#  'อุบลราชธานี',
#  'อ่างทอง',
#  'เชียงราย',
#  'เชียงใหม่',
#  'เพชรบุรี',
#  'เพชรบูรณ์',
#  'เลย',
#  'แพร่',
#  'แม่ฮ่องสอน'}

# %%
set(lab_clean['district'])
# Out:
# {'กบินทร์บุรี',
#  'กระทุ่มแบน',
#  'กระนวน',
#  'กระบุรี',
#  'กะทู้',
#  'กันทรลักษณ์',
#  'กาญจนดิษฐ์',
#  'กุมภวาปี',
#  'ขุขันธ์',
#  'ครบุรี',
#  'คลองสาน',
#  'คลองหลวง',
#  'คลองเตย',
#  'ควนขนุน',
#  'คันนายาว',
#  'จตุจักร',
#  'จอมทอง',
#  'ชัยบาดาล',
#  'ชุมแพ',
#  'ดุสิต',
#  'ด่านช้าง',
#  'ตระการพืชผล',
#  'ตลิ่งชัน',
#  'ตะกั่วป่า',
#  'ตากใบ',
#  'ถลาง',
#  'ทวีวัฒนา',
#  'ทุ่งสง',
#  'ท่าบ่อ',
#  'ท่ามะกา',
#  'ท่ายาง',
#  'ท่าศาลา',
#  'ท่าสองยาง',
#  'ธนบุรี',
#  'ธัญบุรี',
#  'นากลาง',
#  'นางรอง',
#  'นาทวี',
#  'น้ำยืน',
#  'บัวใหญ่',
#  'บางกรวย',
#  'บางกอกน้อย',
#  'บางกะปิ',
#  'บางขุนเทียน',
#  'บางคอแหลม',
#  'บางซื่อ',
#  'บางนา',
#  'บางบอน',
#  'บางบัวทอง',
#  'บางบ่อ',
#  'บางปะกง',
#  'บางปะอิน',
#  'บางพลัด',
#  'บางพลี',
#  'บางรัก',
#  'บางละมุง',
#  'บางสะพาน',
#  'บางเขน',
#  'บางเสาธง',
#  'บางแค',
#  'บางใหญ่',
#  'บึงกุ่ม',
#  'บุณฑริก',
#  'บ้านนาสาร',
#  'บ้านหมี่',
#  'บ้านแพ้ว',
#  'บ้านแฮด',
#  'บ้านโป่ง',
#  'ปทุมวัน',
#  'ประเวศ',
#  'ประโคนชัย',
#  'ปราณบุรี',
#  'ปราสาท',
#  'ปลวกแดง',
#  'ปากช่อง',
#  'ปากท่อ',
#  'ปากพนัง',
#  'ปากเกร็ด',
#  'ป้อมปราบศัตรูพ่าย',
#  'ฝาง',
#  'พญาไท',
#  'พบพระ',
#  'พระนครศรีอยุธยา',
#  'พระประแดง',
#  'พระพุทธบาท',
#  'พระสมุทรเจดีย์',
#  'พระโขนง',
#  'พล',
#  'พิบูลมังสาหาร',
#  'พิมาย',
#  'พุทธมณฑล',
#  'พุนพิน',
#  'ภาษีเจริญ',
#  'ภูเขียว',
#  'มวกเหล็ก',
#  'มีนบุรี',
#  'ยะรัง',
#  'ยะหา',
#  'ยางตลาด',
#  'ยานนาวา',
#  'ระแงะ',
#  'ราชเทวี',
#  'รามัน',
#  'ลาดพร้าว',
#  'ลำปลายมาศ',
#  'ลำลูกกา',
#  'วังทองหลาง',
#  'วังสะพุง',
#  'วัฒนา',
#  'วานรนิวาส',
#  'วารินชำราบ',
#  'วิเชียรบุรี',
#  'ศรีมหาโพธิ',
#  'ศรีรัตนะ',
#  'ศรีราชา',
#  'ศรีสมเด็จ',
#  'ศรีสำโรง',
#  'ศีขรภูมิ',
#  'สตึก',
#  'สมเด็จ',
#  'สวนหลวง',
#  'สว่างแดนดิน',
#  'สองพี่น้อง',
#  'สะพานสูง',
#  'สัตหีบ',
#  'สันกำแพง',
#  'สันทราย',
#  'สันป่าตอง',
#  'สาทร',
#  'สามพราน',
#  'สายบุรี',
#  'สายไหม',
#  'สิชล',
#  'สุวรรณภูมิ',
#  'สุไหงโก-ลก',
#  'หนองแขม',
#  'หนองแค',
#  'หลักสี่',
#  'หลังสวน',
#  'หัวหิน',
#  'หาดใหญ่',
#  'ห้วยขวาง',
#  'องครักษ์',
#  'อรัญประเทศ',
#  'อำเภอเมืองหนองคาย',
#  'อุทัย',
#  'อุทุมพรพิสัย',
#  'อุ้มผาง',
#  'เกษตรวิสัย',
#  'เกาะพะงัน',
#  'เกาะสมุย',
#  'เขื่องใน',
#  'เชียงคาน',
#  'เชียงคำ',
#  'เซกา',
#  'เดชอุดม',
#  'เบตง',
#  'เมือง',
#  'เมืองกระบี่',
#  'เมืองกาญจนบุรี',
#  'เมืองกาฬสินธุ์',
#  'เมืองกำแพงเพชร',
#  'เมืองขอนแก่น',
#  'เมืองจันทบุรี',
#  'เมืองฉะเชิงเทรา',
#  'เมืองชลบุรี',
#  'เมืองชัยนาท',
#  'เมืองชัยภูมิ',
#  'เมืองชุมพร',
#  'เมืองตรัง',
#  'เมืองตราด',
#  'เมืองตาก',
#  'เมืองนครนายก',
#  'เมืองนครปฐม',
#  'เมืองนครพนม',
#  'เมืองนครราชสีมา',
#  'เมืองนครศรีธรรมราช',
#  'เมืองนครสวรรค์',
#  'เมืองนนทบุรี',
#  'เมืองนราธิวาส',
#  'เมืองน่าน',
#  'เมืองบึงกาฬ',
#  'เมืองบุรีรัมย์',
#  'เมืองปทุมธานี',
#  'เมืองประจวบคีรีขันธ์',
#  'เมืองปราจีนบุรี',
#  'เมืองปัตตานี',
#  'เมืองพะเยา',
#  'เมืองพังงา',
#  'เมืองพัทลุง',
#  'เมืองพิจิตร',
#  'เมืองพิษณุโลก',
#  'เมืองภูเก็ต',
#  'เมืองมหาสารคาม',
#  'เมืองมุกดาหาร',
#  'เมืองยะลา',
#  'เมืองยโสธร',
#  'เมืองระนอง',
#  'เมืองระยอง',
#  'เมืองราชบุรี',
#  'เมืองร้อยเอ็ด',
#  'เมืองลพบุรี',
#  'เมืองลำปาง',
#  'เมืองลำพูน',
#  'เมืองศรีสะเกษ',
#  'เมืองสกลนคร',
#  'เมืองสงขลา',
#  'เมืองสตูล',
#  'เมืองสมุทรปราการ',
#  'เมืองสมุทรสงคราม',
#  'เมืองสมุทรสาคร',
#  'เมืองสระบุรี',
#  'เมืองสระแก้ว',
#  'เมืองสิงห์บุรี',
#  'เมืองสุพรรณบุรี',
#  'เมืองสุราษฎร์ธานี',
#  'เมืองสุรินทร์',
#  'เมืองสุโขทัย',
#  'เมืองหนองคาย',
#  'เมืองหนองบัวลำภู',
#  'เมืองอำนาจเจริญ',
#  'เมืองอุดรธานี',
#  'เมืองอุตรดิตถ์',
#  'เมืองอุทัยธานี',
#  'เมืองอุบลราชธานี',
#  'เมืองอ่างทอง',
#  'เมืองเชียงราย',
#  'เมืองเชียงใหม่',
#  'เมืองเพชรบุรี',
#  'เมืองเพชรบูรณ์',
#  'เมืองเลย',
#  'เมืองแพร่',
#  'เมืองแม่ฮ่องสอน',
#  'เวียงสระ',
#  'เสนา',
#  'แม่ระมาด',
#  'แม่ริม',
#  'แม่สอด',
#  'โคกโพธิ์',
#  'โพธาราม',
#  'โพนทอง',
#  'ไทรน้อย',
#  'ไม่ระบุ'}

# %% [markdown]
# # รวมตารางข้อมูลจำนวนผู้ติดเชื้อกับข้อมูลห้องLab

# %% [markdown]
# # ไม่ต้องเอาลงสไลด์ จนถึงตารางข้อมูลจำนวนผู้ติดเชื้อช่วงที่ 4 กับข้อมูลห้องLab

# %% [markdown]
# ## ตารางข้อมูลจำนวนผู้ติดเชื้อช่วงที่ 1 กับข้อมูลห้องLab

# %%
data_pro_lab = data_pro001.merge(data_lab,how='left',left_on='district_of_onset',right_on = 'district') 
data_pro_lab
# Out:
#         announce_date   age                              risk  \
# 0           12/1/2020  61.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1           17/1/2020  74.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2           22/1/2020  73.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3           22/1/2020  73.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4           22/1/2020  68.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...               ...   ...                               ...
# 2034500     12/8/2021  52.0                  ทัณฑสถาน/เรือนจำ
# 2034501     12/8/2021  34.0                  ทัณฑสถาน/เรือนจำ
# 2034502     12/8/2021  31.0                  ทัณฑสถาน/เรือนจำ
# 2034503     12/8/2021  83.0                  ทัณฑสถาน/เรือนจำ
# 2034504     12/8/2021  47.0                  ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset     province_x  \
# 0           กรุงเทพมหานคร       ไม่มีข้อมูล  กรุงเทพมหานคร
# 1           กรุงเทพมหานคร       ไม่มีข้อมูล  กรุงเทพมหานคร
# 2                  นครปฐม             เมือง         นครปฐม
# 3                  นครปฐม             เมือง         นครปฐม
# 4           กรุงเทพมหานคร       ไม่มีข้อมูล  กรุงเทพมหานคร
# ...                   ...               ...            ...
# 2034500         กาญจนบุรี       ไม่มีข้อมูล      กาญจนบุรี
# 2034501         กาญจนบุรี       ไม่มีข้อมูล      กาญจนบุรี
# 2034502         กาญจนบุรี       ไม่มีข้อมูล      กาญจนบุรี
# 2034503         กาญจนบุรี       ไม่มีข้อมูล      กาญจนบุรี
# 2034504         กาญจนบุรี       ไม่มีข้อมูล      กาญจนบุรี
#
#         6 ภูมิภาค (ภูมิศาสตร์)  \
# 0                         กลาง
# 1                         กลาง
# 2                         กลาง
# 3                         กลาง
# 4                         กลาง
# ...                        ...
# 2034500                ตะวันตก
# 2034501                ตะวันตก
# 2034502                ตะวันตก
# 2034503                ตะวันตก
# 2034504                ตะวันตก
#
#                                                      orgth          telephone  \
# 0                                                      NaN                NaN
# 1                                                      NaN                NaN
# 2                                        โรงพยาบาลราชพฤกษ์        0-4333-3555
# 3        บริษัท เนชั่นแนล เฮลท์แคร์ ซิสเท็มส์ จำกัด สาข...  076298298 ต่อ5111
# 4                                                      NaN                NaN
# ...                                                    ...                ...
# 2034500                                                NaN                NaN
# 2034501                                                NaN                NaN
# 2034502                                                NaN                NaN
# 2034503                                                NaN                NaN
# 2034504                                                NaN                NaN
#
#                                                    address district  \
# 0                                                      NaN      NaN
# 1                                                      NaN      NaN
# 2        456 หมู่ 14 ถนนมิตรภาพ ตำบลในเมือง อำเภอเมือง ...    เมือง
# 3                                                  ไม่ระบุ    เมือง
# 4                                                      NaN      NaN
# ...                                                    ...      ...
# 2034500                                                NaN      NaN
# 2034501                                                NaN      NaN
# 2034502                                                NaN      NaN
# 2034503                                                NaN      NaN
# 2034504                                                NaN      NaN
#
#                 npsts pooledsaliva pooledswab province_y
# 0                 NaN          NaN        NaN        NaN
# 1                 NaN          NaN        NaN        NaN
# 2        เปิดตรวจแล้ว      ไม่ระบุ    ไม่ระบุ    ขอนแก่น
# 3        เปิดตรวจแล้ว      ไม่ระบุ    ไม่ระบุ     ภูเก็ต
# 4                 NaN          NaN        NaN        NaN
# ...               ...          ...        ...        ...
# 2034500           NaN          NaN        NaN        NaN
# 2034501           NaN          NaN        NaN        NaN
# 2034502           NaN          NaN        NaN        NaN
# 2034503           NaN          NaN        NaN        NaN
# 2034504           NaN          NaN        NaN        NaN
#
# [2034505 rows x 15 columns]

# %%
data_pro_labdp = data_pro_lab.dropna() 
data_pro_labdp
# Out:
#         announce_date   age  \
# 2           22/1/2020  73.0
# 3           22/1/2020  73.0
# 8           26/1/2020  73.0
# 14          28/1/2020  32.0
# 15          28/1/2020  32.0
# ...               ...   ...
# 2034125     12/8/2021  43.0
# 2034126     12/8/2021  74.0
# 2034127     12/8/2021  29.0
# 2034128     12/8/2021  29.0
# 2034129     12/8/2021  29.0
#
#                                                       risk province_of_onset  \
# 2                         คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3                         คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 8                         คนต่างชาติเดินทางมาจากต่างประเทศ   ประจวบคีรีขันธ์
# 14                        คนต่างชาติเดินทางมาจากต่างประเทศ            ภูเก็ต
# 15                        คนต่างชาติเดินทางมาจากต่างประเทศ            ภูเก็ต
# ...                                                    ...               ...
# 2034125      ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว     กรุงเทพมหานคร
# 2034126      ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว     กรุงเทพมหานคร
# 2034127  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...     กรุงเทพมหานคร
# 2034128  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...     กรุงเทพมหานคร
# 2034129  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...     กรุงเทพมหานคร
#
#         district_of_onset       province_x 6 ภูมิภาค (ภูมิศาสตร์)  \
# 2                   เมือง           นครปฐม                   กลาง
# 3                   เมือง           นครปฐม                   กลาง
# 8                  หัวหิน  ประจวบคีรีขันธ์                ตะวันตก
# 14                  เมือง           ภูเก็ต                    ใต้
# 15                  เมือง           ภูเก็ต                    ใต้
# ...                   ...              ...                    ...
# 2034125            ประเวศ    กรุงเทพมหานคร                   กลาง
# 2034126            ธนบุรี    กรุงเทพมหานคร                   กลาง
# 2034127            ประเวศ    กรุงเทพมหานคร                   กลาง
# 2034128            ประเวศ    กรุงเทพมหานคร                   กลาง
# 2034129            ประเวศ    กรุงเทพมหานคร                   กลาง
#
#                                                      orgth  \
# 2                                        โรงพยาบาลราชพฤกษ์
# 3        บริษัท เนชั่นแนล เฮลท์แคร์ ซิสเท็มส์ จำกัด สาข...
# 8                                          โรงพยาบาลหัวหิน
# 14                                       โรงพยาบาลราชพฤกษ์
# 15       บริษัท เนชั่นแนล เฮลท์แคร์ ซิสเท็มส์ จำกัด สาข...
# ...                                                    ...
# 2034125            คลินิกเทคนิคการแพทย์ ฟีนิกซ์ โมเลกุลาร์
# 2034126                        โรงพยาบาลสมเด็จพระปิ่นเกล้า
# 2034127                                  โรงพยาบาลสิรินธร
# 2034128                      โรงพยาบาลสินแพทย์ ศรีนครินทร์
# 2034129            คลินิกเทคนิคการแพทย์ ฟีนิกซ์ โมเลกุลาร์
#
#                      telephone  \
# 2                  0-4333-3555
# 3            076298298 ต่อ5111
# 8                  0-3252-3000
# 14                 0-4333-3555
# 15           076298298 ต่อ5111
# ...                        ...
# 2034125            080-0064557
# 2034126  0-2460-0000 ต่อ 41592
# 2034127            0-2328-6901
# 2034128            0-2006-8888
# 2034129            080-0064557
#
#                                                    address district  \
# 2        456 หมู่ 14 ถนนมิตรภาพ ตำบลในเมือง อำเภอเมือง ...    เมือง
# 3                                                  ไม่ระบุ    เมือง
# 8        กลุ่มงานเทคนิคการแพทย์ 30/2 ต.หัวหิน อ.หัวหิน ...   หัวหิน
# 14       456 หมู่ 14 ถนนมิตรภาพ ตำบลในเมือง อำเภอเมือง ...    เมือง
# 15                                                 ไม่ระบุ    เมือง
# ...                                                    ...      ...
# 2034125                                            ไม่ระบุ   ประเวศ
# 2034126  504 กลุ่มงานพยาธิวิทยา รพ.สมเด็จพระปิ่นเกล้า พ...   ธนบุรี
# 2034127  20 ซอย อ่อนนุช 90 แขวง ประเวศ เขต ประเวศ กรุงเ...   ประเวศ
# 2034128                                            ไม่ระบุ   ประเวศ
# 2034129                                            ไม่ระบุ   ประเวศ
#
#                 npsts  pooledsaliva    pooledswab       province_y
# 2        เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ          ขอนแก่น
# 3        เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ           ภูเก็ต
# 8        เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว  ประจวบคีรีขันธ์
# 14       เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ          ขอนแก่น
# 15       เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ           ภูเก็ต
# ...               ...           ...           ...              ...
# 2034125  เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว    กรุงเทพมหานคร
# 2034126  เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว    กรุงเทพมหานคร
# 2034127  เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ    กรุงเทพมหานคร
# 2034128  เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ    กรุงเทพมหานคร
# 2034129  เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว    กรุงเทพมหานคร
#
# [1674243 rows x 15 columns]

# %%
data_pro_labdp.shape #ขนาดของตาราง dropna
# Out:
# (1674243, 15)

# %%
removes = data_pro_lab.shape[0] - data_pro_labdp.shape[0]
print(f'size before drop = {data_pro_lab.shape[0]}')
print(f'size after drop = {data_pro_labdp.shape[0]}')
print(f'% from drop = {(removes/data_pro_lab.shape[0])*100}')
 #มีข้อมูลที่หายไป 17% ซึ่งสามารถยอมรับได้
# Out:
# size before drop = 2034505
# size after drop = 1674243
# % from drop = 17.707599637258202

# %%
data_pro_labcn = data_pro_lab.fillna(value={'orgth':'ไม่สามารถระบุได้','telephone':'ไม่สามารถระบุได้','address':'ไม่สามารถระบุได้','district':'ไม่สามารถระบุได้','npsts':'ไม่สามารถระบุได้','pooledsaliva':'ไม่สามารถระบุได้','pooledswab':'ไม่สามารถระบุได้'})
data_pro_labcn
# Out:
#         announce_date   age                              risk  \
# 0           12/1/2020  61.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1           17/1/2020  74.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2           22/1/2020  73.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3           22/1/2020  73.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4           22/1/2020  68.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...               ...   ...                               ...
# 2034500     12/8/2021  52.0                  ทัณฑสถาน/เรือนจำ
# 2034501     12/8/2021  34.0                  ทัณฑสถาน/เรือนจำ
# 2034502     12/8/2021  31.0                  ทัณฑสถาน/เรือนจำ
# 2034503     12/8/2021  83.0                  ทัณฑสถาน/เรือนจำ
# 2034504     12/8/2021  47.0                  ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset     province_x  \
# 0           กรุงเทพมหานคร       ไม่มีข้อมูล  กรุงเทพมหานคร
# 1           กรุงเทพมหานคร       ไม่มีข้อมูล  กรุงเทพมหานคร
# 2                  นครปฐม             เมือง         นครปฐม
# 3                  นครปฐม             เมือง         นครปฐม
# 4           กรุงเทพมหานคร       ไม่มีข้อมูล  กรุงเทพมหานคร
# ...                   ...               ...            ...
# 2034500         กาญจนบุรี       ไม่มีข้อมูล      กาญจนบุรี
# 2034501         กาญจนบุรี       ไม่มีข้อมูล      กาญจนบุรี
# 2034502         กาญจนบุรี       ไม่มีข้อมูล      กาญจนบุรี
# 2034503         กาญจนบุรี       ไม่มีข้อมูล      กาญจนบุรี
# 2034504         กาญจนบุรี       ไม่มีข้อมูล      กาญจนบุรี
#
#         6 ภูมิภาค (ภูมิศาสตร์)  \
# 0                         กลาง
# 1                         กลาง
# 2                         กลาง
# 3                         กลาง
# 4                         กลาง
# ...                        ...
# 2034500                ตะวันตก
# 2034501                ตะวันตก
# 2034502                ตะวันตก
# 2034503                ตะวันตก
# 2034504                ตะวันตก
#
#                                                      orgth          telephone  \
# 0                                         ไม่สามารถระบุได้   ไม่สามารถระบุได้
# 1                                         ไม่สามารถระบุได้   ไม่สามารถระบุได้
# 2                                        โรงพยาบาลราชพฤกษ์        0-4333-3555
# 3        บริษัท เนชั่นแนล เฮลท์แคร์ ซิสเท็มส์ จำกัด สาข...  076298298 ต่อ5111
# 4                                         ไม่สามารถระบุได้   ไม่สามารถระบุได้
# ...                                                    ...                ...
# 2034500                                   ไม่สามารถระบุได้   ไม่สามารถระบุได้
# 2034501                                   ไม่สามารถระบุได้   ไม่สามารถระบุได้
# 2034502                                   ไม่สามารถระบุได้   ไม่สามารถระบุได้
# 2034503                                   ไม่สามารถระบุได้   ไม่สามารถระบุได้
# 2034504                                   ไม่สามารถระบุได้   ไม่สามารถระบุได้
#
#                                                    address          district  \
# 0                                         ไม่สามารถระบุได้  ไม่สามารถระบุได้
# 1                                         ไม่สามารถระบุได้  ไม่สามารถระบุได้
# 2        456 หมู่ 14 ถนนมิตรภาพ ตำบลในเมือง อำเภอเมือง ...             เมือง
# 3                                                  ไม่ระบุ             เมือง
# 4                                         ไม่สามารถระบุได้  ไม่สามารถระบุได้
# ...                                                    ...               ...
# 2034500                                   ไม่สามารถระบุได้  ไม่สามารถระบุได้
# 2034501                                   ไม่สามารถระบุได้  ไม่สามารถระบุได้
# 2034502                                   ไม่สามารถระบุได้  ไม่สามารถระบุได้
# 2034503                                   ไม่สามารถระบุได้  ไม่สามารถระบุได้
# 2034504                                   ไม่สามารถระบุได้  ไม่สามารถระบุได้
#
#                     npsts      pooledsaliva        pooledswab province_y
# 0        ไม่สามารถระบุได้  ไม่สามารถระบุได้  ไม่สามารถระบุได้        NaN
# 1        ไม่สามารถระบุได้  ไม่สามารถระบุได้  ไม่สามารถระบุได้        NaN
# 2            เปิดตรวจแล้ว           ไม่ระบุ           ไม่ระบุ    ขอนแก่น
# 3            เปิดตรวจแล้ว           ไม่ระบุ           ไม่ระบุ     ภูเก็ต
# 4        ไม่สามารถระบุได้  ไม่สามารถระบุได้  ไม่สามารถระบุได้        NaN
# ...                   ...               ...               ...        ...
# 2034500  ไม่สามารถระบุได้  ไม่สามารถระบุได้  ไม่สามารถระบุได้        NaN
# 2034501  ไม่สามารถระบุได้  ไม่สามารถระบุได้  ไม่สามารถระบุได้        NaN
# 2034502  ไม่สามารถระบุได้  ไม่สามารถระบุได้  ไม่สามารถระบุได้        NaN
# 2034503  ไม่สามารถระบุได้  ไม่สามารถระบุได้  ไม่สามารถระบุได้        NaN
# 2034504  ไม่สามารถระบุได้  ไม่สามารถระบุได้  ไม่สามารถระบุได้        NaN
#
# [2034505 rows x 15 columns]

# %% [markdown]
# ## ตารางข้อมูลจำนวนผู้ติดเชื้อช่วงที่ 2 กับข้อมูลห้องLab

# %%
data_pro_lab2 = data_pro002.merge(data_lab,how='left',left_on='district_of_onset',right_on = 'district') 
data_pro_lab2
# Out:
#         announce_date   age                                         risk  \
# 0           12/8/2021   7.0                                        อื่นๆ
# 1           12/8/2021   1.0                                        อื่นๆ
# 2           12/8/2021  35.0                                        อื่นๆ
# 3           12/8/2021  33.0                                        อื่นๆ
# 4           12/8/2021  14.0  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...               ...   ...                                          ...
# 2389516    25/10/2021  45.0                             ทัณฑสถาน/เรือนจำ
# 2389517    25/10/2021  31.0                             ทัณฑสถาน/เรือนจำ
# 2389518    25/10/2021  31.0                             ทัณฑสถาน/เรือนจำ
# 2389519    25/10/2021  24.0                             ทัณฑสถาน/เรือนจำ
# 2389520    25/10/2021  25.0                             ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset   province_x  \
# 0             ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล
# 1             ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล
# 2             ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล
# 3             ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล
# 4             ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล
# ...                   ...               ...          ...
# 2389516       ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล
# 2389517       ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล
# 2389518       ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล
# 2389519       ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล
# 2389520       ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล
#
#         6 ภูมิภาค (ภูมิศาสตร์) orgth telephone address district npsts  \
# 0                  ไม่มีข้อมูล   NaN       NaN     NaN      NaN   NaN
# 1                  ไม่มีข้อมูล   NaN       NaN     NaN      NaN   NaN
# 2                  ไม่มีข้อมูล   NaN       NaN     NaN      NaN   NaN
# 3                  ไม่มีข้อมูล   NaN       NaN     NaN      NaN   NaN
# 4                  ไม่มีข้อมูล   NaN       NaN     NaN      NaN   NaN
# ...                        ...   ...       ...     ...      ...   ...
# 2389516            ไม่มีข้อมูล   NaN       NaN     NaN      NaN   NaN
# 2389517            ไม่มีข้อมูล   NaN       NaN     NaN      NaN   NaN
# 2389518            ไม่มีข้อมูล   NaN       NaN     NaN      NaN   NaN
# 2389519            ไม่มีข้อมูล   NaN       NaN     NaN      NaN   NaN
# 2389520            ไม่มีข้อมูล   NaN       NaN     NaN      NaN   NaN
#
#         pooledsaliva pooledswab province_y
# 0                NaN        NaN        NaN
# 1                NaN        NaN        NaN
# 2                NaN        NaN        NaN
# 3                NaN        NaN        NaN
# 4                NaN        NaN        NaN
# ...              ...        ...        ...
# 2389516          NaN        NaN        NaN
# 2389517          NaN        NaN        NaN
# 2389518          NaN        NaN        NaN
# 2389519          NaN        NaN        NaN
# 2389520          NaN        NaN        NaN
#
# [2389521 rows x 15 columns]

# %%
data_pro_lab2dp = data_pro_lab2.dropna() 
data_pro_lab2dp
# Out:
#         announce_date   age                                         risk  \
# 249         12/8/2021  48.0  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 250         12/8/2021  48.0  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 251         12/8/2021  19.0  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 252         12/8/2021  19.0  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 253         12/8/2021  37.0  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...               ...   ...                                          ...
# 2389315    25/10/2021  80.0                                        อื่นๆ
# 2389316    25/10/2021  67.0                                        อื่นๆ
# 2389317    25/10/2021  67.0                                        อื่นๆ
# 2389318    25/10/2021  53.0                                        อื่นๆ
# 2389319    25/10/2021  53.0                                        อื่นๆ
#
#         province_of_onset district_of_onset     province_x  \
# 249             เพชรบูรณ์    เมืองเพชรบูรณ์      เพชรบูรณ์
# 250             เพชรบูรณ์    เมืองเพชรบูรณ์      เพชรบูรณ์
# 251             เพชรบูรณ์    เมืองเพชรบูรณ์      เพชรบูรณ์
# 252             เพชรบูรณ์    เมืองเพชรบูรณ์      เพชรบูรณ์
# 253             เพชรบูรณ์    เมืองเพชรบูรณ์      เพชรบูรณ์
# ...                   ...               ...            ...
# 2389315     กรุงเทพมหานคร            สายไหม  กรุงเทพมหานคร
# 2389316     กรุงเทพมหานคร            สายไหม  กรุงเทพมหานคร
# 2389317     กรุงเทพมหานคร            สายไหม  กรุงเทพมหานคร
# 2389318     กรุงเทพมหานคร            สายไหม  กรุงเทพมหานคร
# 2389319     กรุงเทพมหานคร            สายไหม  กรุงเทพมหานคร
#
#         6 ภูมิภาค (ภูมิศาสตร์)                                orgth  \
# 249                       กลาง                   โรงพยาบาลเพชรบูรณ์
# 250                       กลาง                   โรงพยาบาลเพชรรัตน์
# 251                       กลาง                   โรงพยาบาลเพชรบูรณ์
# 252                       กลาง                   โรงพยาบาลเพชรรัตน์
# 253                       กลาง                   โรงพยาบาลเพชรบูรณ์
# ...                        ...                                  ...
# 2389315                   กลาง  โรงพยาบาล บี.แคร์ เมดิคอล เซ็นเตอร์
# 2389316                   กลาง              โรงพยาบาลภูมิพลอดุลยเดช
# 2389317                   กลาง  โรงพยาบาล บี.แคร์ เมดิคอล เซ็นเตอร์
# 2389318                   กลาง              โรงพยาบาลภูมิพลอดุลยเดช
# 2389319                   กลาง  โรงพยาบาล บี.แคร์ เมดิคอล เซ็นเตอร์
#
#               telephone                                            address  \
# 249         0-5671-7600      203 ถนนสามัคคีชัย อำเภอเมือง จังหวัดเพชรบูรณ์
# 250         0-5672-0680                                            ไม่ระบุ
# 251         0-5671-7600      203 ถนนสามัคคีชัย อำเภอเมือง จังหวัดเพชรบูรณ์
# 252         0-5672-0680                                            ไม่ระบุ
# 253         0-5671-7600      203 ถนนสามัคคีชัย อำเภอเมือง จังหวัดเพชรบูรณ์
# ...                 ...                                                ...
# 2389315  02-523-3360-71                                            ไม่ระบุ
# 2389316     0-2534-7647  ห้องปฏิบัติการจุลชีววิทยา อาคาร14 รพ.ภูมิพลอดุ...
# 2389317  02-523-3360-71                                            ไม่ระบุ
# 2389318     0-2534-7647  ห้องปฏิบัติการจุลชีววิทยา อาคาร14 รพ.ภูมิพลอดุ...
# 2389319  02-523-3360-71                                            ไม่ระบุ
#
#                district         npsts  pooledsaliva    pooledswab  \
# 249      เมืองเพชรบูรณ์  เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 250      เมืองเพชรบูรณ์  เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ
# 251      เมืองเพชรบูรณ์  เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 252      เมืองเพชรบูรณ์  เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ
# 253      เมืองเพชรบูรณ์  เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# ...                 ...           ...           ...           ...
# 2389315          สายไหม  เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ
# 2389316          สายไหม  เปิดตรวจแล้ว       ไม่ระบุ  เปิดตรวจแล้ว
# 2389317          สายไหม  เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ
# 2389318          สายไหม  เปิดตรวจแล้ว       ไม่ระบุ  เปิดตรวจแล้ว
# 2389319          สายไหม  เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ
#
#             province_y
# 249          เพชรบูรณ์
# 250          เพชรบูรณ์
# 251          เพชรบูรณ์
# 252          เพชรบูรณ์
# 253          เพชรบูรณ์
# ...                ...
# 2389315  กรุงเทพมหานคร
# 2389316  กรุงเทพมหานคร
# 2389317  กรุงเทพมหานคร
# 2389318  กรุงเทพมหานคร
# 2389319  กรุงเทพมหานคร
#
# [1949192 rows x 15 columns]

# %%
data_pro_lab2dp.shape #ขนาดของตาราง dropna
# Out:
# (1949192, 15)

# %%
removes = data_pro_lab2.shape[0] - data_pro_lab2dp.shape[0]
print(f'size before drop = {data_pro_lab2.shape[0]}')
print(f'size after drop = {data_pro_lab2dp.shape[0]}')
print(f'% from drop = {(removes/data_pro_lab2.shape[0])*100}')
 #มีข้อมูลที่หายไป 18% ซึ่งสามารถยอมรับได้
# Out:
# size before drop = 2389521
# size after drop = 1949192
# % from drop = 18.427500741780463

# %%
data_pro_labcn2 = data_pro_lab.fillna(value={'orgth':'ไม่สามารถระบุได้','telephone':'ไม่สามารถระบุได้','address':'ไม่สามารถระบุได้','district':'ไม่สามารถระบุได้','npsts':'ไม่สามารถระบุได้','pooledsaliva':'ไม่สามารถระบุได้','pooledswab':'ไม่สามารถระบุได้'})
data_pro_labcn2
# Out:
#         announce_date   age                              risk  \
# 0           12/1/2020  61.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1           17/1/2020  74.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2           22/1/2020  73.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3           22/1/2020  73.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4           22/1/2020  68.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...               ...   ...                               ...
# 2034500     12/8/2021  52.0                  ทัณฑสถาน/เรือนจำ
# 2034501     12/8/2021  34.0                  ทัณฑสถาน/เรือนจำ
# 2034502     12/8/2021  31.0                  ทัณฑสถาน/เรือนจำ
# 2034503     12/8/2021  83.0                  ทัณฑสถาน/เรือนจำ
# 2034504     12/8/2021  47.0                  ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset     province_x  \
# 0           กรุงเทพมหานคร       ไม่มีข้อมูล  กรุงเทพมหานคร
# 1           กรุงเทพมหานคร       ไม่มีข้อมูล  กรุงเทพมหานคร
# 2                  นครปฐม             เมือง         นครปฐม
# 3                  นครปฐม             เมือง         นครปฐม
# 4           กรุงเทพมหานคร       ไม่มีข้อมูล  กรุงเทพมหานคร
# ...                   ...               ...            ...
# 2034500         กาญจนบุรี       ไม่มีข้อมูล      กาญจนบุรี
# 2034501         กาญจนบุรี       ไม่มีข้อมูล      กาญจนบุรี
# 2034502         กาญจนบุรี       ไม่มีข้อมูล      กาญจนบุรี
# 2034503         กาญจนบุรี       ไม่มีข้อมูล      กาญจนบุรี
# 2034504         กาญจนบุรี       ไม่มีข้อมูล      กาญจนบุรี
#
#         6 ภูมิภาค (ภูมิศาสตร์)  \
# 0                         กลาง
# 1                         กลาง
# 2                         กลาง
# 3                         กลาง
# 4                         กลาง
# ...                        ...
# 2034500                ตะวันตก
# 2034501                ตะวันตก
# 2034502                ตะวันตก
# 2034503                ตะวันตก
# 2034504                ตะวันตก
#
#                                                      orgth          telephone  \
# 0                                         ไม่สามารถระบุได้   ไม่สามารถระบุได้
# 1                                         ไม่สามารถระบุได้   ไม่สามารถระบุได้
# 2                                        โรงพยาบาลราชพฤกษ์        0-4333-3555
# 3        บริษัท เนชั่นแนล เฮลท์แคร์ ซิสเท็มส์ จำกัด สาข...  076298298 ต่อ5111
# 4                                         ไม่สามารถระบุได้   ไม่สามารถระบุได้
# ...                                                    ...                ...
# 2034500                                   ไม่สามารถระบุได้   ไม่สามารถระบุได้
# 2034501                                   ไม่สามารถระบุได้   ไม่สามารถระบุได้
# 2034502                                   ไม่สามารถระบุได้   ไม่สามารถระบุได้
# 2034503                                   ไม่สามารถระบุได้   ไม่สามารถระบุได้
# 2034504                                   ไม่สามารถระบุได้   ไม่สามารถระบุได้
#
#                                                    address          district  \
# 0                                         ไม่สามารถระบุได้  ไม่สามารถระบุได้
# 1                                         ไม่สามารถระบุได้  ไม่สามารถระบุได้
# 2        456 หมู่ 14 ถนนมิตรภาพ ตำบลในเมือง อำเภอเมือง ...             เมือง
# 3                                                  ไม่ระบุ             เมือง
# 4                                         ไม่สามารถระบุได้  ไม่สามารถระบุได้
# ...                                                    ...               ...
# 2034500                                   ไม่สามารถระบุได้  ไม่สามารถระบุได้
# 2034501                                   ไม่สามารถระบุได้  ไม่สามารถระบุได้
# 2034502                                   ไม่สามารถระบุได้  ไม่สามารถระบุได้
# 2034503                                   ไม่สามารถระบุได้  ไม่สามารถระบุได้
# 2034504                                   ไม่สามารถระบุได้  ไม่สามารถระบุได้
#
#                     npsts      pooledsaliva        pooledswab province_y
# 0        ไม่สามารถระบุได้  ไม่สามารถระบุได้  ไม่สามารถระบุได้        NaN
# 1        ไม่สามารถระบุได้  ไม่สามารถระบุได้  ไม่สามารถระบุได้        NaN
# 2            เปิดตรวจแล้ว           ไม่ระบุ           ไม่ระบุ    ขอนแก่น
# 3            เปิดตรวจแล้ว           ไม่ระบุ           ไม่ระบุ     ภูเก็ต
# 4        ไม่สามารถระบุได้  ไม่สามารถระบุได้  ไม่สามารถระบุได้        NaN
# ...                   ...               ...               ...        ...
# 2034500  ไม่สามารถระบุได้  ไม่สามารถระบุได้  ไม่สามารถระบุได้        NaN
# 2034501  ไม่สามารถระบุได้  ไม่สามารถระบุได้  ไม่สามารถระบุได้        NaN
# 2034502  ไม่สามารถระบุได้  ไม่สามารถระบุได้  ไม่สามารถระบุได้        NaN
# 2034503  ไม่สามารถระบุได้  ไม่สามารถระบุได้  ไม่สามารถระบุได้        NaN
# 2034504  ไม่สามารถระบุได้  ไม่สามารถระบุได้  ไม่สามารถระบุได้        NaN
#
# [2034505 rows x 15 columns]

# %% [markdown]
# ## ตารางข้อมูลจำนวนผู้ติดเชื้อช่วงที่ 3 กับข้อมูลห้องLab

# %%
data_pro_lab3 = data_pro003.merge(data_lab,how='left',left_on='district_of_onset',right_on = 'district') 
data_pro_lab3
# Out:
#         announce_date   age              risk province_of_onset  \
# 0          26/10/2021  20.0             อื่นๆ             ลำปาง
# 1          26/10/2021  20.0             อื่นๆ             ลำปาง
# 2          26/10/2021  20.0             อื่นๆ             ลำปาง
# 3          26/10/2021  20.0             อื่นๆ             ลำปาง
# 4          26/10/2021  42.0             อื่นๆ             ลำปาง
# ...               ...   ...               ...               ...
# 2356223     27/2/2022    ปี  ทัณฑสถาน/เรือนจำ       ไม่มีข้อมูล
# 2356224     27/2/2022    ปี  ทัณฑสถาน/เรือนจำ       ไม่มีข้อมูล
# 2356225     27/2/2022    ปี  ทัณฑสถาน/เรือนจำ       ไม่มีข้อมูล
# 2356226     27/2/2022    ปี  ทัณฑสถาน/เรือนจำ       ไม่มีข้อมูล
# 2356227     27/2/2022    ปี  ทัณฑสถาน/เรือนจำ       ไม่มีข้อมูล
#
#         district_of_onset   province_x 6 ภูมิภาค (ภูมิศาสตร์)  \
# 0              เมืองลำปาง        ลำปาง                  เหนือ
# 1              เมืองลำปาง        ลำปาง                  เหนือ
# 2              เมืองลำปาง        ลำปาง                  เหนือ
# 3              เมืองลำปาง        ลำปาง                  เหนือ
# 4              เมืองลำปาง        ลำปาง                  เหนือ
# ...                   ...          ...                    ...
# 2356223       ไม่มีข้อมูล  ไม่มีข้อมูล            ไม่มีข้อมูล
# 2356224       ไม่มีข้อมูล  ไม่มีข้อมูล            ไม่มีข้อมูล
# 2356225       ไม่มีข้อมูล  ไม่มีข้อมูล            ไม่มีข้อมูล
# 2356226       ไม่มีข้อมูล  ไม่มีข้อมูล            ไม่มีข้อมูล
# 2356227       ไม่มีข้อมูล  ไม่มีข้อมูล            ไม่มีข้อมูล
#
#                                           orgth      telephone  \
# 0                                โรงพยาบาลลำปาง    0-5423-7400
# 1                 โรงพยาบาลเขลางค์นคร-ราม ลำปาง    0-5401-9619
# 2                          โรงพยาบาลมะเร็งลำปาง  0-5433-5262-8
# 3        เซ็นทรัลแล็บกรุ๊ป คลินิกเทคนิคการแพทย์        ไม่ระบุ
# 4                                โรงพยาบาลลำปาง    0-5423-7400
# ...                                         ...            ...
# 2356223                                     NaN            NaN
# 2356224                                     NaN            NaN
# 2356225                                     NaN            NaN
# 2356226                                     NaN            NaN
# 2356227                                     NaN            NaN
#
#                                                    address    district  \
# 0        28/3 ห้องอณูชีวโมเลกุล กลุ่มงานเทคนิคการแพทย์ ...  เมืองลำปาง
# 1        ห้องปฏิบัติการโรงพยาบาลเขลางค์นครราม 79/12 ถ.พ...  เมืองลำปาง
# 2        199 ถ. ลำปาง-งาว ตำบลพิชัย อำเภอเมือง จังหวัดล...  เมืองลำปาง
# 3        655/19-20 ถนนไฮเวย์-ลำปาง-งาว ตำบล หัวเวียง อำ...  เมืองลำปาง
# 4        28/3 ห้องอณูชีวโมเลกุล กลุ่มงานเทคนิคการแพทย์ ...  เมืองลำปาง
# ...                                                    ...         ...
# 2356223                                                NaN         NaN
# 2356224                                                NaN         NaN
# 2356225                                                NaN         NaN
# 2356226                                                NaN         NaN
# 2356227                                                NaN         NaN
#
#                 npsts  pooledsaliva    pooledswab province_y
# 0        เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว      ลำปาง
# 1        เปิดตรวจแล้ว       ไม่ระบุ  เปิดตรวจแล้ว      ลำปาง
# 2        เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ      ลำปาง
# 3        เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ      ลำปาง
# 4        เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว      ลำปาง
# ...               ...           ...           ...        ...
# 2356223           NaN           NaN           NaN        NaN
# 2356224           NaN           NaN           NaN        NaN
# 2356225           NaN           NaN           NaN        NaN
# 2356226           NaN           NaN           NaN        NaN
# 2356227           NaN           NaN           NaN        NaN
#
# [2356228 rows x 15 columns]

# %%
data_pro_lab3dp = data_pro_lab3.dropna() 
data_pro_lab3dp
# Out:
#         announce_date   age   risk province_of_onset district_of_onset  \
# 0          26/10/2021  20.0  อื่นๆ             ลำปาง        เมืองลำปาง
# 1          26/10/2021  20.0  อื่นๆ             ลำปาง        เมืองลำปาง
# 2          26/10/2021  20.0  อื่นๆ             ลำปาง        เมืองลำปาง
# 3          26/10/2021  20.0  อื่นๆ             ลำปาง        เมืองลำปาง
# 4          26/10/2021  42.0  อื่นๆ             ลำปาง        เมืองลำปาง
# ...               ...   ...    ...               ...               ...
# 2356139     27/2/2022  64.0  อื่นๆ     กรุงเทพมหานคร           ราชเทวี
# 2356140     27/2/2022  64.0  อื่นๆ     กรุงเทพมหานคร           ราชเทวี
# 2356141     27/2/2022  64.0  อื่นๆ     กรุงเทพมหานคร           ราชเทวี
# 2356142     27/2/2022  64.0  อื่นๆ     กรุงเทพมหานคร           ราชเทวี
# 2356143     27/2/2022  64.0  อื่นๆ     กรุงเทพมหานคร           ราชเทวี
#
#             province_x 6 ภูมิภาค (ภูมิศาสตร์)  \
# 0                ลำปาง                  เหนือ
# 1                ลำปาง                  เหนือ
# 2                ลำปาง                  เหนือ
# 3                ลำปาง                  เหนือ
# 4                ลำปาง                  เหนือ
# ...                ...                    ...
# 2356139  กรุงเทพมหานคร                   กลาง
# 2356140  กรุงเทพมหานคร                   กลาง
# 2356141  กรุงเทพมหานคร                   กลาง
# 2356142  กรุงเทพมหานคร                   กลาง
# 2356143  กรุงเทพมหานคร                   กลาง
#
#                                                      orgth  \
# 0                                           โรงพยาบาลลำปาง
# 1                            โรงพยาบาลเขลางค์นคร-ราม ลำปาง
# 2                                     โรงพยาบาลมะเร็งลำปาง
# 3                   เซ็นทรัลแล็บกรุ๊ป คลินิกเทคนิคการแพทย์
# 4                                           โรงพยาบาลลำปาง
# ...                                                    ...
# 2356139                  คลินิกเทคนิคการแพทย์ กรุงเทพจีโนม
# 2356140                               สถาบันมะเร็งแห่งชาติ
# 2356141  บริษัท เนชั่นแนล เฮลท์แคร์ ซิสเท็มส์ จำกัด สาข...
# 2356142                    งานอณูชีววิทยา โรงพยาบาลราชวิถี
# 2356143                    งานจุลชีววิทยา โรงพยาบาลราชวิถี
#
#                           telephone  \
# 0                       0-5423-7400
# 1                       0-5401-9619
# 2                     0-5433-5262-8
# 3                           ไม่ระบุ
# 4                       0-5423-7400
# ...                             ...
# 2356139                 0-2034-1544
# 2356140                 02 202 6800
# 2356141                 0-2201-4600
# 2356142     0-2206-2900 ต่อ 40610-2
# 2356143  0-2206-2900 ต่อ 3142, 3143
#
#                                                    address    district  \
# 0        28/3 ห้องอณูชีวโมเลกุล กลุ่มงานเทคนิคการแพทย์ ...  เมืองลำปาง
# 1        ห้องปฏิบัติการโรงพยาบาลเขลางค์นครราม 79/12 ถ.พ...  เมืองลำปาง
# 2        199 ถ. ลำปาง-งาว ตำบลพิชัย อำเภอเมือง จังหวัดล...  เมืองลำปาง
# 3        655/19-20 ถนนไฮเวย์-ลำปาง-งาว ตำบล หัวเวียง อำ...  เมืองลำปาง
# 4        28/3 ห้องอณูชีวโมเลกุล กลุ่มงานเทคนิคการแพทย์ ...  เมืองลำปาง
# ...                                                    ...         ...
# 2356139  39 ถนน พญาไท แขวง ถนนพญาไท เขตราชเทวี กรุงเทพม...     ราชเทวี
# 2356140                                            ไม่ระบุ     ราชเทวี
# 2356141                                            ไม่ระบุ     ราชเทวี
# 2356142                                            ไม่ระบุ     ราชเทวี
# 2356143                                            ไม่ระบุ     ราชเทวี
#
#                 npsts  pooledsaliva    pooledswab     province_y
# 0        เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว          ลำปาง
# 1        เปิดตรวจแล้ว       ไม่ระบุ  เปิดตรวจแล้ว          ลำปาง
# 2        เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ          ลำปาง
# 3        เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ          ลำปาง
# 4        เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว          ลำปาง
# ...               ...           ...           ...            ...
# 2356139  เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ  กรุงเทพมหานคร
# 2356140  เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ  กรุงเทพมหานคร
# 2356141  เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ  กรุงเทพมหานคร
# 2356142  เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ  กรุงเทพมหานคร
# 2356143  เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ  กรุงเทพมหานคร
#
# [1922044 rows x 15 columns]

# %%
data_pro_lab2dp.shape #ขนาดของตาราง dropna
# Out:
# (1949192, 15)

# %%
removes = data_pro_lab3.shape[0] - data_pro_lab3dp.shape[0]
print(f'size before drop = {data_pro_lab3.shape[0]}')
print(f'size after drop = {data_pro_lab3dp.shape[0]}')
print(f'% from drop = {(removes/data_pro_lab3.shape[0])*100}')
 #มีข้อมูลที่หายไป 18% ซึ่งสามารถยอมรับได้
# Out:
# size before drop = 2356228
# size after drop = 1922044
# % from drop = 18.427079213047296

# %%
data_pro_labcn3 = data_pro_lab.fillna(value={'orgth':'ไม่สามารถระบุได้','telephone':'ไม่สามารถระบุได้','address':'ไม่สามารถระบุได้','district':'ไม่สามารถระบุได้','npsts':'ไม่สามารถระบุได้','pooledsaliva':'ไม่สามารถระบุได้','pooledswab':'ไม่สามารถระบุได้'})
data_pro_labcn3
# Out:
#         announce_date   age                              risk  \
# 0           12/1/2020  61.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1           17/1/2020  74.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2           22/1/2020  73.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3           22/1/2020  73.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4           22/1/2020  68.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...               ...   ...                               ...
# 2034500     12/8/2021  52.0                  ทัณฑสถาน/เรือนจำ
# 2034501     12/8/2021  34.0                  ทัณฑสถาน/เรือนจำ
# 2034502     12/8/2021  31.0                  ทัณฑสถาน/เรือนจำ
# 2034503     12/8/2021  83.0                  ทัณฑสถาน/เรือนจำ
# 2034504     12/8/2021  47.0                  ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset     province_x  \
# 0           กรุงเทพมหานคร       ไม่มีข้อมูล  กรุงเทพมหานคร
# 1           กรุงเทพมหานคร       ไม่มีข้อมูล  กรุงเทพมหานคร
# 2                  นครปฐม             เมือง         นครปฐม
# 3                  นครปฐม             เมือง         นครปฐม
# 4           กรุงเทพมหานคร       ไม่มีข้อมูล  กรุงเทพมหานคร
# ...                   ...               ...            ...
# 2034500         กาญจนบุรี       ไม่มีข้อมูล      กาญจนบุรี
# 2034501         กาญจนบุรี       ไม่มีข้อมูล      กาญจนบุรี
# 2034502         กาญจนบุรี       ไม่มีข้อมูล      กาญจนบุรี
# 2034503         กาญจนบุรี       ไม่มีข้อมูล      กาญจนบุรี
# 2034504         กาญจนบุรี       ไม่มีข้อมูล      กาญจนบุรี
#
#         6 ภูมิภาค (ภูมิศาสตร์)  \
# 0                         กลาง
# 1                         กลาง
# 2                         กลาง
# 3                         กลาง
# 4                         กลาง
# ...                        ...
# 2034500                ตะวันตก
# 2034501                ตะวันตก
# 2034502                ตะวันตก
# 2034503                ตะวันตก
# 2034504                ตะวันตก
#
#                                                      orgth          telephone  \
# 0                                         ไม่สามารถระบุได้   ไม่สามารถระบุได้
# 1                                         ไม่สามารถระบุได้   ไม่สามารถระบุได้
# 2                                        โรงพยาบาลราชพฤกษ์        0-4333-3555
# 3        บริษัท เนชั่นแนล เฮลท์แคร์ ซิสเท็มส์ จำกัด สาข...  076298298 ต่อ5111
# 4                                         ไม่สามารถระบุได้   ไม่สามารถระบุได้
# ...                                                    ...                ...
# 2034500                                   ไม่สามารถระบุได้   ไม่สามารถระบุได้
# 2034501                                   ไม่สามารถระบุได้   ไม่สามารถระบุได้
# 2034502                                   ไม่สามารถระบุได้   ไม่สามารถระบุได้
# 2034503                                   ไม่สามารถระบุได้   ไม่สามารถระบุได้
# 2034504                                   ไม่สามารถระบุได้   ไม่สามารถระบุได้
#
#                                                    address          district  \
# 0                                         ไม่สามารถระบุได้  ไม่สามารถระบุได้
# 1                                         ไม่สามารถระบุได้  ไม่สามารถระบุได้
# 2        456 หมู่ 14 ถนนมิตรภาพ ตำบลในเมือง อำเภอเมือง ...             เมือง
# 3                                                  ไม่ระบุ             เมือง
# 4                                         ไม่สามารถระบุได้  ไม่สามารถระบุได้
# ...                                                    ...               ...
# 2034500                                   ไม่สามารถระบุได้  ไม่สามารถระบุได้
# 2034501                                   ไม่สามารถระบุได้  ไม่สามารถระบุได้
# 2034502                                   ไม่สามารถระบุได้  ไม่สามารถระบุได้
# 2034503                                   ไม่สามารถระบุได้  ไม่สามารถระบุได้
# 2034504                                   ไม่สามารถระบุได้  ไม่สามารถระบุได้
#
#                     npsts      pooledsaliva        pooledswab province_y
# 0        ไม่สามารถระบุได้  ไม่สามารถระบุได้  ไม่สามารถระบุได้        NaN
# 1        ไม่สามารถระบุได้  ไม่สามารถระบุได้  ไม่สามารถระบุได้        NaN
# 2            เปิดตรวจแล้ว           ไม่ระบุ           ไม่ระบุ    ขอนแก่น
# 3            เปิดตรวจแล้ว           ไม่ระบุ           ไม่ระบุ     ภูเก็ต
# 4        ไม่สามารถระบุได้  ไม่สามารถระบุได้  ไม่สามารถระบุได้        NaN
# ...                   ...               ...               ...        ...
# 2034500  ไม่สามารถระบุได้  ไม่สามารถระบุได้  ไม่สามารถระบุได้        NaN
# 2034501  ไม่สามารถระบุได้  ไม่สามารถระบุได้  ไม่สามารถระบุได้        NaN
# 2034502  ไม่สามารถระบุได้  ไม่สามารถระบุได้  ไม่สามารถระบุได้        NaN
# 2034503  ไม่สามารถระบุได้  ไม่สามารถระบุได้  ไม่สามารถระบุได้        NaN
# 2034504  ไม่สามารถระบุได้  ไม่สามารถระบุได้  ไม่สามารถระบุได้        NaN
#
# [2034505 rows x 15 columns]

# %% [markdown]
# ## ตารางข้อมูลจำนวนผู้ติดเชื้อช่วงที่ 4 กับข้อมูลห้องLab

# %%
data_pro_lab4 = data_pro004.merge(data_lab,how='left',left_on='district_of_onset',right_on = 'district') 
data_pro_lab4
# Out:
#        announce_date        age                                         risk  \
# 0          28/2/2022  41.000000  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1          28/2/2022  41.000000  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2          28/2/2022  45.000000  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 3          28/2/2022  45.000000  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 4          28/2/2022  40.000000  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...              ...        ...                                          ...
# 792016     15/3/2022  36.943725                             ทัณฑสถาน/เรือนจำ
# 792017     15/3/2022  36.943725                             ทัณฑสถาน/เรือนจำ
# 792018     15/3/2022  36.943725                             ทัณฑสถาน/เรือนจำ
# 792019     15/3/2022  36.943725                             ทัณฑสถาน/เรือนจำ
# 792020     15/3/2022  36.943725                             ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset   province_x  \
# 0                  พะเยา        เมืองพะเยา        พะเยา
# 1                  พะเยา        เมืองพะเยา        พะเยา
# 2                  พะเยา        เมืองพะเยา        พะเยา
# 3                  พะเยา        เมืองพะเยา        พะเยา
# 4                  พะเยา        เมืองพะเยา        พะเยา
# ...                  ...               ...          ...
# 792016       ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล
# 792017       ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล
# 792018       ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล
# 792019       ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล
# 792020       ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล
#
#        6 ภูมิภาค (ภูมิศาสตร์)              orgth        telephone  \
# 0                       เหนือ     โรงพยาบาลพะเยา      0-5440-9300
# 1                       เหนือ  โรงพยาบาลพะเยาราม  0-5441-1111\r\n
# 2                       เหนือ     โรงพยาบาลพะเยา      0-5440-9300
# 3                       เหนือ  โรงพยาบาลพะเยาราม  0-5441-1111\r\n
# 4                       เหนือ     โรงพยาบาลพะเยา      0-5440-9300
# ...                       ...                ...              ...
# 792016            ไม่มีข้อมูล                NaN              NaN
# 792017            ไม่มีข้อมูล                NaN              NaN
# 792018            ไม่มีข้อมูล                NaN              NaN
# 792019            ไม่มีข้อมูล                NaN              NaN
# 792020            ไม่มีข้อมูล                NaN              NaN
#
#                                                   address    district  \
# 0        269 ถ. พหลโยธิน ต.บ้านต๋อม อ.เมือง จ.พะเยา 56000  เมืองพะเยา
# 1       660 หมู่ 3 ตำบล ท่าวังทอง อำเภอ เมือง จังหวัด ...  เมืองพะเยา
# 2        269 ถ. พหลโยธิน ต.บ้านต๋อม อ.เมือง จ.พะเยา 56000  เมืองพะเยา
# 3       660 หมู่ 3 ตำบล ท่าวังทอง อำเภอ เมือง จังหวัด ...  เมืองพะเยา
# 4        269 ถ. พหลโยธิน ต.บ้านต๋อม อ.เมือง จ.พะเยา 56000  เมืองพะเยา
# ...                                                   ...         ...
# 792016                                                NaN         NaN
# 792017                                                NaN         NaN
# 792018                                                NaN         NaN
# 792019                                                NaN         NaN
# 792020                                                NaN         NaN
#
#                npsts  pooledsaliva    pooledswab province_y
# 0       เปิดตรวจแล้ว       ไม่ระบุ  เปิดตรวจแล้ว      พะเยา
# 1       เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว      พะเยา
# 2       เปิดตรวจแล้ว       ไม่ระบุ  เปิดตรวจแล้ว      พะเยา
# 3       เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว      พะเยา
# 4       เปิดตรวจแล้ว       ไม่ระบุ  เปิดตรวจแล้ว      พะเยา
# ...              ...           ...           ...        ...
# 792016           NaN           NaN           NaN        NaN
# 792017           NaN           NaN           NaN        NaN
# 792018           NaN           NaN           NaN        NaN
# 792019           NaN           NaN           NaN        NaN
# 792020           NaN           NaN           NaN        NaN
#
# [792021 rows x 15 columns]

# %%
data_pro_lab4.isnull().any()
# Out:
# announce_date             False
# age                       False
# risk                      False
# province_of_onset         False
# district_of_onset         False
# province_x                False
# 6 ภูมิภาค (ภูมิศาสตร์)    False
# orgth                      True
# telephone                  True
# address                    True
# district                   True
# npsts                      True
# pooledsaliva               True
# pooledswab                 True
# province_y                 True
# dtype: bool

# %%
data_pro_lab4dp = data_pro_lab4.dropna() 
data_pro_lab4dp
# Out:
#        announce_date   age                                         risk  \
# 0          28/2/2022  41.0  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1          28/2/2022  41.0  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2          28/2/2022  45.0  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 3          28/2/2022  45.0  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 4          28/2/2022  40.0  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...              ...   ...                                          ...
# 791962     15/3/2022  46.0                                        อื่นๆ
# 791963     15/3/2022  46.0                                        อื่นๆ
# 791964     15/3/2022  46.0                                        อื่นๆ
# 791965     15/3/2022  46.0                                        อื่นๆ
# 791966     15/3/2022  46.0                                        อื่นๆ
#
#        province_of_onset district_of_onset     province_x  \
# 0                  พะเยา        เมืองพะเยา          พะเยา
# 1                  พะเยา        เมืองพะเยา          พะเยา
# 2                  พะเยา        เมืองพะเยา          พะเยา
# 3                  พะเยา        เมืองพะเยา          พะเยา
# 4                  พะเยา        เมืองพะเยา          พะเยา
# ...                  ...               ...            ...
# 791962     กรุงเทพมหานคร          ห้วยขวาง  กรุงเทพมหานคร
# 791963     กรุงเทพมหานคร          ห้วยขวาง  กรุงเทพมหานคร
# 791964     กรุงเทพมหานคร          ห้วยขวาง  กรุงเทพมหานคร
# 791965     กรุงเทพมหานคร          ห้วยขวาง  กรุงเทพมหานคร
# 791966     กรุงเทพมหานคร          ห้วยขวาง  กรุงเทพมหานคร
#
#        6 ภูมิภาค (ภูมิศาสตร์)  \
# 0                       เหนือ
# 1                       เหนือ
# 2                       เหนือ
# 3                       เหนือ
# 4                       เหนือ
# ...                       ...
# 791962                   กลาง
# 791963                   กลาง
# 791964                   กลาง
# 791965                   กลาง
# 791966                   กลาง
#
#                                                     orgth  \
# 0                                          โรงพยาบาลพะเยา
# 1                                       โรงพยาบาลพะเยาราม
# 2                                          โรงพยาบาลพะเยา
# 3                                       โรงพยาบาลพะเยาราม
# 4                                          โรงพยาบาลพะเยา
# ...                                                   ...
# 791962                                โรงพยาบาลพระรามเก้า
# 791963  MIC Lab (บริษัทเมดิคอล อินโนเวชัน เซ็นเตอร์ จำ...
# 791964                                   โรงพยาบาลปิยะเวท
# 791965  บริษัทเนชั่นแนล เฮลท์แคร์ ซิสเท็มส์ จำกัด สาขา...
# 791966                                   โรงพยาบาลเพชรเวช
#
#                           telephone  \
# 0                       0-5440-9300
# 1                   0-5441-1111\r\n
# 2                       0-5440-9300
# 3                   0-5441-1111\r\n
# 4                       0-5440-9300
# ...                             ...
# 791962  0-2202-9999 ต่อ 11710-11712
# 791963                  0-2101-6345
# 791964                  0-2129-5555
# 791965        0-2467-1111 ต่อ 3284
# 791966                         1390
#
#                                                   address    district  \
# 0        269 ถ. พหลโยธิน ต.บ้านต๋อม อ.เมือง จ.พะเยา 56000  เมืองพะเยา
# 1       660 หมู่ 3 ตำบล ท่าวังทอง อำเภอ เมือง จังหวัด ...  เมืองพะเยา
# 2        269 ถ. พหลโยธิน ต.บ้านต๋อม อ.เมือง จ.พะเยา 56000  เมืองพะเยา
# 3       660 หมู่ 3 ตำบล ท่าวังทอง อำเภอ เมือง จังหวัด ...  เมืองพะเยา
# 4        269 ถ. พหลโยธิน ต.บ้านต๋อม อ.เมือง จ.พะเยา 56000  เมืองพะเยา
# ...                                                   ...         ...
# 791962  โรงพยาบาลพระรามเก้า เลขที่ 99 ถ.พระรามเก้า บาง...    ห้วยขวาง
# 791963  เลขที่ 7 ซอยจัดสรร ถนนสุทธิสารวินิจฉัย แขวงสาม...    ห้วยขวาง
# 791964  โรงพยาบาลปิยะเวท 998 ถนนริมคลองสามเสน แขวงบางะ...    ห้วยขวาง
# 791965  2301/2 ถนน เพชรบุรีตัดใหม่ แขวง บางกะปิ เขตห้ว...    ห้วยขวาง
# 791966  2469/13,15 ถ.เพชรบุรีตัดใหม่ ระหว่างแยก เอกมัย...    ห้วยขวาง
#
#                npsts  pooledsaliva    pooledswab     province_y
# 0       เปิดตรวจแล้ว       ไม่ระบุ  เปิดตรวจแล้ว          พะเยา
# 1       เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว          พะเยา
# 2       เปิดตรวจแล้ว       ไม่ระบุ  เปิดตรวจแล้ว          พะเยา
# 3       เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว          พะเยา
# 4       เปิดตรวจแล้ว       ไม่ระบุ  เปิดตรวจแล้ว          พะเยา
# ...              ...           ...           ...            ...
# 791962  เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ  กรุงเทพมหานคร
# 791963  เปิดตรวจแล้ว       ไม่ระบุ  เปิดตรวจแล้ว  กรุงเทพมหานคร
# 791964  เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ  กรุงเทพมหานคร
# 791965  เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ  กรุงเทพมหานคร
# 791966  เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ  กรุงเทพมหานคร
#
# [645469 rows x 15 columns]

# %%
data_pro_lab4dp.shape #ขนาดของตาราง dropna
# Out:
# (645469, 15)

# %%
removes = data_pro_lab4.shape[0] - data_pro_lab4dp.shape[0]
print(f'size before drop = {data_pro_lab4.shape[0]}')
print(f'size after drop = {data_pro_lab4dp.shape[0]}')
print(f'% from drop = {(removes/data_pro_lab4.shape[0])*100}')
 #มีข้อมูลที่หายไป 18% ซึ่งสามารถยอมรับได้
# Out:
# size before drop = 792021
# size after drop = 645469
# % from drop = 18.503549779614428

# %%
data_pro_labcn4 = data_pro_lab4.fillna(value={'orgth':'ไม่สามารถระบุได้','telephone':'ไม่สามารถระบุได้','address':'ไม่สามารถระบุได้','district':'ไม่สามารถระบุได้','npsts':'ไม่สามารถระบุได้','pooledsaliva':'ไม่สามารถระบุได้','pooledswab':'ไม่สามารถระบุได้'})
data_pro_labcn4
# Out:
#        announce_date        age                                         risk  \
# 0          28/2/2022  41.000000  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1          28/2/2022  41.000000  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2          28/2/2022  45.000000  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 3          28/2/2022  45.000000  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 4          28/2/2022  40.000000  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...              ...        ...                                          ...
# 792016     15/3/2022  36.943725                             ทัณฑสถาน/เรือนจำ
# 792017     15/3/2022  36.943725                             ทัณฑสถาน/เรือนจำ
# 792018     15/3/2022  36.943725                             ทัณฑสถาน/เรือนจำ
# 792019     15/3/2022  36.943725                             ทัณฑสถาน/เรือนจำ
# 792020     15/3/2022  36.943725                             ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset   province_x  \
# 0                  พะเยา        เมืองพะเยา        พะเยา
# 1                  พะเยา        เมืองพะเยา        พะเยา
# 2                  พะเยา        เมืองพะเยา        พะเยา
# 3                  พะเยา        เมืองพะเยา        พะเยา
# 4                  พะเยา        เมืองพะเยา        พะเยา
# ...                  ...               ...          ...
# 792016       ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล
# 792017       ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล
# 792018       ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล
# 792019       ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล
# 792020       ไม่มีข้อมูล       ไม่มีข้อมูล  ไม่มีข้อมูล
#
#        6 ภูมิภาค (ภูมิศาสตร์)              orgth         telephone  \
# 0                       เหนือ     โรงพยาบาลพะเยา       0-5440-9300
# 1                       เหนือ  โรงพยาบาลพะเยาราม   0-5441-1111\r\n
# 2                       เหนือ     โรงพยาบาลพะเยา       0-5440-9300
# 3                       เหนือ  โรงพยาบาลพะเยาราม   0-5441-1111\r\n
# 4                       เหนือ     โรงพยาบาลพะเยา       0-5440-9300
# ...                       ...                ...               ...
# 792016            ไม่มีข้อมูล   ไม่สามารถระบุได้  ไม่สามารถระบุได้
# 792017            ไม่มีข้อมูล   ไม่สามารถระบุได้  ไม่สามารถระบุได้
# 792018            ไม่มีข้อมูล   ไม่สามารถระบุได้  ไม่สามารถระบุได้
# 792019            ไม่มีข้อมูล   ไม่สามารถระบุได้  ไม่สามารถระบุได้
# 792020            ไม่มีข้อมูล   ไม่สามารถระบุได้  ไม่สามารถระบุได้
#
#                                                   address          district  \
# 0        269 ถ. พหลโยธิน ต.บ้านต๋อม อ.เมือง จ.พะเยา 56000        เมืองพะเยา
# 1       660 หมู่ 3 ตำบล ท่าวังทอง อำเภอ เมือง จังหวัด ...        เมืองพะเยา
# 2        269 ถ. พหลโยธิน ต.บ้านต๋อม อ.เมือง จ.พะเยา 56000        เมืองพะเยา
# 3       660 หมู่ 3 ตำบล ท่าวังทอง อำเภอ เมือง จังหวัด ...        เมืองพะเยา
# 4        269 ถ. พหลโยธิน ต.บ้านต๋อม อ.เมือง จ.พะเยา 56000        เมืองพะเยา
# ...                                                   ...               ...
# 792016                                   ไม่สามารถระบุได้  ไม่สามารถระบุได้
# 792017                                   ไม่สามารถระบุได้  ไม่สามารถระบุได้
# 792018                                   ไม่สามารถระบุได้  ไม่สามารถระบุได้
# 792019                                   ไม่สามารถระบุได้  ไม่สามารถระบุได้
# 792020                                   ไม่สามารถระบุได้  ไม่สามารถระบุได้
#
#                    npsts      pooledsaliva        pooledswab province_y
# 0           เปิดตรวจแล้ว           ไม่ระบุ      เปิดตรวจแล้ว      พะเยา
# 1           เปิดตรวจแล้ว      เปิดตรวจแล้ว      เปิดตรวจแล้ว      พะเยา
# 2           เปิดตรวจแล้ว           ไม่ระบุ      เปิดตรวจแล้ว      พะเยา
# 3           เปิดตรวจแล้ว      เปิดตรวจแล้ว      เปิดตรวจแล้ว      พะเยา
# 4           เปิดตรวจแล้ว           ไม่ระบุ      เปิดตรวจแล้ว      พะเยา
# ...                  ...               ...               ...        ...
# 792016  ไม่สามารถระบุได้  ไม่สามารถระบุได้  ไม่สามารถระบุได้        NaN
# 792017  ไม่สามารถระบุได้  ไม่สามารถระบุได้  ไม่สามารถระบุได้        NaN
# 792018  ไม่สามารถระบุได้  ไม่สามารถระบุได้  ไม่สามารถระบุได้        NaN
# 792019  ไม่สามารถระบุได้  ไม่สามารถระบุได้  ไม่สามารถระบุได้        NaN
# 792020  ไม่สามารถระบุได้  ไม่สามารถระบุได้  ไม่สามารถระบุได้        NaN
#
# [792021 rows x 15 columns]

# %%
#data_pro_labcn.to_csv('data01.csv', encoding='utf-8')

# %%
#data_pro_labcn2.to_csv('data02.csv', encoding='utf-8')

# %%
#data_pro_labcn3.to_csv('data03.csv', encoding='utf-8')

# %%
#data_pro_labcn4.to_csv('data04.csv', encoding='utf-8')

# %%
#data_pro_labcn4.to_csv('data_pro_labcn4.csv')

# %%
#case_pro_lab = data1234.merge(data_lab,how='left',left_on='province_of_onset',right_on = 'province') 
#case_pro_lab

# %%
##case_pro_labdp.to_csv('Project_otter.csv', encoding='utf-8')

# %% [markdown]
# # เอาตั้งแต่ลองลงไปจนสุด

# %% [markdown]
# # ลอง

# %%
data1234.head()
# Out:
#   announce_date   age                              risk province_of_onset  \
# 0     12/1/2020  61.0  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1     17/1/2020  74.0  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2     22/1/2020  73.0  คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3     22/1/2020  68.0  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4     24/1/2020  66.0  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
#
#   district_of_onset
# 0       ไม่มีข้อมูล
# 1       ไม่มีข้อมูล
# 2             เมือง
# 3       ไม่มีข้อมูล
# 4       ไม่มีข้อมูล

# %%
data1234['district_of_onset'].replace({'กิงอำเภอชัยบุรี':'อำเภอชัยบุรี','บ้านฝาง\n':'บ้านฝาง','-':'ไม่มีข้อมูล', 'อำเภอศรีราชา':'ศรีราชา','\xa0ประจันตคาม':'ประจันตคาม','บ่างกะปิ':'บางกะปิ','บางละมุง.':'บางละมุง',
 'ท่าศาลา/ปทุมธานี':'ท่าศาลา','วังโป่ง เพชรบูรณ์':'เมืองเพชรบูรณ์','คบองเตย':'คลองเตย', 'นตรไทย':'เมืองพิษณุโลก',
 'แพรกษา':'เมืองสมุทรปราการ', 'อ.หนองแขม กรุงเทพมหานคร.':'หนองแขม',  'รพ.น้ำหนาว':'เมืองเพชรบูรณ์',
 'ตลิ่งชีน':'ตลิ่งชัน', 'เมืองปทุมธานี\xa0':'เมืองปทุมธานี', 'ปลวดเเดง':'ปลวกเเดง', 'เขต ทวีวัฒนา':'ทวีวัฒนา',
 'ชุุมพลบุรี':'เมืองสุรินทร์', 'เขตปทุมวัน':'ปทุมวัน', 'วังกระโจม':'เมืองนครนายก', 'ค่ายบางระจัน':'เมืองสิงห์บุรี',
 'ด่านมะขามเตี้ย กาญจนบุรี':'เมืองกาญจนบุรี', 'บางเสาร์ธง':'บางเสาธง', 'ตลองหลวง':'คลองหลวง',
 'วััดหลวง':'วัดหลวง', 'เมืืองอุดรธานี':'เมืองอุดรธานี', 'พระโขนง กรุงเทพมหานคร':'พระโขนง',
 'ศีราชา':'ศรีราชา', 'บาง เสาธง':'บางเสาธง', 'ราษฏร์ลูรณะ':'ราษฎร์บูรณะ', 'สัามพราย':'สามพราน',
 'นครศรีธรรมราช':'เมืองนครศรีธรรมราช', 'พระโขนง\u200b':'พระโขนง', 'คอลเตย':'คลองเตย',
 'หันนายาว':'คันนายาว', 'ท่าปลา (พิชัย)':'ท่าปลา', 'ลำพยา':'เมืองนครปฐม', 'ต้าผามอก':'ลอง',
 'กำแพงแสน นฐ':'กำแพงแสน', 'เมืองสมุทรปราากร':'เมืองสมุทรปราการ', 'สาบยใหม่':'สายไหม',
 'กัณฑรลักษณ์':'กันทรลักษณ์', 'ลลาดหลุมแก้ว':'ลาดหลุมแก้ว', '2สองพี่น้อง':'สองพี่น้อง',
 'เมืองสมุทรสาค':'เมืองสมุทรสาคร', 'เขตบางกะปิ กรุงเทพมหานคร.':'บางกะปิ','กเกร็ด':'ปากเกร็ด',
 'หนองจอก กรุงเทพมหานคร':'หนองจอก', 'สัังขละบุรี':'สังขละบุรี', 'คองสามวา':'คลองสามวา',
 'กิ่งอำเภอบัวลาย':'บัวลาย', 'เจะไอร้อง':'เจาะไอร้อง', 'ท่าม่วงกาญจนบุรี':'ท่าม่วง', 'ห้วยผึ้ึ่ง':'ห้วยผึ้ง',
 'สานมพราน':'สามพราน', 'พังตรุ':'ท่าม่วง', 'งบ้านฉาง':'บ้านฉาง', 'บ้านผืือ':'บ้านผือ', 'รพ.หล่มสัก':'หล่มสัก',
 'อ.เขาย้อย จ.เพชรบุรี':'เขาย้อย', 'เขตดุสิต':'ดุสิต', 'พุมธมณฑล':'พุทธมณฑล', 'บางซิ่อ':'บางซื่อ',
 'ปากเพลียว':'ปากเกลียว', 'คลองหลวง /หนองแซง':'คลองหลวง', 'ลานสัก-Cupทัพทัน':'ลานสัก',
 'มโรมย์':'มโนรมย์', 'เขตปทุม':'ปทุมวัน', 'เขตจตุจักร':'จตุจักร', 'นหว้า':'นาหว้า', 'ตรอน ทุ่งเสลี่ยม':'ทุ่งเสลี่ยม',
 'ราษำร์บูรณะ':'ราษฎร์บูรณะ', 'ลากพร้าว':'ลาดพร้าว', 'อ.กะพ้อ':'กะพ้อ', 'อ.ปางศิลาทอง':'ปางศิลาทอง',
 'กิ่งอำเภอบางเสาธง':'บางเสาธง', 'เขตสาธร':'สาธร', 'หนองแขม กรุงเทพมหานคร':'หนองแขม',
 'บ้านโปาง':'บ้านโป่ง', 'ศรี\u200bราชา':'ศรีราชา', 'นบพิดำ':'นบพิตำ', 'อ.เชียรใหญ่':'เชียรใหญ่',
 'บางละมุงชลบุรี':'บางละมุง', 'เมืองปัตตานี-':'เมืองปัตตานี', 'วานรนิิวาส':'วานรนิวาส', 'เมืองศีรสะเกษ':'เมืองศรีสะเกษ',
 'บางประปิ':'บางกระปิ', 'เมืองจันทรบุรี':'เมืองจันทบุรี', 'กิ่งอำเภอโนนนารายณ์':'โนนนารายณ์',
 'เขาคิฌกูฏ':'เขาคิชฌกูฏ', 'บางน้ำเปริ้ยว':'บางน้ำเปรี้ยว', 'ท่าเรื่อ':'ท่าเรือ', 'เมืองนครศรีธรรมราข':'เมืองนครศรีธรรมราช',
 'เขตทุ่งครุ':'ทุ่งครุ', 'ท่่าบ่อ':'ท่าบ่อ', 'เมืองนนทบรี':'เมืองนนทบุรี',  'เขตบางเขน':'บางเขน',
 'อำเภอเมืองนนทบุรี':'เมืองนนทบุรี', 'ปรวกแดง':'ปลวกแดง', 'เขตบางนาตราด':'บางนาตราด',
 'อ.เมืองอำนาจเจริญ จ.อำนาจเจริญ':'เมืองอำนาจเจริญ', 'ศรีสวัสดิ์\xa0':'ศรีสวัสดิ์', 'เขตคลองขวาง':'คลองขวาง',
 'โพนพิสััย':'โพนพิสัย', 'เมืองอำนาจ':'เมืองอำนาจเจริญ', 'อ.สามพราน จ.นครปฐม':'สามพราน',
'เมืองจันทบุรี\xa0':'เมืองจันทบุรี', 'ป้อมปราบฯ':'ป้อมปราบศัตรูพ่าย', 'เปือยน้้อย':'เปือยน้อย',
 'เมืองกาฬสิินธุ์':'เมืองกาฬสินธุ์', 'อ.หนองฉาง  จ.อุทัยธานี':'หนองฉาง', 'หัวหมาก กรุงเทพมหานคร':'หัวหมาก',
 'เมืองฉะเชิงเมรา':'เมืองฉะเชิงเฉรา', 'หัวยคต':'ห้วยคต', 'เมืองขอนแก่่น':'เมืองขอนแก่น',
 'ทุ้งกระเบน':'คุ้งกระเบน', 'เขตคลองตัน':'คลองตัน', 'อ.ประเวศ กรุงเทพมหานคร.':'ประเวศ',
 'เขตทุ่งครู':'ทุ่งครู่', 'เมืองสตล':'เมืองสตูล', 'ดอนเมือง กรุงเทพ':'ดอนเมือง', 'เมืิอง':'เมือง',
 'สีีคิ้ว':'สีคิ้ว', 'ปากเกร็ดจ.นนทบุรี':'ปากเกร็ด', 'สองพีน้อง':'สองพี่น้อง', 'เมืืองมหาสารคาม':'เมืองมหาสารคาม',
 'เขตลาดกระบัง':'ลาดกระบัง', 'เขตปทุมเวศ กรุงเทพมหานคร':'ปทุมเวศ', 'เขตคลองมหานาค':'คลองมหานาค',
 'เมืองกาญฯ':'เมืองกาญจนบุรี', 'กันททรลักษ์':'กันทรลักษณ์', 'เมือง/กรุงเทพมหานคร':'เมือง',
 'อ.สวนผึ้ง':'สวนผึ้ง', 'บางเขน\xa0':'บางเขน', '\xa0เขตดินแดง':'ดินแดง', 'อ.บ้านไผ่':'บ้านไผ่',
 'สตูล':'เมืองสตูล', 'อ.เมืองปัตตานี':'เมืองปัตตานี', 'สมุทรปราการ':'เมืองสมุทรปราการ'}, inplace=True)

# %%
data1234.head()
# Out:
#   announce_date   age                              risk province_of_onset  \
# 0     12/1/2020  61.0  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1     17/1/2020  74.0  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2     22/1/2020  73.0  คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3     22/1/2020  68.0  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4     24/1/2020  66.0  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
#
#   district_of_onset
# 0       ไม่มีข้อมูล
# 1       ไม่มีข้อมูล
# 2             เมือง
# 3       ไม่มีข้อมูล
# 4       ไม่มีข้อมูล

# %%
data_t= data1234.merge(data_lab,how='left',left_on='district_of_onset',right_on = 'district') 
data_t
# Out:
#         announce_date        age                              risk  \
# 0           12/1/2020       61.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1           17/1/2020       74.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2           22/1/2020       73.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3           22/1/2020       73.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4           22/1/2020       68.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...               ...        ...                               ...
# 7577439     15/3/2022  36.943725                  ทัณฑสถาน/เรือนจำ
# 7577440     15/3/2022  36.943725                  ทัณฑสถาน/เรือนจำ
# 7577441     15/3/2022  36.943725                  ทัณฑสถาน/เรือนจำ
# 7577442     15/3/2022  36.943725                  ทัณฑสถาน/เรือนจำ
# 7577443     15/3/2022  36.943725                  ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset  \
# 0           กรุงเทพมหานคร       ไม่มีข้อมูล
# 1           กรุงเทพมหานคร       ไม่มีข้อมูล
# 2                  นครปฐม             เมือง
# 3                  นครปฐม             เมือง
# 4           กรุงเทพมหานคร       ไม่มีข้อมูล
# ...                   ...               ...
# 7577439       ไม่มีข้อมูล       ไม่มีข้อมูล
# 7577440       ไม่มีข้อมูล       ไม่มีข้อมูล
# 7577441       ไม่มีข้อมูล       ไม่มีข้อมูล
# 7577442       ไม่มีข้อมูล       ไม่มีข้อมูล
# 7577443       ไม่มีข้อมูล       ไม่มีข้อมูล
#
#                                                      orgth          telephone  \
# 0                                                      NaN                NaN
# 1                                                      NaN                NaN
# 2                                        โรงพยาบาลราชพฤกษ์        0-4333-3555
# 3        บริษัท เนชั่นแนล เฮลท์แคร์ ซิสเท็มส์ จำกัด สาข...  076298298 ต่อ5111
# 4                                                      NaN                NaN
# ...                                                    ...                ...
# 7577439                                                NaN                NaN
# 7577440                                                NaN                NaN
# 7577441                                                NaN                NaN
# 7577442                                                NaN                NaN
# 7577443                                                NaN                NaN
#
#                                                    address district  \
# 0                                                      NaN      NaN
# 1                                                      NaN      NaN
# 2        456 หมู่ 14 ถนนมิตรภาพ ตำบลในเมือง อำเภอเมือง ...    เมือง
# 3                                                  ไม่ระบุ    เมือง
# 4                                                      NaN      NaN
# ...                                                    ...      ...
# 7577439                                                NaN      NaN
# 7577440                                                NaN      NaN
# 7577441                                                NaN      NaN
# 7577442                                                NaN      NaN
# 7577443                                                NaN      NaN
#
#                 npsts pooledsaliva pooledswab province
# 0                 NaN          NaN        NaN      NaN
# 1                 NaN          NaN        NaN      NaN
# 2        เปิดตรวจแล้ว      ไม่ระบุ    ไม่ระบุ  ขอนแก่น
# 3        เปิดตรวจแล้ว      ไม่ระบุ    ไม่ระบุ   ภูเก็ต
# 4                 NaN          NaN        NaN      NaN
# ...               ...          ...        ...      ...
# 7577439           NaN          NaN        NaN      NaN
# 7577440           NaN          NaN        NaN      NaN
# 7577441           NaN          NaN        NaN      NaN
# 7577442           NaN          NaN        NaN      NaN
# 7577443           NaN          NaN        NaN      NaN
#
# [7577444 rows x 13 columns]

# %%
data_tcn =data_t.dropna()
data_tcn
# Out:
#         announce_date   age                              risk  \
# 2           22/1/2020  73.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3           22/1/2020  73.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 8           26/1/2020  73.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 14          28/1/2020  32.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 15          28/1/2020  32.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...               ...   ...                               ...
# 7577385     15/3/2022  46.0                             อื่นๆ
# 7577386     15/3/2022  46.0                             อื่นๆ
# 7577387     15/3/2022  46.0                             อื่นๆ
# 7577388     15/3/2022  46.0                             อื่นๆ
# 7577389     15/3/2022  46.0                             อื่นๆ
#
#         province_of_onset district_of_onset  \
# 2                  นครปฐม             เมือง
# 3                  นครปฐม             เมือง
# 8         ประจวบคีรีขันธ์            หัวหิน
# 14                 ภูเก็ต             เมือง
# 15                 ภูเก็ต             เมือง
# ...                   ...               ...
# 7577385     กรุงเทพมหานคร          ห้วยขวาง
# 7577386     กรุงเทพมหานคร          ห้วยขวาง
# 7577387     กรุงเทพมหานคร          ห้วยขวาง
# 7577388     กรุงเทพมหานคร          ห้วยขวาง
# 7577389     กรุงเทพมหานคร          ห้วยขวาง
#
#                                                      orgth  \
# 2                                        โรงพยาบาลราชพฤกษ์
# 3        บริษัท เนชั่นแนล เฮลท์แคร์ ซิสเท็มส์ จำกัด สาข...
# 8                                          โรงพยาบาลหัวหิน
# 14                                       โรงพยาบาลราชพฤกษ์
# 15       บริษัท เนชั่นแนล เฮลท์แคร์ ซิสเท็มส์ จำกัด สาข...
# ...                                                    ...
# 7577385                                โรงพยาบาลพระรามเก้า
# 7577386  MIC Lab (บริษัทเมดิคอล อินโนเวชัน เซ็นเตอร์ จำ...
# 7577387                                   โรงพยาบาลปิยะเวท
# 7577388  บริษัทเนชั่นแนล เฮลท์แคร์ ซิสเท็มส์ จำกัด สาขา...
# 7577389                                   โรงพยาบาลเพชรเวช
#
#                            telephone  \
# 2                        0-4333-3555
# 3                  076298298 ต่อ5111
# 8                        0-3252-3000
# 14                       0-4333-3555
# 15                 076298298 ต่อ5111
# ...                              ...
# 7577385  0-2202-9999 ต่อ 11710-11712
# 7577386                  0-2101-6345
# 7577387                  0-2129-5555
# 7577388        0-2467-1111 ต่อ 3284
# 7577389                         1390
#
#                                                    address  district  \
# 2        456 หมู่ 14 ถนนมิตรภาพ ตำบลในเมือง อำเภอเมือง ...     เมือง
# 3                                                  ไม่ระบุ     เมือง
# 8        กลุ่มงานเทคนิคการแพทย์ 30/2 ต.หัวหิน อ.หัวหิน ...    หัวหิน
# 14       456 หมู่ 14 ถนนมิตรภาพ ตำบลในเมือง อำเภอเมือง ...     เมือง
# 15                                                 ไม่ระบุ     เมือง
# ...                                                    ...       ...
# 7577385  โรงพยาบาลพระรามเก้า เลขที่ 99 ถ.พระรามเก้า บาง...  ห้วยขวาง
# 7577386  เลขที่ 7 ซอยจัดสรร ถนนสุทธิสารวินิจฉัย แขวงสาม...  ห้วยขวาง
# 7577387  โรงพยาบาลปิยะเวท 998 ถนนริมคลองสามเสน แขวงบางะ...  ห้วยขวาง
# 7577388  2301/2 ถนน เพชรบุรีตัดใหม่ แขวง บางกะปิ เขตห้ว...  ห้วยขวาง
# 7577389  2469/13,15 ถ.เพชรบุรีตัดใหม่ ระหว่างแยก เอกมัย...  ห้วยขวาง
#
#                 npsts  pooledsaliva    pooledswab         province
# 2        เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ          ขอนแก่น
# 3        เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ           ภูเก็ต
# 8        เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว  ประจวบคีรีขันธ์
# 14       เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ          ขอนแก่น
# 15       เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ           ภูเก็ต
# ...               ...           ...           ...              ...
# 7577385  เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ    กรุงเทพมหานคร
# 7577386  เปิดตรวจแล้ว       ไม่ระบุ  เปิดตรวจแล้ว    กรุงเทพมหานคร
# 7577387  เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ    กรุงเทพมหานคร
# 7577388  เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ    กรุงเทพมหานคร
# 7577389  เปิดตรวจแล้ว       ไม่ระบุ       ไม่ระบุ    กรุงเทพมหานคร
#
# [6198506 rows x 13 columns]

# %%
covid_dist = data_tcn.groupby('district')['risk'].count()
covid_dist
# Out:
# district
# กบินทร์บุรี    12086
# กระทุ่มแบน     97893
# กระนวน           702
# กระบุรี          892
# กะทู้           4819
#                ...
# โคกโพธิ์        3949
# โพธาราม         8112
# โพนทอง          3169
# ไทรน้อย         6033
# ไม่ระบุ         7200
# Name: risk, Length: 242, dtype: int64

# %%
covid_df = pd.DataFrame(covid_dist)
covid_noindex = covid_df.reset_index()
covid_noindex
# Out:
#         district   risk
# 0    กบินทร์บุรี  12086
# 1     กระทุ่มแบน  97893
# 2         กระนวน    702
# 3        กระบุรี    892
# 4          กะทู้   4819
# ..           ...    ...
# 237     โคกโพธิ์   3949
# 238      โพธาราม   8112
# 239       โพนทอง   3169
# 240      ไทรน้อย   6033
# 241      ไม่ระบุ   7200
#
# [242 rows x 2 columns]

# %%
covid_noindex.to_csv('covid_noindex.csv', encoding='UTF-8')

# %%
data_dis1= covid_noindex.merge(data_lab,how='left',left_on='district',right_on = 'district') 
data_dis1
# Out:
#         district   risk                                              orgth  \
# 0    กบินทร์บุรี  12086                               โรงพยาบาลกบินทร์บุรี
# 1     กระทุ่มแบน  97893                                โรงพยาบาลกระทุ่มแบน
# 2     กระทุ่มแบน  97893                                  โรงพยาบาลมหาชัย 2
# 3     กระทุ่มแบน  97893       โรงพยาบาลวิชัยเวช อินเตอร์เนชั่นแนล อ้อมน้อย
# 4         กระนวน    702                     โรงพยาบาลสมเด็จพระยุพราชกระนวน
# ..           ...    ...                                                ...
# 507      ไม่ระบุ   7200                        วินเมด คลินิกเทคนิคการแพทย์
# 508      ไม่ระบุ   7200           คลินิกเทคนิคการแพทย์ ยู เวลเนส เซ็นเตอร์
# 509      ไม่ระบุ   7200              หนองคายเฮลท์แล็บ คลินิกเทคนิคการแพทย์
# 510      ไม่ระบุ   7200  บริษัท เนชั่นแนล เฮลท์แคร์ ซิสเท็มส์ จำกัด สาข...
# 511      ไม่ระบุ   7200  บริษัท เนชั่นแนล เฮลท์แคร์ ซิสเท็มส์ จำกัด สาข...
#
#         telephone                                            address  \
# 0     0-3728-8196                                            ไม่ระบุ
# 1     0-3447-0750  450/4 ถนนสุคนนิวิท ต.ตลาด อ.กระทุ่มแบน จ.สมุทร...
# 2    0-2431-0054                                             ไม่ระบุ
# 3     02-441-7899                                            ไม่ระบุ
# 4     0-4325-1302                                            ไม่ระบุ
# ..            ...                                                ...
# 507       ไม่ระบุ                                            ไม่ระบุ
# 508       ไม่ระบุ                                            ไม่ระบุ
# 509       ไม่ระบุ                                            ไม่ระบุ
# 510       ไม่ระบุ                                            ไม่ระบุ
# 511       ไม่ระบุ                                            ไม่ระบุ
#
#             npsts pooledsaliva pooledswab       province
# 0    เปิดตรวจแล้ว      ไม่ระบุ    ไม่ระบุ     ปราจีนบุรี
# 1    เปิดตรวจแล้ว      ไม่ระบุ    ไม่ระบุ      สมุทรสาคร
# 2    เปิดตรวจแล้ว      ไม่ระบุ    ไม่ระบุ      สมุทรสาคร
# 3    เปิดตรวจแล้ว      ไม่ระบุ    ไม่ระบุ      สมุทรสาคร
# 4    เปิดตรวจแล้ว      ไม่ระบุ    ไม่ระบุ        ขอนแก่น
# ..            ...          ...        ...            ...
# 507  เปิดตรวจแล้ว      ไม่ระบุ    ไม่ระบุ  กรุงเทพมหานคร
# 508  เปิดตรวจแล้ว      ไม่ระบุ    ไม่ระบุ  กรุงเทพมหานคร
# 509  เปิดตรวจแล้ว      ไม่ระบุ    ไม่ระบุ        หนองคาย
# 510  เปิดตรวจแล้ว      ไม่ระบุ    ไม่ระบุ       พิษณุโลก
# 511  เปิดตรวจแล้ว      ไม่ระบุ    ไม่ระบุ           ตราด
#
# [512 rows x 9 columns]

# %% [markdown]
# # ส่วนใหม่

# %%
data_dis11= data_dis1.merge(province_df,how='left',left_on='province',right_on = 'province') 
data_dis11.head()
# Out:
#       district   risk                                         orgth  \
# 0  กบินทร์บุรี  12086                          โรงพยาบาลกบินทร์บุรี
# 1   กระทุ่มแบน  97893                           โรงพยาบาลกระทุ่มแบน
# 2   กระทุ่มแบน  97893                             โรงพยาบาลมหาชัย 2
# 3   กระทุ่มแบน  97893  โรงพยาบาลวิชัยเวช อินเตอร์เนชั่นแนล อ้อมน้อย
# 4       กระนวน    702                โรงพยาบาลสมเด็จพระยุพราชกระนวน
#
#       telephone                                            address  \
# 0   0-3728-8196                                            ไม่ระบุ
# 1   0-3447-0750  450/4 ถนนสุคนนิวิท ต.ตลาด อ.กระทุ่มแบน จ.สมุทร...
# 2  0-2431-0054                                             ไม่ระบุ
# 3   02-441-7899                                            ไม่ระบุ
# 4   0-4325-1302                                            ไม่ระบุ
#
#           npsts pooledsaliva pooledswab    province 6 ภูมิภาค (ภูมิศาสตร์)
# 0  เปิดตรวจแล้ว      ไม่ระบุ    ไม่ระบุ  ปราจีนบุรี               ตะวันออก
# 1  เปิดตรวจแล้ว      ไม่ระบุ    ไม่ระบุ   สมุทรสาคร                   กลาง
# 2  เปิดตรวจแล้ว      ไม่ระบุ    ไม่ระบุ   สมุทรสาคร                   กลาง
# 3  เปิดตรวจแล้ว      ไม่ระบุ    ไม่ระบุ   สมุทรสาคร                   กลาง
# 4  เปิดตรวจแล้ว      ไม่ระบุ    ไม่ระบุ     ขอนแก่น     ตะวันออกเฉียงเหนือ

# %%
District = {'district':'อำเภอ'}
data_dis11.rename(columns=District,
          inplace=True)

# %%
Province = {'province':'จังหวัด'}
data_dis11.rename(columns=Province,
          inplace=True)

# %%
Number = {'risk':'จำนวนผู้ติดเชื้อ'}
data_dis11.rename(columns=Number,
          inplace=True)

# %%
data_dis11
# Out:
#            อำเภอ  จำนวนผู้ติดเชื้อ  \
# 0    กบินทร์บุรี             12086
# 1     กระทุ่มแบน             97893
# 2     กระทุ่มแบน             97893
# 3     กระทุ่มแบน             97893
# 4         กระนวน               702
# ..           ...               ...
# 507      ไม่ระบุ              7200
# 508      ไม่ระบุ              7200
# 509      ไม่ระบุ              7200
# 510      ไม่ระบุ              7200
# 511      ไม่ระบุ              7200
#
#                                                  orgth     telephone  \
# 0                                 โรงพยาบาลกบินทร์บุรี   0-3728-8196
# 1                                  โรงพยาบาลกระทุ่มแบน   0-3447-0750
# 2                                    โรงพยาบาลมหาชัย 2  0-2431-0054
# 3         โรงพยาบาลวิชัยเวช อินเตอร์เนชั่นแนล อ้อมน้อย   02-441-7899
# 4                       โรงพยาบาลสมเด็จพระยุพราชกระนวน   0-4325-1302
# ..                                                 ...           ...
# 507                        วินเมด คลินิกเทคนิคการแพทย์       ไม่ระบุ
# 508           คลินิกเทคนิคการแพทย์ ยู เวลเนส เซ็นเตอร์       ไม่ระบุ
# 509              หนองคายเฮลท์แล็บ คลินิกเทคนิคการแพทย์       ไม่ระบุ
# 510  บริษัท เนชั่นแนล เฮลท์แคร์ ซิสเท็มส์ จำกัด สาข...       ไม่ระบุ
# 511  บริษัท เนชั่นแนล เฮลท์แคร์ ซิสเท็มส์ จำกัด สาข...       ไม่ระบุ
#
#                                                address         npsts  \
# 0                                              ไม่ระบุ  เปิดตรวจแล้ว
# 1    450/4 ถนนสุคนนิวิท ต.ตลาด อ.กระทุ่มแบน จ.สมุทร...  เปิดตรวจแล้ว
# 2                                              ไม่ระบุ  เปิดตรวจแล้ว
# 3                                              ไม่ระบุ  เปิดตรวจแล้ว
# 4                                              ไม่ระบุ  เปิดตรวจแล้ว
# ..                                                 ...           ...
# 507                                            ไม่ระบุ  เปิดตรวจแล้ว
# 508                                            ไม่ระบุ  เปิดตรวจแล้ว
# 509                                            ไม่ระบุ  เปิดตรวจแล้ว
# 510                                            ไม่ระบุ  เปิดตรวจแล้ว
# 511                                            ไม่ระบุ  เปิดตรวจแล้ว
#
#     pooledsaliva pooledswab        จังหวัด 6 ภูมิภาค (ภูมิศาสตร์)
# 0        ไม่ระบุ    ไม่ระบุ     ปราจีนบุรี               ตะวันออก
# 1        ไม่ระบุ    ไม่ระบุ      สมุทรสาคร                   กลาง
# 2        ไม่ระบุ    ไม่ระบุ      สมุทรสาคร                   กลาง
# 3        ไม่ระบุ    ไม่ระบุ      สมุทรสาคร                   กลาง
# 4        ไม่ระบุ    ไม่ระบุ        ขอนแก่น     ตะวันออกเฉียงเหนือ
# ..           ...        ...            ...                    ...
# 507      ไม่ระบุ    ไม่ระบุ  กรุงเทพมหานคร                   กลาง
# 508      ไม่ระบุ    ไม่ระบุ  กรุงเทพมหานคร                   กลาง
# 509      ไม่ระบุ    ไม่ระบุ        หนองคาย     ตะวันออกเฉียงเหนือ
# 510      ไม่ระบุ    ไม่ระบุ       พิษณุโลก                   กลาง
# 511      ไม่ระบุ    ไม่ระบุ           ตราด               ตะวันออก
#
# [512 rows x 10 columns]

# %%
data_final = data_dis11[['จังหวัด','6 ภูมิภาค (ภูมิศาสตร์)','อำเภอ','จำนวนผู้ติดเชื้อ','orgth','telephone','npsts','pooledsaliva','pooledswab']] 
data_final
# Out:
#            จังหวัด 6 ภูมิภาค (ภูมิศาสตร์)        อำเภอ  จำนวนผู้ติดเชื้อ  \
# 0       ปราจีนบุรี               ตะวันออก  กบินทร์บุรี             12086
# 1        สมุทรสาคร                   กลาง   กระทุ่มแบน             97893
# 2        สมุทรสาคร                   กลาง   กระทุ่มแบน             97893
# 3        สมุทรสาคร                   กลาง   กระทุ่มแบน             97893
# 4          ขอนแก่น     ตะวันออกเฉียงเหนือ       กระนวน               702
# ..             ...                    ...          ...               ...
# 507  กรุงเทพมหานคร                   กลาง      ไม่ระบุ              7200
# 508  กรุงเทพมหานคร                   กลาง      ไม่ระบุ              7200
# 509        หนองคาย     ตะวันออกเฉียงเหนือ      ไม่ระบุ              7200
# 510       พิษณุโลก                   กลาง      ไม่ระบุ              7200
# 511           ตราด               ตะวันออก      ไม่ระบุ              7200
#
#                                                  orgth     telephone  \
# 0                                 โรงพยาบาลกบินทร์บุรี   0-3728-8196
# 1                                  โรงพยาบาลกระทุ่มแบน   0-3447-0750
# 2                                    โรงพยาบาลมหาชัย 2  0-2431-0054
# 3         โรงพยาบาลวิชัยเวช อินเตอร์เนชั่นแนล อ้อมน้อย   02-441-7899
# 4                       โรงพยาบาลสมเด็จพระยุพราชกระนวน   0-4325-1302
# ..                                                 ...           ...
# 507                        วินเมด คลินิกเทคนิคการแพทย์       ไม่ระบุ
# 508           คลินิกเทคนิคการแพทย์ ยู เวลเนส เซ็นเตอร์       ไม่ระบุ
# 509              หนองคายเฮลท์แล็บ คลินิกเทคนิคการแพทย์       ไม่ระบุ
# 510  บริษัท เนชั่นแนล เฮลท์แคร์ ซิสเท็มส์ จำกัด สาข...       ไม่ระบุ
# 511  บริษัท เนชั่นแนล เฮลท์แคร์ ซิสเท็มส์ จำกัด สาข...       ไม่ระบุ
#
#             npsts pooledsaliva pooledswab
# 0    เปิดตรวจแล้ว      ไม่ระบุ    ไม่ระบุ
# 1    เปิดตรวจแล้ว      ไม่ระบุ    ไม่ระบุ
# 2    เปิดตรวจแล้ว      ไม่ระบุ    ไม่ระบุ
# 3    เปิดตรวจแล้ว      ไม่ระบุ    ไม่ระบุ
# 4    เปิดตรวจแล้ว      ไม่ระบุ    ไม่ระบุ
# ..            ...          ...        ...
# 507  เปิดตรวจแล้ว      ไม่ระบุ    ไม่ระบุ
# 508  เปิดตรวจแล้ว      ไม่ระบุ    ไม่ระบุ
# 509  เปิดตรวจแล้ว      ไม่ระบุ    ไม่ระบุ
# 510  เปิดตรวจแล้ว      ไม่ระบุ    ไม่ระบุ
# 511  เปิดตรวจแล้ว      ไม่ระบุ    ไม่ระบุ
#
# [512 rows x 9 columns]

# %%
#data_final.to_csv('data_final2.csv', encoding="TIS-620")

# %%
covid_province = data1234.groupby('province_of_onset')['risk'].count()
covid_province
# Out:
# province_of_onset
# กระบี่            17131
# กรุงเทพมหานคร    562769
# กาญจนบุรี         23564
# กาฬสินธุ์         17758
# กำแพงเพชร         12609
#                   ...
# เพชรบูรณ์         47436
# เลย                9592
# แพร่               5445
# แม่ฮ่องสอน         4040
# ไม่มีข้อมูล      392974
# Name: risk, Length: 82, dtype: int64

# %%
covid_prodf = pd.DataFrame(covid_province)
prodf_noindex = covid_prodf.reset_index()
prodf_noindex
# Out:
#    province_of_onset    risk
# 0             กระบี่   17131
# 1      กรุงเทพมหานคร  562769
# 2          กาญจนบุรี   23564
# 3          กาฬสินธุ์   17758
# 4          กำแพงเพชร   12609
# ..               ...     ...
# 77         เพชรบูรณ์   47436
# 78               เลย    9592
# 79              แพร่    5445
# 80        แม่ฮ่องสอน    4040
# 81       ไม่มีข้อมูล  392974
#
# [82 rows x 2 columns]

# %%
data222 = prodf_noindex.merge(province_df,how='left',left_on='province_of_onset',right_on = 'province') 
data222
# Out:
#    province_of_onset    risk       province 6 ภูมิภาค (ภูมิศาสตร์)
# 0             กระบี่   17131         กระบี่                    ใต้
# 1      กรุงเทพมหานคร  562769  กรุงเทพมหานคร                   กลาง
# 2          กาญจนบุรี   23564      กาญจนบุรี                ตะวันตก
# 3          กาฬสินธุ์   17758      กาฬสินธุ์     ตะวันออกเฉียงเหนือ
# 4          กำแพงเพชร   12609      กำแพงเพชร                   กลาง
# ..               ...     ...            ...                    ...
# 77         เพชรบูรณ์   47436      เพชรบูรณ์                   กลาง
# 78               เลย    9592            เลย     ตะวันออกเฉียงเหนือ
# 79              แพร่    5445           แพร่                  เหนือ
# 80        แม่ฮ่องสอน    4040     แม่ฮ่องสอน                  เหนือ
# 81       ไม่มีข้อมูล  392974            NaN                    NaN
#
# [82 rows x 4 columns]

# %%
data333 = data222.fillna(value={'province':'ไม่มีข้อมูล','6 ภูมิภาค (ภูมิศาสตร์)':'ไม่มีข้อมูล'})
data333
# Out:
#    province_of_onset    risk       province 6 ภูมิภาค (ภูมิศาสตร์)
# 0             กระบี่   17131         กระบี่                    ใต้
# 1      กรุงเทพมหานคร  562769  กรุงเทพมหานคร                   กลาง
# 2          กาญจนบุรี   23564      กาญจนบุรี                ตะวันตก
# 3          กาฬสินธุ์   17758      กาฬสินธุ์     ตะวันออกเฉียงเหนือ
# 4          กำแพงเพชร   12609      กำแพงเพชร                   กลาง
# ..               ...     ...            ...                    ...
# 77         เพชรบูรณ์   47436      เพชรบูรณ์                   กลาง
# 78               เลย    9592            เลย     ตะวันออกเฉียงเหนือ
# 79              แพร่    5445           แพร่                  เหนือ
# 80        แม่ฮ่องสอน    4040     แม่ฮ่องสอน                  เหนือ
# 81       ไม่มีข้อมูล  392974    ไม่มีข้อมูล            ไม่มีข้อมูล
#
# [82 rows x 4 columns]

# %%
data333 .to_csv('data333 .csv', encoding='UTF-8')

# %%
prodf_noindex.to_csv('prodf_noindex.csv', encoding='UTF-8')

# %% [markdown]
# # **แก้**

# %% [markdown]
# ## จัดการข้อมูล Missing ใหม่

# %% [markdown]
# ### รวมข้อมูลผู้ติดเชื้อตั้งแต่ช่วงที่ 1-4 แล้วนำมาเลือกข้อมูลที่สนใจก่อนที่จะเตรียมข้อมูล

# %%
data_case1234= pd.concat([data_cases, data_cases1, data_cases2, data_cases3],axis=0) #vertical_concat
data_case1234
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0             1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1             2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2             3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3             4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4             5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...         ...           ...           ...   ...   ...  ...         ...
# 357076  3226693     15/3/2022     14/3/2022   ชาย   NaN  NaN         NaN
# 357077  3226694     15/3/2022     14/3/2022   ชาย   NaN  NaN         NaN
# 357078  3226695     15/3/2022     14/3/2022   ชาย   NaN  NaN         NaN
# 357079  3226696     15/3/2022     14/3/2022   ชาย   NaN  NaN         NaN
# 357080  3226697     15/3/2022     14/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                              risk  \
# 0              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                     นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                    นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                      ...                               ...
# 357076            ปราจีนบุรี                  ทัณฑสถาน/เรือนจำ
# 357077            ปราจีนบุรี                  ทัณฑสถาน/เรือนจำ
# 357078            นครราชสีมา                  ทัณฑสถาน/เรือนจำ
# 357079            นครราชสีมา                  ทัณฑสถาน/เรือนจำ
# 357080               ขอนแก่น                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset  Unnamed: 11
# 0          กรุงเทพมหานคร               NaN          NaN
# 1          กรุงเทพมหานคร               NaN          NaN
# 2                 นครปฐม             เมือง          NaN
# 3          กรุงเทพมหานคร               NaN          NaN
# 4          กรุงเทพมหานคร               NaN          NaN
# ...                  ...               ...          ...
# 357076               NaN               NaN          NaN
# 357077               NaN               NaN          NaN
# 357078               NaN               NaN          NaN
# 357079               NaN               NaN          NaN
# 357080               NaN               NaN          NaN
#
# [3249479 rows x 12 columns]

# %% [markdown]
# ### เลือกข้อมูลที่สนใจ

# %%
data_10 = data_case1234[['risk','province_of_onset','district_of_onset']]
data_10
# Out:
#                                     risk province_of_onset district_of_onset
# 0       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร               NaN
# 1       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร               NaN
# 2       คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม             เมือง
# 3       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร               NaN
# 4       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร               NaN
# ...                                  ...               ...               ...
# 357076                  ทัณฑสถาน/เรือนจำ               NaN               NaN
# 357077                  ทัณฑสถาน/เรือนจำ               NaN               NaN
# 357078                  ทัณฑสถาน/เรือนจำ               NaN               NaN
# 357079                  ทัณฑสถาน/เรือนจำ               NaN               NaN
# 357080                  ทัณฑสถาน/เรือนจำ               NaN               NaN
#
# [3249479 rows x 3 columns]

# %% [markdown]
# ### เตรียมข้อมูล

# %%
data_10.isnull().any()
# Out:
# risk                 True
# province_of_onset    True
# district_of_onset    True
# dtype: bool

# %% [markdown]
# ### Dropna

# %%
data_10_clean = data_10.dropna() 
data_10_clean
# Out:
#                                                      risk province_of_onset  \
# 2                        คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 7                        คนต่างชาติเดินทางมาจากต่างประเทศ   ประจวบคีรีขันธ์
# 13                       คนต่างชาติเดินทางมาจากต่างประเทศ            ภูเก็ต
# 16                       คนต่างชาติเดินทางมาจากต่างประเทศ         เชียงใหม่
# 22      อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...   ประจวบคีรีขันธ์
# ...                                                   ...               ...
# 357022                                              อื่นๆ     กรุงเทพมหานคร
# 357023                                              อื่นๆ     กรุงเทพมหานคร
# 357024                                              อื่นๆ     กรุงเทพมหานคร
# 357025                                              อื่นๆ     กรุงเทพมหานคร
# 357026                                              อื่นๆ     กรุงเทพมหานคร
#
#        district_of_onset
# 2                  เมือง
# 7                 หัวหิน
# 13                 เมือง
# 16                 หางดง
# 22                หัวหิน
# ...                  ...
# 357022          ห้วยขวาง
# 357023          ห้วยขวาง
# 357024           ราชเทวี
# 357025          ลาดพร้าว
# 357026          ห้วยขวาง
#
# [2673133 rows x 3 columns]

# %% [markdown]
# ### แก้คำผิดใน province_of_onset และdistrict_of_onset

# %%
data_10_clean['province_of_onset'].replace({'USA':'ไม่มีข้อมูล','\tประจวบคีรีขันธ์':'ประจวบคีรีขันธ์','\xa0กาญจนบุรี':'กาญจนบุรี','\xa0ชลบุรี':'ชลบุรี','\xa0ตราด':'ตราด','\xa0นครปฐม':'นครปฐม',
                                         '\xa0สมุทรสงคราม':'สมุทรสงคราม','\xa0สมุทรสาคร':'สมุทรสาคร','\xa0อุทัยธานี':'อุทัยธานี','กทม':'กรุงเทพมหานคร','กทม.':'กรุงเทพมหานคร','กบินทร์บุรี':'ปราจีนบุรี','กระบี่ี่':'กระบี่','กรุงเทพ':'กรุงเทพมหานคร',
                                         'กรุงเทพมหานคร.':'กรุงเทพมหานคร','กรุงเทพมหานคร. / พระนครศรีอยุธยา':'กรุงเทพมหานคร','กรุงเทพมหานคร. / ศรีสะเกษ':'กรุงเทพมหานคร','กรุงเทพฯ':'กรุงเทพมหานคร','กะทู้':'ภูเก็ต',
                                         'กัมพูชา':'ไม่มีข้อมูล','กาญจบุรี':'กาญจนบุรี','กาญนบุรี':'กาญจนบุรี','กาฬสิน':'กาฬสินธุ์','กาฬสินธิ์':'กาฬสินธุ์','กาฬสินธุ์\xa0':'กาฬสินธุ์','กาฬสินธ์':'กาฬสินธุ์',
                                         'กำเพงเพชร':'กำแพงเพชร','กำแพง':'กำแพงเพชร','กำแพงเพชร':'กำแพงเพชร','กำแพงเพชร\xa0':'กำแพงเพชร','กําแพงเพชร':'กำแพงเพชร',
                                         'ขอนแก่น\xa0':'ขอนแก่น','ขอนแก่่น':'ขอนแก่น','ขานุวรลักษณ์บุรี':'กำแพงเพชร','คนไทยเดินทางกลับจากต่างประเทศ':'ไม่มีข้อมูล','คลองเตย':'กรุงเทพมหานคร','จ.กรุงเทพมหานคร':'กรุงเทพมหานคร',
                                         'จ.ภูเก็ต':'ภูเก็ต','จ.ราชบุรี':'ราชบุรี','จ.สุราษฎร์ธานี':'สุราษฎร์ธานี','จังหวัดสมุทรสาคร':'สมุทรสาคร','ฉะเชองเทราร':'ฉะเชิงเทรา','ชมพร':'ชุมพร',
                                         'ชลบุรี\t':'ชลบุรี','ชลบุรี\xa0':'ชลบุรี','ชลบุุรี':'ชลบุรี','ชอนแก่น':'ขอนแก่น','ชัยนาถ':'ชัยนาท','ชัยบาดาล':'ลพบุรี','ชัยภูมิ\xa0':'ชัยภูมิ','ชุุมพร':'ชุมพร','ชุุุมพร':'ชุมพร',
                                         'ดอนมดแดง':'อุบลราชธานี','ดินแดง':'กรุงเทพมหานคร','ตรััง':'ตรัง','ตราด\xa0':'ตราด','ตากใบ':'นราธิวาส','ต่างจังหวัด':'ไม่มีข้อมูล','ทุ่งเสลี่ยม':'สุโขทัย',
                                         'ท้ายบ้าน':'สมุทรปราการ','ธารโต':'ยะลา','นคนปฐม':'นครปฐม','นคปฐม':'นครปฐม','นครนปฐม':'นครปฐม','นครนาชสีมา':'นครราชสีมา','นครปฐม\xa0':'นครปฐม',
                                         'นครปบม':'นครปฐม','นครพนม\xa0':'นครพนม','นครยายก':'นครนายก','นครราขสีมา':'นครราชสีมา','นครราชธานี':'นครราชสีมา','นครราชศรีมา':'นครราชสีมา','นครราชสสีมา':'นครราชสีมา',
                                         'นครราชสีมา ลพบุรี':'นครราชสีมา','นครราชสีมา\xa0':'นครราชสีมา','นครศรธรรมราช':'นครศรีธรรมราช','นครศรี':'นครศรีธรรมราช','นครศรีธรมมราช':'นครศรีธรรมราช',
                                         'นครศรีธรมราช':'นครศรีธรรมราช','นครศรีธรรมราข':'นครศรีธรรมราช','นครศรีฯ':'นครศรีธรรมราช','นครศรีีธรรมราช':'นครศรีธรรมราช','นครศร๊ธรรมราช':'นครศรีธรรมราช',
                                         'นครศร๊ะรรมราช':'นครศรีธรรมราช','นครสรรค์':'นครสวรรค์','นครสรีธรรมราช':'นครศรีธรรมราช','นครสวรรค':'นครสวรรค์','นครสวรรค์\xa0':'นครสวรรค์','นครสีธรรมราช':'นครศรีธรรมราช',
                                         'นครฯ':'นครศรีธรรมราช','นคราชสีมา':'นครราชสีมา','นครีศรีธรรมราช':'นครศรีธรรมราช','นตรนายก':'นครนายก','นตรปฐม':'นครปฐม','นนทบุรี\xa0':'นนทบุรี',
                                         'นนทบุุรี':'นนทบุรี','นนทุบรี':'นนทบุรี','นนทุรี':'นนทบุรี','นนมบุรี':'นนทบุรี','นรศรีธรรมราช':'นครศรีธรรมราช','นราธิวาส\u200b':'นราธิวาส','นราธฺวาส':'นราธิวาส','นอกเขต':'ไม่มีข้อมูล',
                                         'นาราธิวาส':'นราธิวาส','นาวัง':'หนองบัวลำภู','น่าน/ฉะเชิงเทรา':'น่าน','บางกรวย':'นนทบุรี','บางกะปิ':'กรุงเทพมหานคร','บางนา':'กรุงเทพมหานคร','บางปะอิน':'กรุงเทพมหานคร',
                                         'บางละมุง':'ชลบุรี','บางศรีเมือง':'นนทบุรี','บางเพียง':'สมุทรปราการ','บึงโขงหลง':'บึงกาฬ','บุรีรัมภ์':'บุรีรัมย์','บุรีรัมย์\xa0':'บุรีรัมย์','บุรีรัยม์':'บุรีรัมย์','บุรีรีมย์':'บุรีรัมย์',
                                         'บ้านหลวง':'น่าน','ปจ':'ไม่มีข้อมูล','ปทึมธานี':'ปทุมธานี','ปทุทธานี':'ปทุมธานี','ปทุมฑานี':'ปทุมธานี','ปทุมทานี':'ปทุมธานี','ปทุมธาน':'ปทุมธานี','ปทุมธานี\xa0':'ปทุมธานี','ปทุมาธานี':'ปทุมธานี',
                                         'ปธุมธานี':'ปทุมธานี','ปทุมธานี.':'ปทุมธานี','ปทุมธานีี':'ปทุมธานี','ปทุุมธานี':'ปทุมธานี','ปมุมธานี':'ปทุมธานี',
                                         'ประจวนคีรีขันธ็':'ประจวบคีรีขันธ์','ประจวบ':'ประจวบคีรีขันธ์','ประจวบคิรีขันธ์':'ประจวบคีรีขันธ์','ประจวบคีรขันธ์':'ประจวบคีรีขันธ์','ประจวบคีรขัันธ์':'ประจวบคีรีขันธ์','ประจวบคีรีขัน':'ประจวบคีรีขันธ์',
                                         'ประจวบคีรีขันธื':'ประจวบคีรีขันธ์','ประจวบคีรีขันธฺ':'ประจวบคีรีขันธ์','ประจวบคีรีขันธ์\xa0':'ประจวบคีรีขันธ์','ประจวบคีรีขันธ์์':'ประจวบคีรีขันธ์','ประจวบคีรีขัันธ์':'ประจวบคีรีขันธ์','ประจวบคีีรีขันธ์':'ประจวบคีรีขันธ์',
                                         'ประจวบฯ':'ประจวบคีรีขันธ์','ประทุมธานี':'ปทุมธานี', 'ประเทศกัมพูชา':'ไม่มีข้อมูล','ปราจีบุรี':'ปราจีนบุรี','ปลวกแดง':'ระยอง','ปลายพระยา':'กระบี่', 'ปอยเปต':'ไม่มีข้อมูล','ปัตตนรี':'ปัตตานี',
                                         'ปัตตานนี':'ปัตตานี','ปัตตานีี':'ปัตตานี','ปัว':'น่าน','ปััตตานี':'ปัตตานี','ปุทมธานี':'ปทุมธานี','ป่าโมก':'อ่างทอง','พม่า':'ไม่มีข้อมูล','พรหมพิราม':'พิษณุโลก','พระนครศรียุธยา':'พระนครศรีอยุธยา',
                                         'พระนครศรีอยุทธยา':'พระนครศรีอยุธยา','พระนครศรีอยุทยา':'พระนครศรีอยุธยา','พระนครศรีอยุธยา\xa0':'พระนครศรีอยุธยา','พัทยา':'ชลบุรี','พัทลุุง':'พัทลุง','พัังงา':'พังงา',
                                         'พิษณุโลก\xa0':'พิษณุโลก','พิษณูโลก':'พิษณุโลก','ฟินแลนด์':'ไม่มีข้อมูล','ภาษีเจริญ':'กรุงเทพมหานคร','ภุเก็ต':'ภูเก็ต','ภูุเก็ต':'ภูเก็ต','ภููเก็ต':'ภูเก็ต','ภูเก็็ต':'ภูเก็ต','ภูเพียง':'น่าน',
                                         'มหาสาคาม':'มหาสารคาม','มาเลเซีย':'ไม่มีข้อมูล','มุกาดหาร':'มุกดาหาร','ยานนาวา':'กรุงเทพมหานคร','ร.จ.จ.นราธิวาส':'นราธิวาส','รอ':'ร้อยเอ็ด','ระบุ':'ไม่มีข้อมูล','ระยอง\xa0':'ระยอง',
                                         'ระอยง':'ระยอง','ราชบบุรี':'ราชบุรี','ราชบุรีี':'ราชบุรี','ราชบุรี\u200b':'ราชบุรี','ราชุรี':'ราชบุรี','ราชเทวี':'กรุงเทพมหานคร','ร้องกวาง':'แพร่','ลบุรี':'ลพบุรี','ลพบุรี.':'ลพบุรี','ลพบุรี\xa0':'ลพบุรี','ลอง':'แพร่',
                                         'ลาดกระบัง':'กรุงเทพมหานคร','ลาดพร้าว':'กรุงเทพมหานคร','ลาว':'ไม่มีข้อมูล','ลำพูน\u200b':'ลำพูน','ลำพููน':'ลำพูน','ลำลูกกา':'ปทุมธานี','วังชิ้น':'ลำปาง','วังทอง':'พิษณุโลก',
                                         'วิเศษชัยชาญ':'อ่างทอง','ศรีษะสะเกษ':'ศรีสะเกษ','ศรีษะเกษ':'ศรีสะเกษ','ศรีสระเกษ':'ศรีสะเกษ','ศีรสะเกษ':'ศรีสะเกษ','สครสวรรค์':'นครสวรรค์',
                                         'สงขลา\u200b':'สงขลา','สถานที่ทำงาน':'ไม่มีข้อมูล','สพรรณบุรี':'สุพรรณบุรี','สมถทรปราการ':'สมุทรปราการ','สมทรสงคราม':'สมุทรสงคราม','สมทรสาคร':'สมุทรสาคร','สมุครปราการ':'สมุทรปราการ',
                                         'สมุครสาคร':'สมุทรสาคร','สมุท':'ไม่มีข้อมูล','สมุทปราการ':'สมุทรปราการ','สมุทรปรากร':'สมุทรปราการ','สมุทรปรากรร':'สมุทรปราการ','สมุทรปราการ\xa0':'สมุทรปราการ','สมุทรศาคร':'สมุทรสาคร',
                                         'สมุทรสาคร\xa0':'สมุทรสาคร','สมุทรสาคา':'สมุทรสาคร','สมุทรสาคาร':'สมุทรสาคร','สมุทรสาทร':'สมุทรสาคร','สมุทรสารคร':'สมุทรสาคร','สมุทราปราการ':'สมุทรปราการ',
                                         'สมุทราสาคร':'สมุทรสาคร','สมุทสงคราม':'สมุทรสงคราม','สมุทสาคร':'สมุทรสาคร','สมุย':'สุราษฎร์ธานี','สมุุทรปราการ':'สมุทรปราการ','สมุุทรสงคราม':'สมุทรสงคราม','สมุุทรสาคร':'สมุทรสาคร',
                                         'สระก้ว':'สระแก้ว','สระบุรี\xa0':'สระบุรี','สรินทร์':'สุรินทร์','สวิสเซอร์แลนด์':'ไม่มีข้อมูล','สอง':'แพร่','สองแคว':'น่าน','สะพานสูง':'กรุงเทพมหานคร',
                                         'สะแก้ว':'สระแก้ว','สัตหีบ':'ชลบุรี','สัมผัสผู้ป่วยยืนยัน COVID20':'ไม่มีข้อมูล','สามุทรสาคร':'สมุทรสาคร','สารคาม':'มหาสารคาม','สารภี':'เชียงใหม่','สิงห์บุรี\xa0':'สิงห์บุรี',
                                         'สุทรปราการ':'สมุทรปราการ','สุพรรญบุรี':'สุพรรณบุรี','สุพรรณบุรั':'สุพรรณบุรี','สุพรรณบุรี\xa0':'สุพรรณบุรี','สุมทรปราการ':'สมุทรปราการ',
                                         'สุมทรสาคร':'สมุทรสาคร','สุมุทรปราการ':'สมุทรปราการ','สุมุทรสาคร':'สมุทรสาคร','สุระบุรี':'สระบุรี','สุราษ':'สุราษฎร์ธานี','สุราษฎณ์ธานี':'สุราษฎร์ธานี','สุราษฎธานี':'สุราษฎร์ธานี',
                                         'สุราษฎร์':'สุราษฎร์ธานี','สุราษฎร์ฯ':'สุราษฎร์ธานี','สุราษฎร์์ธานี':'สุราษฎร์ธานี','สุราษฎ์ธานี':'สุราษฎร์ธานี','สุราษฏร์ธานี':'สุราษฎร์ธานี','สุราษธานี':'สุราษฎร์ธานี',
                                         'สุราษร์ฎธานี':'สุราษฎร์ธานี','สุราษร์ธานี':'สุราษฎร์ธานี','สุราษฯ':'สุราษฎร์ธานี','สุรินทรื':'สุรินทร์','สุรินทร์ 32150':'สุรินทร์','สุรินทร์,รีสะเกษ':'สุรินทร์','สุรินทร์\xa0':'สุรินทร์','สุริมทร์':'สุรินทร์',
                                         'สุริะแก้ว':'สระแก้ว','สุวรรณภูมิ':'สมุทรปราการ','สุุพรรณบุรี':'สุพรรณบุรี','สุุราษฎร์ธานี':'สุราษฎร์ธานี','สุุราษฏร์ธานี':'สุราษฎร์ธนี','สุุราษฯ':'สุราษฎร์ธนี','สุุรินทร์':'สุรินทร์',
                                         'สุุุโขทัย':'สุโขทัย','สุโขทับ':'สุโขทัย','สุโขทัย\xa0':'สุโขทัย','สูงเม่น':'แพร่','หนวงบัวลำภู':'หนองบัวลำภู','หนองงคาย':'หนองคาย','หนองบัวภู':'หนองบัวลำภู',
                                         'หนองบัวลำพูน':'หนองบัวลำภู','หนองบัวลําภู':'หนองบัวลำภู','หนองบััวลำภู':'หนองบัวลำภู','หนองม่วงไข่':'แพร่','หนอบัวลำภู':'หนองบัวลำภู','หลายจังหวัด':'ไม่มีข้อมูล','หัวหิน':'ประจวบคีรีขันธ์',
                                         'ห้วยขวาง':'กรุงเทพมหานคร','อยุทธยา':'พระนครศรีอยุธยา','อยุธยา':'พระนครศรีอยุธยา','อยุุธยา':'พระนครศรีอยุธยา','อำนาจเจิญ':'อำนาจเจริญ','อำนาญเจริญ':'อำนาจเจริญ','อำนาเจริญ':'อำนาจเจริญ',
                                         'อิสราเอล':'ไม่มีข้อมูล','อุดธานี':'อุดรธานี','อุดร':'อุดรธานี','อุดรธาณี':'อุดรธานี','อุดรธานี\xa0':'อุดรธานี','อุดรธานีี':'อุดรธานี','อุดรราชธานี':'อุดรธานี','อุตรดิตถ์\xa0':'อุตรดิตถ์',
                                         'อุตรดิตถ์์':'อุตรดิตถ์','อุตรดิษถ์':'อุตรดิตถ์','อุตรดิิตถ์':'อุตรดิตถ์','อุตรติดถ์':'อุตรดิตถ์','อุบลราขธานี':'อุบลราชธานี','อุบลราชธานี\xa0':'อุบลราชธานี','อุุครดิตถ์':'อุตรดิตถ์',
                                         'อุุดรธาน':'อุดรธานี','อุุดรธานี':'อุดรธานี','อุุตรดิตถ์':'อุตรดิตถ์','อุุทัยธานี':'อุทัยธานี','อุุบลราชธานี':'อุบลราชธานี','อ่งทอง':'อ่างทอง','อ่างทอง\xa0':'อ่างทอง','อํานาจเจริญ':'อำนาจเจริญ',
                                         'เชิงเทรา':'ฉะเชิงเทรา','เชียรใหญ่':'นครศรีธรรมราช','เชีียงราย':'เชียงราย','เชีียงใหม่':'เชียงใหม่','เด่นชัย':'แพร่',
                                         'เพขรบุรี':'เพชรบูรณ์','เพขรบูรณื':'เพชรบูรณ์','เพขรบูรณ์':'เพชรบูรณ์','เพชรบุรณ์':'เพชรบูรณ์','เพชรบุรี':'เพชรบูรณ์','เพชรบุรึ':'เพชรบูรณ์','เพชรบุุรี':'เพชรบูรณ์','เพชรบุูรณ์':'เพชรบูรณ์','เพชรบูรณ์\xa0':'เพชรบูรณ์',
                                         'เพชรบูร์':'เพชรบูรณ์','เพชรบููรณ์':'เพชรบูรณ์','เมือง':'แพร่','เมืองตาก':'ตาก','เมืองน่าน':'น่าน','เมืองปัตตานี':'ปัตตานี','เรือ':'เลย','เลย\xa0':'เลย','เวียงจันทร์':'ไม่มีข้อมูล','เวียงสา':'น่าน','แม่ทะ':'ลำปาง',
                                         'แล้วป่วย':'ไม่มีข้อมูล','โพธิ์ทอง':'อ่างทอง','ไชโย':'อ่างทอง','ไม่มีข้อมูล':'ไม่มีข้อมูล','ไม่มีชื่อหอพัก':'ไม่มีข้อมูล','ไม่ระบุ':'ไม่มีข้อมูล','สมุทรปรากา':'สมุทรปราการ'}, inplace=True)# แก้ไขข้อมูลที่พิมพ์จังหวัดผิด ให้อยู่ในชื่อจังหวัดที่ถูกต้อง
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
data_10_clean['district_of_onset'].replace({'กิงอำเภอชัยบุรี':'อำเภอชัยบุรี','บ้านฝาง\n':'บ้านฝาง','-':'ไม่มีข้อมูล', 'อำเภอศรีราชา':'ศรีราชา','\xa0ประจันตคาม':'ประจันตคาม','บ่างกะปิ':'บางกะปิ','บางละมุง.':'บางละมุง',
 'ท่าศาลา/ปทุมธานี':'ท่าศาลา','วังโป่ง เพชรบูรณ์':'เมืองเพชรบูรณ์','คบองเตย':'คลองเตย', 'นตรไทย':'เมืองพิษณุโลก',
 'แพรกษา':'เมืองสมุทรปราการ', 'อ.หนองแขม กรุงเทพมหานคร.':'หนองแขม',  'รพ.น้ำหนาว':'เมืองเพชรบูรณ์',
 'ตลิ่งชีน':'ตลิ่งชัน', 'เมืองปทุมธานี\xa0':'เมืองปทุมธานี', 'ปลวดเเดง':'ปลวกเเดง', 'เขต ทวีวัฒนา':'ทวีวัฒนา',
 'ชุุมพลบุรี':'เมืองสุรินทร์', 'เขตปทุมวัน':'ปทุมวัน', 'วังกระโจม':'เมืองนครนายก', 'ค่ายบางระจัน':'เมืองสิงห์บุรี',
 'ด่านมะขามเตี้ย กาญจนบุรี':'เมืองกาญจนบุรี', 'บางเสาร์ธง':'บางเสาธง', 'ตลองหลวง':'คลองหลวง',
 'วััดหลวง':'วัดหลวง', 'เมืืองอุดรธานี':'เมืองอุดรธานี', 'พระโขนง กรุงเทพมหานคร':'พระโขนง',
 'ศีราชา':'ศรีราชา', 'บาง เสาธง':'บางเสาธง', 'ราษฏร์ลูรณะ':'ราษฎร์บูรณะ', 'สัามพราย':'สามพราน',
 'นครศรีธรรมราช':'เมืองนครศรีธรรมราช', 'พระโขนง\u200b':'พระโขนง', 'คอลเตย':'คลองเตย',
 'หันนายาว':'คันนายาว', 'ท่าปลา (พิชัย)':'ท่าปลา', 'ลำพยา':'เมืองนครปฐม', 'ต้าผามอก':'ลอง',
 'กำแพงแสน นฐ':'กำแพงแสน', 'เมืองสมุทรปราากร':'เมืองสมุทรปราการ', 'สาบยใหม่':'สายไหม',
 'กัณฑรลักษณ์':'กันทรลักษณ์', 'ลลาดหลุมแก้ว':'ลาดหลุมแก้ว', '2สองพี่น้อง':'สองพี่น้อง',
 'เมืองสมุทรสาค':'เมืองสมุทรสาคร', 'เขตบางกะปิ กรุงเทพมหานคร.':'บางกะปิ','กเกร็ด':'ปากเกร็ด',
 'หนองจอก กรุงเทพมหานคร':'หนองจอก', 'สัังขละบุรี':'สังขละบุรี', 'คองสามวา':'คลองสามวา',
 'กิ่งอำเภอบัวลาย':'บัวลาย', 'เจะไอร้อง':'เจาะไอร้อง', 'ท่าม่วงกาญจนบุรี':'ท่าม่วง', 'ห้วยผึ้ึ่ง':'ห้วยผึ้ง',
 'สานมพราน':'สามพราน', 'พังตรุ':'ท่าม่วง', 'งบ้านฉาง':'บ้านฉาง', 'บ้านผืือ':'บ้านผือ', 'รพ.หล่มสัก':'หล่มสัก',
 'อ.เขาย้อย จ.เพชรบุรี':'เขาย้อย', 'เขตดุสิต':'ดุสิต', 'พุมธมณฑล':'พุทธมณฑล', 'บางซิ่อ':'บางซื่อ',
 'ปากเพลียว':'ปากเกลียว', 'คลองหลวง /หนองแซง':'คลองหลวง', 'ลานสัก-Cupทัพทัน':'ลานสัก',
 'มโรมย์':'มโนรมย์', 'เขตปทุม':'ปทุมวัน', 'เขตจตุจักร':'จตุจักร', 'นหว้า':'นาหว้า', 'ตรอน ทุ่งเสลี่ยม':'ทุ่งเสลี่ยม',
 'ราษำร์บูรณะ':'ราษฎร์บูรณะ', 'ลากพร้าว':'ลาดพร้าว', 'อ.กะพ้อ':'กะพ้อ', 'อ.ปางศิลาทอง':'ปางศิลาทอง',
 'กิ่งอำเภอบางเสาธง':'บางเสาธง', 'เขตสาธร':'สาธร', 'หนองแขม กรุงเทพมหานคร':'หนองแขม',
 'บ้านโปาง':'บ้านโป่ง', 'ศรี\u200bราชา':'ศรีราชา', 'นบพิดำ':'นบพิตำ', 'อ.เชียรใหญ่':'เชียรใหญ่',
 'บางละมุงชลบุรี':'บางละมุง', 'เมืองปัตตานี-':'เมืองปัตตานี', 'วานรนิิวาส':'วานรนิวาส', 'เมืองศีรสะเกษ':'เมืองศรีสะเกษ',
 'บางประปิ':'บางกระปิ', 'เมืองจันทรบุรี':'เมืองจันทบุรี', 'กิ่งอำเภอโนนนารายณ์':'โนนนารายณ์',
 'เขาคิฌกูฏ':'เขาคิชฌกูฏ', 'บางน้ำเปริ้ยว':'บางน้ำเปรี้ยว', 'ท่าเรื่อ':'ท่าเรือ', 'เมืองนครศรีธรรมราข':'เมืองนครศรีธรรมราช',
 'เขตทุ่งครุ':'ทุ่งครุ', 'ท่่าบ่อ':'ท่าบ่อ', 'เมืองนนทบรี':'เมืองนนทบุรี',  'เขตบางเขน':'บางเขน',
 'อำเภอเมืองนนทบุรี':'เมืองนนทบุรี', 'ปรวกแดง':'ปลวกแดง', 'เขตบางนาตราด':'บางนาตราด',
 'อ.เมืองอำนาจเจริญ จ.อำนาจเจริญ':'เมืองอำนาจเจริญ', 'ศรีสวัสดิ์\xa0':'ศรีสวัสดิ์', 'เขตคลองขวาง':'คลองขวาง',
 'โพนพิสััย':'โพนพิสัย', 'เมืองอำนาจ':'เมืองอำนาจเจริญ', 'อ.สามพราน จ.นครปฐม':'สามพราน',
'เมืองจันทบุรี\xa0':'เมืองจันทบุรี', 'ป้อมปราบฯ':'ป้อมปราบศัตรูพ่าย', 'เปือยน้้อย':'เปือยน้อย',
 'เมืองกาฬสิินธุ์':'เมืองกาฬสินธุ์', 'อ.หนองฉาง  จ.อุทัยธานี':'หนองฉาง', 'หัวหมาก กรุงเทพมหานคร':'หัวหมาก',
 'เมืองฉะเชิงเมรา':'เมืองฉะเชิงเฉรา', 'หัวยคต':'ห้วยคต', 'เมืองขอนแก่่น':'เมืองขอนแก่น',
 'ทุ้งกระเบน':'คุ้งกระเบน', 'เขตคลองตัน':'คลองตัน', 'อ.ประเวศ กรุงเทพมหานคร.':'ประเวศ',
 'เขตทุ่งครู':'ทุ่งครู่', 'เมืองสตล':'เมืองสตูล', 'ดอนเมือง กรุงเทพ':'ดอนเมือง', 'เมืิอง':'เมือง',
 'สีีคิ้ว':'สีคิ้ว', 'ปากเกร็ดจ.นนทบุรี':'ปากเกร็ด', 'สองพีน้อง':'สองพี่น้อง', 'เมืืองมหาสารคาม':'เมืองมหาสารคาม',
 'เขตลาดกระบัง':'ลาดกระบัง', 'เขตปทุมเวศ กรุงเทพมหานคร':'ปทุมเวศ', 'เขตคลองมหานาค':'คลองมหานาค',
 'เมืองกาญฯ':'เมืองกาญจนบุรี', 'กันททรลักษ์':'กันทรลักษณ์', 'เมือง/กรุงเทพมหานคร':'เมือง',
 'อ.สวนผึ้ง':'สวนผึ้ง', 'บางเขน\xa0':'บางเขน', '\xa0เขตดินแดง':'ดินแดง', 'อ.บ้านไผ่':'บ้านไผ่',
 'สตูล':'เมืองสตูล', 'อ.เมืองปัตตานี':'เมืองปัตตานี', 'สมุทรปราการ':'เมืองสมุทรปราการ'}, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %% [markdown]
# ## ข้อมูลรายชื่อห้องปฏิบัติการเครือข่ายตรวจโควิด-19

# %%
lab.head()
# Out:
#                                       orgth  \
# 0   ศูนย์วิทยาศาสตร์การแพทย์ที่ 1 เชียงใหม่
# 1  ศูนย์วิทยาศาสตร์การแพทย์ที่ 1/1 เชียงราย
# 2   สำนักงานป้องกันควบคุมโรคที่ 1 เชียงใหม่
# 3                         โรงพยาบาลนครพิงค์
# 4                            โรงพยาบาลลำปาง
#
#                                                orgen       telephone  \
# 0      Regional Medical Sciences Center 1 Chiang Mai  0-5311-2188-90
# 1    Regional Medical Sciences Center 1/1 Chiang Rai   0-5317-6224-6
# 2  The Office of Disease Prevention and Control 1...     0-5314-0774
# 3                                Nakornping Hospital    0-5399-9200
# 4                                   Lampang Hospital     0-5423-7400
#
#                                              address  \
# 0    191 หมู่ 8 ต.ดอนแก้ว อ.แม่ริม จ.เชียงใหม่ 50180
# 1  148 หมู่ 3 ตำบลนางแล อำเภอเมือง จังหวัดเชียงรา...
# 2  447 ถนนเชียงใหม่-ลำพูน ตำบลวัดเกต อำเภอเมือง จ...
# 3  159 ม.10 ถ.โชตนา ต.ดอนแก้ว อ.แม่ริม จ.เชียงใหม...
# 4  28/3 ห้องอณูชีวโมเลกุล กลุ่มงานเทคนิคการแพทย์ ...
#
#                                              website healtharea  agency  \
# 0  http://webapp1.dmsc.moph.go.th/cm1/web/post-gr...      เขต 1  ภาครัฐ
# 1                        http://cri.dmsc.moph.go.th/      เขต 1  ภาครัฐ
# 2                      https://ddc.moph.go.th/odpc1/      เขต 1  ภาครัฐ
# 3                  http://www.nkp-hospital.go.th/th/      เขต 1  ภาครัฐ
# 4                        http://www.lph.go.th/lpweb/      เขต 1  ภาครัฐ
#
#     province        district         area         npsts  pooledsaliva  \
# 0  เชียงใหม่          แม่ริม  ต่างจังหวัด  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 1   เชียงราย   เมืองเชียงราย  ต่างจังหวัด  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 2  เชียงใหม่  เมืองเชียงใหม่  ต่างจังหวัด  เปิดตรวจแล้ว           NaN
# 3  เชียงใหม่          แม่ริม  ต่างจังหวัด  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 4      ลำปาง      เมืองลำปาง  ต่างจังหวัด  เปิดตรวจแล้ว  เปิดตรวจแล้ว
#
#      pooledswab
# 0  เปิดตรวจแล้ว
# 1  เปิดตรวจแล้ว
# 2  เปิดตรวจแล้ว
# 3  เปิดตรวจแล้ว
# 4  เปิดตรวจแล้ว

# %% [markdown]
# ### เลือกข้อมูลที่สนใจ

# %%
lab_10 = lab[['orgth','telephone','province','district','npsts','pooledsaliva','pooledswab']]
lab_10
# Out:
#                                         orgth                   telephone  \
# 0     ศูนย์วิทยาศาสตร์การแพทย์ที่ 1 เชียงใหม่              0-5311-2188-90
# 1    ศูนย์วิทยาศาสตร์การแพทย์ที่ 1/1 เชียงราย               0-5317-6224-6
# 2     สำนักงานป้องกันควบคุมโรคที่ 1 เชียงใหม่                 0-5314-0774
# 3                           โรงพยาบาลนครพิงค์                0-5399-9200
# 4                              โรงพยาบาลลำปาง                 0-5423-7400
# ..                                        ...                         ...
# 508           งานอณูชีววิทยา โรงพยาบาลราชวิถี     0-2206-2900 ต่อ 40610-2
# 509           งานจุลชีววิทยา โรงพยาบาลราชวิถี  0-2206-2900 ต่อ 3142, 3143
# 510                        โรงพยาบาลประโคนชัย                 0-4467-0103
# 511     กรุงเทพพยาธิ-แลป คลินิกเทคนิคการแพทย์                 0-2619-2909
# 512            เอ็นเฮลท์ คลินิกเทคนิคการแพทย์  0-2019-9921,  09-8650-6735
#
#           province        district         npsts  pooledsaliva    pooledswab
# 0        เชียงใหม่          แม่ริม  เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 1         เชียงราย   เมืองเชียงราย  เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 2        เชียงใหม่  เมืองเชียงใหม่  เปิดตรวจแล้ว           NaN  เปิดตรวจแล้ว
# 3        เชียงใหม่          แม่ริม  เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 4            ลำปาง      เมืองลำปาง  เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# ..             ...             ...           ...           ...           ...
# 508  กรุงเทพมหานคร         ราชเทวี  เปิดตรวจแล้ว           NaN           NaN
# 509  กรุงเทพมหานคร         ราชเทวี  เปิดตรวจแล้ว           NaN           NaN
# 510      บุรีรัมย์       ประโคนชัย  เปิดตรวจแล้ว           NaN           NaN
# 511  กรุงเทพมหานคร           พญาไท  เปิดตรวจแล้ว           NaN           NaN
# 512  กรุงเทพมหานคร           บางแค  เปิดตรวจแล้ว           NaN           NaN
#
# [513 rows x 7 columns]

# %%
lab_10.isnull().any()
# Out:
# orgth           False
# telephone        True
# province        False
# district         True
# npsts           False
# pooledsaliva     True
# pooledswab       True
# dtype: bool

# %%
lab_10_clean = lab_10.dropna() 
lab_10_clean
# Out:
#                                         orgth                   telephone  \
# 0     ศูนย์วิทยาศาสตร์การแพทย์ที่ 1 เชียงใหม่              0-5311-2188-90
# 1    ศูนย์วิทยาศาสตร์การแพทย์ที่ 1/1 เชียงราย               0-5317-6224-6
# 3                           โรงพยาบาลนครพิงค์                0-5399-9200
# 4                              โรงพยาบาลลำปาง                 0-5423-7400
# 7             โรงพยาบาลเชียงรายประชานุเคราะห์                 0-5391-0600
# ..                                        ...                         ...
# 314                          โรงพยาบาลวิภาราม  0-2722-2500 ต่อ 2101, 2102
# 315                         โรงพยาบาลเมดพาร์ค                 0-2090-3081
# 320                      โรงพยาบาลไทยนครินทร์        0-2340-6499 ต่อ 3124
# 431   คลินิกเทคนิคการแพทย์ ฟีนิกซ์ โมเลกุลาร์                 080-0064557
# 464                         โรงพยาบาลโคกโพธิ์                 0-7343-1313
#
#           province       district         npsts  pooledsaliva    pooledswab
# 0        เชียงใหม่         แม่ริม  เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 1         เชียงราย  เมืองเชียงราย  เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 3        เชียงใหม่         แม่ริม  เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 4            ลำปาง     เมืองลำปาง  เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 7         เชียงราย  เมืองเชียงราย  เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# ..             ...            ...           ...           ...           ...
# 314  กรุงเทพมหานคร        สวนหลวง  เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 315  กรุงเทพมหานคร        คลองเตย  เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 320  กรุงเทพมหานคร          บางนา  เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 431  กรุงเทพมหานคร         ประเวศ  เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 464        ปัตตานี       โคกโพธิ์  เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว
#
# [140 rows x 7 columns]

# %% [markdown]
# ## รวมตารางผู้ติดเชื้อกับตาราง Lab

# %%
data_lab10= data_10_clean.merge(lab_10_clean,how='left',left_on='district_of_onset',right_on = 'district') 
data_lab10
# Out:
#                                                       risk province_of_onset  \
# 0                         คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 1                         คนต่างชาติเดินทางมาจากต่างประเทศ   ประจวบคีรีขันธ์
# 2                         คนต่างชาติเดินทางมาจากต่างประเทศ            ภูเก็ต
# 3                         คนต่างชาติเดินทางมาจากต่างประเทศ         เชียงใหม่
# 4        อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...   ประจวบคีรีขันธ์
# ...                                                    ...               ...
# 3296355                                              อื่นๆ     กรุงเทพมหานคร
# 3296356                                              อื่นๆ     กรุงเทพมหานคร
# 3296357                                              อื่นๆ     กรุงเทพมหานคร
# 3296358                                              อื่นๆ     กรุงเทพมหานคร
# 3296359                                              อื่นๆ     กรุงเทพมหานคร
#
#         district_of_onset                                              orgth  \
# 0                   เมือง                                                NaN
# 1                  หัวหิน                                    โรงพยาบาลหัวหิน
# 2                   เมือง                                                NaN
# 3                   หางดง                                                NaN
# 4                  หัวหิน                                    โรงพยาบาลหัวหิน
# ...                   ...                                                ...
# 3296355           ราชเทวี               คณะเวชศาสตร์เขตร้อน มหาวิทยาลัยมหิดล
# 3296356           ราชเทวี                             โรงพยาบาลพระมงกุฎเกล้า
# 3296357           ราชเทวี  บริษัทเอ็มบริโอ แพลนแนท จำกัด (สยามเฟอร์ทิลิตี...
# 3296358          ลาดพร้าว                                                NaN
# 3296359          ห้วยขวาง  บริษัท ไบโอ โมเลกุลาร์ แลบอราทอรีส์ (ในนามกลุ่...
#
#                      telephone         province  district         npsts  \
# 0                          NaN              NaN       NaN           NaN
# 1                  0-3252-3000  ประจวบคีรีขันธ์    หัวหิน  เปิดตรวจแล้ว
# 2                          NaN              NaN       NaN           NaN
# 3                          NaN              NaN       NaN           NaN
# 4                  0-3252-3000  ประจวบคีรีขันธ์    หัวหิน  เปิดตรวจแล้ว
# ...                        ...              ...       ...           ...
# 3296355   0-2306-9100 ต่อ 3082    กรุงเทพมหานคร   ราชเทวี  เปิดตรวจแล้ว
# 3296356  0-2354-7711 ต่อ 99358    กรุงเทพมหานคร   ราชเทวี  เปิดตรวจแล้ว
# 3296357          0-2116-5905-6    กรุงเทพมหานคร   ราชเทวี  เปิดตรวจแล้ว
# 3296358                    NaN              NaN       NaN           NaN
# 3296359            0-2762-4111    กรุงเทพมหานคร  ห้วยขวาง  เปิดตรวจแล้ว
#
#          pooledsaliva    pooledswab
# 0                 NaN           NaN
# 1        เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 2                 NaN           NaN
# 3                 NaN           NaN
# 4        เปิดตรวจแล้ว  เปิดตรวจแล้ว
# ...               ...           ...
# 3296355  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 3296356  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 3296357  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 3296358           NaN           NaN
# 3296359  เปิดตรวจแล้ว  เปิดตรวจแล้ว
#
# [3296360 rows x 10 columns]

# %%
data_lab10.isnull().any()
# Out:
# risk                 False
# province_of_onset    False
# district_of_onset    False
# orgth                 True
# telephone             True
# province              True
# district              True
# npsts                 True
# pooledsaliva          True
# pooledswab            True
# dtype: bool

# %%
data_lab10_clean = data_lab10.dropna() 
data_lab10_clean
# Out:
#                                                       risk province_of_onset  \
# 1                         คนต่างชาติเดินทางมาจากต่างประเทศ   ประจวบคีรีขันธ์
# 4        อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...   ประจวบคีรีขันธ์
# 6                         คนต่างชาติเดินทางมาจากต่างประเทศ            ภูเก็ต
# 8        อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...     กรุงเทพมหานคร
# 9        อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...     กรุงเทพมหานคร
# ...                                                    ...               ...
# 3296354                                              อื่นๆ     กรุงเทพมหานคร
# 3296355                                              อื่นๆ     กรุงเทพมหานคร
# 3296356                                              อื่นๆ     กรุงเทพมหานคร
# 3296357                                              อื่นๆ     กรุงเทพมหานคร
# 3296359                                              อื่นๆ     กรุงเทพมหานคร
#
#         district_of_onset                                              orgth  \
# 1                  หัวหิน                                    โรงพยาบาลหัวหิน
# 4                  หัวหิน                                    โรงพยาบาลหัวหิน
# 6                   กะทู้  ศูนย์บริการเทคนิคการแพทย์ คณะเทคนิคการแพทย์ มห...
# 8                 ราชเทวี                   คณะแพทยศาสตร์ โรงพยาบาลรามาธิบดี
# 9                 ราชเทวี               คณะเวชศาสตร์เขตร้อน มหาวิทยาลัยมหิดล
# ...                   ...                                                ...
# 3296354           ราชเทวี                   คณะแพทยศาสตร์ โรงพยาบาลรามาธิบดี
# 3296355           ราชเทวี               คณะเวชศาสตร์เขตร้อน มหาวิทยาลัยมหิดล
# 3296356           ราชเทวี                             โรงพยาบาลพระมงกุฎเกล้า
# 3296357           ราชเทวี  บริษัทเอ็มบริโอ แพลนแนท จำกัด (สยามเฟอร์ทิลิตี...
# 3296359          ห้วยขวาง  บริษัท ไบโอ โมเลกุลาร์ แลบอราทอรีส์ (ในนามกลุ่...
#
#                      telephone         province  district         npsts  \
# 1                  0-3252-3000  ประจวบคีรีขันธ์    หัวหิน  เปิดตรวจแล้ว
# 4                  0-3252-3000  ประจวบคีรีขันธ์    หัวหิน  เปิดตรวจแล้ว
# 6               0-7627-6012-13           ภูเก็ต     กะทู้  เปิดตรวจแล้ว
# 8                  0-2201-1470    กรุงเทพมหานคร   ราชเทวี  เปิดตรวจแล้ว
# 9         0-2306-9100 ต่อ 3082    กรุงเทพมหานคร   ราชเทวี  เปิดตรวจแล้ว
# ...                        ...              ...       ...           ...
# 3296354            0-2201-1470    กรุงเทพมหานคร   ราชเทวี  เปิดตรวจแล้ว
# 3296355   0-2306-9100 ต่อ 3082    กรุงเทพมหานคร   ราชเทวี  เปิดตรวจแล้ว
# 3296356  0-2354-7711 ต่อ 99358    กรุงเทพมหานคร   ราชเทวี  เปิดตรวจแล้ว
# 3296357          0-2116-5905-6    กรุงเทพมหานคร   ราชเทวี  เปิดตรวจแล้ว
# 3296359            0-2762-4111    กรุงเทพมหานคร  ห้วยขวาง  เปิดตรวจแล้ว
#
#          pooledsaliva    pooledswab
# 1        เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 4        เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 6        เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 8        เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 9        เปิดตรวจแล้ว  เปิดตรวจแล้ว
# ...               ...           ...
# 3296354  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 3296355  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 3296356  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 3296357  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 3296359  เปิดตรวจแล้ว  เปิดตรวจแล้ว
#
# [1558616 rows x 10 columns]

# %% [markdown]
# ### groupby risk

# %%
covid_10 = data_lab10_clean.groupby('district')['risk'].count()
covid_10
# Out:
# district
# กะทู้               4798
# คลองสาน             8489
# คลองหลวง           25404
# คลองเตย            20984
# คันนายาว            5642
#                    ...
# เมืองเพชรบูรณ์      1023
# เมืองแม่ฮ่องสอน       11
# แม่ริม              4802
# แม่สอด             35565
# โคกโพธิ์            3949
# Name: risk, Length: 99, dtype: int64

# %%
covid_df10 = pd.DataFrame(covid_10)
covid_noindex10 = covid_df10.reset_index()
covid_noindex10
# Out:
#            district   risk
# 0             กะทู้   4798
# 1           คลองสาน   8489
# 2          คลองหลวง  25404
# 3           คลองเตย  20984
# 4          คันนายาว   5642
# ..              ...    ...
# 94   เมืองเพชรบูรณ์   1023
# 95  เมืองแม่ฮ่องสอน     11
# 96           แม่ริม   4802
# 97           แม่สอด  35565
# 98         โคกโพธิ์   3949
#
# [99 rows x 2 columns]

# %%
data_dis10= covid_noindex10.merge(lab_10_clean,how='left',left_on='district',right_on = 'district') 
data_dis10
# Out:
#      district   risk                                              orgth  \
# 0       กะทู้   4798  ศูนย์บริการเทคนิคการแพทย์ คณะเทคนิคการแพทย์ มห...
# 1     คลองสาน   8489                                    โรงพยาบาลตากสิน
# 2    คลองหลวง  25404  ห้องปฏิบัติการเทคนิคการแพทย์ โรงพยาบาลธรรมศาสต...
# 3     คลองเตย  20984                คลินิกเทคนิคการแพทย์แบงคอกจีโนมิกส์
# 4     คลองเตย  20984                                  โรงพยาบาลเมดพาร์ค
# ..        ...    ...                                                ...
# 135    แม่ริม   4802                                  โรงพยาบาลนครพิงค์
# 136    แม่สอด  35565  หน่วยวิจัยมาลาเรียโซโกล ห้องปฏิบัติการจุลชีววิทยา
# 137    แม่สอด  35565                                    โรงพยาบาลแม่สอด
# 138    แม่สอด  35565                                โรงพยาบาลแม่สอด-ราม
# 139  โคกโพธิ์   3949                                  โรงพยาบาลโคกโพธิ์
#
#                         telephone       province         npsts  pooledsaliva  \
# 0                  0-7627-6012-13         ภูเก็ต  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 1    0-2437-0116-30 ต่อ 1231,1257  กรุงเทพมหานคร  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 2                  0-2926-9114-21       ปทุมธานี  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 3             0-2261-2638 ต่อ 206  กรุงเทพมหานคร  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 4                     0-2090-3081  กรุงเทพมหานคร  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# ..                            ...            ...           ...           ...
# 135                  0-5399-9200       เชียงใหม่  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 136                      55532026            ตาก  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 137                   0-5553-1224            ตาก  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 138                   0-5533-9124            ตาก  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 139                   0-7343-1313        ปัตตานี  เปิดตรวจแล้ว  เปิดตรวจแล้ว
#
#        pooledswab
# 0    เปิดตรวจแล้ว
# 1    เปิดตรวจแล้ว
# 2    เปิดตรวจแล้ว
# 3    เปิดตรวจแล้ว
# 4    เปิดตรวจแล้ว
# ..            ...
# 135  เปิดตรวจแล้ว
# 136  เปิดตรวจแล้ว
# 137  เปิดตรวจแล้ว
# 138  เปิดตรวจแล้ว
# 139  เปิดตรวจแล้ว
#
# [140 rows x 8 columns]

# %% [markdown]
# ## ข้อมูลจังหวัดแต่ละภูมิภาค

# %%
province_df
# Out:
#       province 6 ภูมิภาค (ภูมิศาสตร์)
# 0   อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 1       บึงกาฬ     ตะวันออกเฉียงเหนือ
# 2    บุรีรัมย์     ตะวันออกเฉียงเหนือ
# 3      ชัยภูมิ     ตะวันออกเฉียงเหนือ
# 4    กาฬสินธุ์     ตะวันออกเฉียงเหนือ
# ..         ...                    ...
# 72       พังงา                    ใต้
# 73      ภูเก็ต                    ใต้
# 74       ระนอง                    ใต้
# 75        สตูล                    ใต้
# 76        ตรัง                    ใต้
#
# [77 rows x 2 columns]

# %%
data_dis100= data_dis10.merge(province_df,how='left',left_on='province',right_on = 'province') 
data_dis100.head()
# Out:
#    district   risk                                              orgth  \
# 0     กะทู้   4798  ศูนย์บริการเทคนิคการแพทย์ คณะเทคนิคการแพทย์ มห...
# 1   คลองสาน   8489                                    โรงพยาบาลตากสิน
# 2  คลองหลวง  25404  ห้องปฏิบัติการเทคนิคการแพทย์ โรงพยาบาลธรรมศาสต...
# 3   คลองเตย  20984                คลินิกเทคนิคการแพทย์แบงคอกจีโนมิกส์
# 4   คลองเตย  20984                                  โรงพยาบาลเมดพาร์ค
#
#                       telephone       province         npsts  pooledsaliva  \
# 0                0-7627-6012-13         ภูเก็ต  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 1  0-2437-0116-30 ต่อ 1231,1257  กรุงเทพมหานคร  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 2                0-2926-9114-21       ปทุมธานี  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 3           0-2261-2638 ต่อ 206  กรุงเทพมหานคร  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 4                   0-2090-3081  กรุงเทพมหานคร  เปิดตรวจแล้ว  เปิดตรวจแล้ว
#
#      pooledswab 6 ภูมิภาค (ภูมิศาสตร์)
# 0  เปิดตรวจแล้ว                    ใต้
# 1  เปิดตรวจแล้ว                   กลาง
# 2  เปิดตรวจแล้ว                   กลาง
# 3  เปิดตรวจแล้ว                   กลาง
# 4  เปิดตรวจแล้ว                   กลาง

# %%
data_dis100.isnull().any()
# Out:
# district                  False
# risk                      False
# orgth                     False
# telephone                 False
# province                  False
# npsts                     False
# pooledsaliva              False
# pooledswab                False
# 6 ภูมิภาค (ภูมิศาสตร์)    False
# dtype: bool

# %%
data_final10 = data_dis100[['province','6 ภูมิภาค (ภูมิศาสตร์)','district','risk','orgth','telephone','npsts','pooledsaliva','pooledswab']] 
data_final10
# Out:
#           province 6 ภูมิภาค (ภูมิศาสตร์)  district   risk  \
# 0           ภูเก็ต                    ใต้     กะทู้   4798
# 1    กรุงเทพมหานคร                   กลาง   คลองสาน   8489
# 2         ปทุมธานี                   กลาง  คลองหลวง  25404
# 3    กรุงเทพมหานคร                   กลาง   คลองเตย  20984
# 4    กรุงเทพมหานคร                   กลาง   คลองเตย  20984
# ..             ...                    ...       ...    ...
# 135      เชียงใหม่                  เหนือ    แม่ริม   4802
# 136            ตาก                ตะวันตก    แม่สอด  35565
# 137            ตาก                ตะวันตก    แม่สอด  35565
# 138            ตาก                ตะวันตก    แม่สอด  35565
# 139        ปัตตานี                    ใต้  โคกโพธิ์   3949
#
#                                                  orgth  \
# 0    ศูนย์บริการเทคนิคการแพทย์ คณะเทคนิคการแพทย์ มห...
# 1                                      โรงพยาบาลตากสิน
# 2    ห้องปฏิบัติการเทคนิคการแพทย์ โรงพยาบาลธรรมศาสต...
# 3                  คลินิกเทคนิคการแพทย์แบงคอกจีโนมิกส์
# 4                                    โรงพยาบาลเมดพาร์ค
# ..                                                 ...
# 135                                  โรงพยาบาลนครพิงค์
# 136  หน่วยวิจัยมาลาเรียโซโกล ห้องปฏิบัติการจุลชีววิทยา
# 137                                    โรงพยาบาลแม่สอด
# 138                                โรงพยาบาลแม่สอด-ราม
# 139                                  โรงพยาบาลโคกโพธิ์
#
#                         telephone         npsts  pooledsaliva    pooledswab
# 0                  0-7627-6012-13  เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 1    0-2437-0116-30 ต่อ 1231,1257  เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 2                  0-2926-9114-21  เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 3             0-2261-2638 ต่อ 206  เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 4                     0-2090-3081  เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# ..                            ...           ...           ...           ...
# 135                  0-5399-9200   เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 136                      55532026  เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 137                   0-5553-1224  เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 138                   0-5533-9124  เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว
# 139                   0-7343-1313  เปิดตรวจแล้ว  เปิดตรวจแล้ว  เปิดตรวจแล้ว
#
# [140 rows x 9 columns]

# %%
data_final10.to_csv('data_final10.csv', encoding="TIS-620")
